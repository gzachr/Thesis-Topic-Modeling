# %%
import os
import random
import requests
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.models import FastText
import numpy as np
import spacy
import string
from wordcloud import WordCloud
import unicodedata
import matplotlib.pyplot as plt
from collections import Counter
from nltk.util import ngrams
from collections import defaultdict

# Load FastText Model
#fasttext_model = FastText.load("fasttext_300dim_20epochs.model")

def load_filipino_context_words():
    """Load Filipino-related words from a file."""
    with open("filipino_context_words.txt", "r", encoding="utf-8") as file:
        return [line.strip() for line in file.readlines()]

#filipino_context_words = load_filipino_context_words()

# Folder paths
transcripts_folder_path = 'cleaned_transcripts/'
tags_folder_path = 'tags/'

# Function to load random documents
def load_random_documents(folder_path, sample_size=2086):
    all_files = [file_name for file_name in os.listdir(folder_path) if file_name.endswith('.txt')]
    sampled_files = random.sample(all_files, min(sample_size, len(all_files)))

    documents = []
    file_names = []
    for file_name in sampled_files:
        with open(os.path.join(folder_path, file_name), 'r', encoding='utf-8') as file:
            content = file.read().lower()
            if len(content.split()) >= 100:
                documents.append(content)
                file_names.append(file_name)
    return documents, file_names

documents, file_names = load_random_documents(transcripts_folder_path)

# Function to load video tags
def load_video_tags(folder_path):
    video_tags = {}
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.txt'):
            video_id = file_name.split('_')[0]
            with open(os.path.join(folder_path, file_name), 'r', encoding='utf-8') as file:
                tags_content = file.read().lower()
                video_tags[video_id] = tags_content.split()
    return video_tags

video_tags = load_video_tags(tags_folder_path)

# Fetch stopwords
def fetch_stopwords_from_github(url):
    response = requests.get(url)
    return set(response.text.splitlines())

github_stopwords_url = 'https://raw.githubusercontent.com/stopwords-iso/stopwords-en/master/stopwords-en.txt'
github_stopwords = fetch_stopwords_from_github(github_stopwords_url)

stop_words = set(stopwords.words('english'))
custom_stop_words = ['like', 'yeah', 'know', 'um', 'uh', 'really', 'one', 'go', 'right', 'okay', 'well', 'said', 
                     'going', 'got', 'na', 'always', 'every', 'each', 'say', 'el', 'little', 'still', 
                     'best', 'dutch', 'nice', 'great', 'awesome', 'good', 'cool', 'love', 'amazing', 'wow' ]
broad_terms = ['philippines', 'philippine', 'british', 'filipino', 'video', 'http', 'korea', 'korean', 
               'youtube', 'google', 'united', 'america', 'american']
kpop_keywords = ['kpop', '필리핀', 'bts', 'blackpink', 'twice', 'exo', 'k-pop', 'seventeen', 
                 'stray kids', 'nct', 'kdrama', 'aespa', 'taehyung', 'jimin', 'jungkook']
more_keywords = [
    'breaking news', 'report', 'coverage', 'investigation', 'interview', 'documentary', 'news', 'netherlands', 'psy', 'subtitle', 'description', 'link', 
    'journalist', 'headline', 'reporter', 'current events', 'special report', 
    'analysis', 'documented', 'broadcast', 'reporting', 'v', 'food', 'travel', 'react', 
    'reacts', 'reaction', 'foreigner', 'thing', 'visit', 'dc', 'japan', 'first', 'fast', 
    'asia', 'ang', 'indian', 'thai', 'vietnamese', 'russia', 'gon', 'canada', 'canadian', 'russian', 
    'russia', 'guy', 'lot', 'bit', 'diba', 'ola', 'cuz', 'thai', 'thailand', 'person', 'citizen', 'foreigner', 'foreign', 'foreigners',
    'facebook', 'filipinos', 'filipinas', 'vlog', 'vlogs', 'vlogging', 'hashtag', 'india', 'bro', 'dito', 'people', 'time', 'music', 'gonna', 'life', 
    'lol', 'guys', 'tho', 'cute', 'hmm', 'huh', 'channel', 'subscribe', 'day6', 'mandarin', 'chinese', 'beautiful',
    'chuckles', 'fbe', 'hit', 'laughs', 'yo', 'ka', 'word', 'living', 'boi', 'minimum', 'ya', 'successful', 'perfectly', 'yeap', 
    'wondering', 'fantastic', 'hurry', 'german', 'age', 'country', 'subscribing', 'bluesy', 'jump', 'pretty', 'understanding', 'personalized',
    'and', 'the', 'to', 'of', 'in', 'for', 'on', 'with', 'at', 'by', 'from', 'up', 'about', 'over', 'into', 'through', 'between', 'under', 'against', 'all',
    'you', 'haha', 'hahaha', 'ha', 'hey', 'bye', 'hello', 'hi', 'oh', 'blah', 'easy', 'alright', 'ta', 'day', 'ooh', 'en', 'do', 'lot', 'comment', 'notification', 
    'korean', 'jjajangmyeon', 'jajangmyeon', 'damn', 'yall', 'month', 'week', 'year', 'ohhh', 'pvf', 'dude', 'mmm', 'kagilagilalas', 'ofcourse', 'australia', 'uxo', 
    'atleast', 'yusuf', 'bangkok', 'ot', 'anytime', 'allover', 'kala', 'nope', 'wan', 'brazil', 'smooth', 'ot', 'timeshere', 'batchof', 'yep', 'opo', 'del',
    'gosh', 'po', 'ourself', 'wo', 'wait', 'ugh', 'nyc', 'whoa', 'nicaragua', 'yup', 'em', 'bout', 'le', 'omg', 'overwhelm', 'maam', 'nicer', 'haha', 'hahaha', 'ha', 
    'nbcs', 'lana', 'rc', 'whatsoever', 'oxy', 'decade', 'whyd', 'unknown', 'ahhhhh', 'ohoh', 'ohto', 'ohhhh', 'bruh', 'ooe', 'ahmedabad', 'mexico', 
    'understand', 'excuse', 'kinda', 'applause', 'oooh', 'thiswhat', 'nevermind', 'ahh', 'againthank', 'toto', 'aww', 'nah', 'bbmas', 'ay', 'op', 'huh', 'huhu',
    'tada', 'beacuse', 'voila', 'upstairs', 'thatswhy', 'yea', 'that', 'armenia', 'or', 'not', 'funwhat', 'aka', 'armeniathat', 'woosexy', 'worth', 'laugh', 'box', 
    'xd', 'vb', 'eff', 'ananya', 'welsh', 'latron', 'shout', 'whatwhat', 'what', 'pause', 'why', 'thats', 'byebye', 'iv', 'bye', 'ado', 'ownup', 'dom', 'jomm', 'sir', 
    'budgie', 'nomac', 'lavocha', 'germany', 'why', 'walang', 'superduper', 'philip', 'mom', 'jre', 'giddy', 'intro', 'dupe', 'europe', 'dream', 'team', 'dislike', 'content', 
    'yoongi', 'royale', 'ilu', 'jhope', 'day', 'jin', 'ecc', 'nyhs', 'nego', 'chavez', 'pb', 'everyones', 'epic', 'matter', 'oneonone', 'region', 'change', 'ho', 'seetoh', 
    'atin', 'vpn', 'facetune', 'busu', 'mackie', 'clyd', 'china', 'rest', 'friend', 'woah', 'dindins', 'poster', 'vibe', 'woman', 'boss', 'woah', 'type', 'mahana', 'joke', 
    'taller', 'insane', 'whang', 'psa', 'manatee', 'recommend', 'caesar', 'mmmhmm', 'mosul', 'dun', 'clue', 'naysayer', 'hindi', 'ko', 'pero', 'bulgaria', 'question', 'video', 
    'yobi', 'hindu', 'expat', 'option', 'gap', 'eu', 'simo', 'kouignamann', 'bct', 'month', 'cfo'
]
stop_words.update(custom_stop_words, kpop_keywords, broad_terms, more_keywords, github_stopwords)

lemmatizer = WordNetLemmatizer()

# Helper function to check if a word contains only Latin script characters
def is_latin_script(word):
    for char in word:
        if not ('LATIN' in unicodedata.name(char, '') or char.isdigit()):
            return False
    return True

def preprocess_text(doc, video_id, ngram_range=(1, 2), tag_weight=1, filipino_weight=2, ngram_weight_factor=1):
    """Preprocess text while considering Filipino context and video tags."""
    doc = doc.lower().translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(doc)
    tokens_with_pos = pos_tag(tokens)

    # Apply lemmatization
    lemmatized_tokens = [lemmatizer.lemmatize(word, get_wordnet_pos(pos)) for word, pos in tokens_with_pos]

    # Generate n-grams
    ngram_tokens = []
    for n in range(ngram_range[0], ngram_range[1] + 1):
        ngram_tokens.extend([' '.join(gram) for gram in ngrams(lemmatized_tokens, n)])

    # Count n-gram frequency
    ngram_frequencies = Counter(ngram_tokens)

    # Filter stopwords and non-useful words
    filtered_tokens = []
    for word, pos in tokens_with_pos:
        if not word.isalpha() or word in stop_words:
            continue
        if pos in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'JJ', 'JJR', 'JJS', 'RB', 'RBR', 'RBS']:
            continue  # Remove verbs and adjectives
        filtered_tokens.append(word)

    # Assign weight based on n-grams and Filipino similarity
    weighted_tokens = []
    for token in filtered_tokens:
        token_weight = 1 + ngram_frequencies.get(token, 0) * ngram_weight_factor
        weighted_tokens.extend([token] * int(token_weight))

    # Include video tags
    if video_id in video_tags:
        tags = video_tags[video_id]
        for tag in tags:
            if tag.isalpha():
                tag_weight_multiplier = tag_weight
                #filipino_similarity = get_filipino_similarity(tag)
                #if filipino_similarity > 0.3:
                    #tag_weight_multiplier *= filipino_weight * filipino_similarity
                weighted_tokens.extend([tag] * int(tag_weight_multiplier))

    return ' '.join(weighted_tokens)

def get_filipino_similarity(word):
    """Compute similarity to Filipino words using FastText."""
    if word in filipino_context_words:
        return 1
    try:
        similarities = [fasttext_model.wv.similarity(word, ref_word) for ref_word in filipino_context_words if ref_word in fasttext_model.wv]
        return max(similarities) if similarities else 0
    except KeyError:
        return 0
    
def get_wordnet_pos(treebank_tag):
    """Convert POS tag to WordNet format for lemmatization."""
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default to noun
    
# Load and preprocess all transcripts together
all_documents = []
video_ids = []
for file_name in os.listdir(transcripts_folder_path):
    if file_name.endswith('.txt'):
        video_id = file_name.split('_captions')[0]
        with open(os.path.join(transcripts_folder_path, file_name), 'r', encoding='utf-8') as file:
            content = file.read().lower()
            if len(content.split()) >= 100:  # Minimum word count check
                processed_text = preprocess_text(content, video_id)
                all_documents.append(processed_text)
                video_ids.append(video_id)

# Create Dictionary and Corpus for LDA
dictionary = corpora.Dictionary([doc.split() for doc in all_documents])
corpus = [dictionary.doc2bow(doc.split()) for doc in all_documents]

# Train LDA on all transcripts
num_topics = 15  # Adjust based on coherence scoring if needed
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, eta='auto', alpha='auto', passes=50, random_state=42)

# Dictionary to store the number of videos per topic
topic_video_count = defaultdict(int)

# Associate videos with topics and update topic count
video_topic_mapping = {}
for idx, doc_bow in enumerate(corpus):
    video_id = video_ids[idx]
    topic_distribution = lda_model.get_document_topics(doc_bow, minimum_probability=0)

    # Extract topics with high probabilities
    assigned_topics = [topic for topic, prob in topic_distribution if prob > 0.2]  # Threshold can be tuned
    video_topic_mapping[video_id] = assigned_topics

    # Update the count for each assigned topic
    for topic in assigned_topics:
        topic_video_count[topic] += 1

# Print results
for video_id, topics in video_topic_mapping.items():
    print(f"Video {video_id} belongs to topics: {topics}")

# Print the number of videos per topic
print("\nNumber of videos per topic:")
for topic, count in sorted(topic_video_count.items()):
    print(f"Topic {topic}: {count} videos")
# Out:
# Video --8n6A8Q6M0 belongs to topics: [1]
# Video -0FfyNZdHk0 belongs to topics: [0]
# Video -4yu_13EHFM belongs to topics: [2, 14]
# Video -6FvAU9H98w belongs to topics: [7]
# Video -7vF5F-1btE belongs to topics: [0]
# Video -9hDaG3nJwg belongs to topics: [10]
# Video -Pe-c-CHkIo belongs to topics: [8, 9]
# Video -U5-r29G-t0 belongs to topics: [0, 13]
# Video 0-dAyU-yUWk belongs to topics: [14]
# Video 008Fi25LbKY belongs to topics: [1, 7]
# Video 00qBuhJeG-o belongs to topics: [0, 10]
# Video 026urE67c8c belongs to topics: [0, 1]
# Video 06Qq4to_l10 belongs to topics: [0, 9]
# Video 09HUMZrCH3A belongs to topics: [6]
# Video 0AuL6FQR3HE belongs to topics: [6]
# Video 0ax6XooGykc belongs to topics: [0]
# Video 0Cj35oMbb9Q belongs to topics: [1, 3]
# Video 0E4c8VDmUTk belongs to topics: [0]
# Video 0eTmLcoLe9s belongs to topics: [10]
# Video 0f3m80ZA8BM belongs to topics: [10]
# Video 0gc-NMhT8Y0 belongs to topics: [9]
# Video 0ifwCzzCdvc belongs to topics: [7]
# Video 0IJm5TFpldU belongs to topics: [0, 14]
# Video 0IMWasj76yU belongs to topics: [9, 11]
# Video 0iNlBNR9PGE belongs to topics: [1, 8]
# Video 0i_ZIWC0c1M belongs to topics: [0]
# Video 0KOXxVJx0sk belongs to topics: [6, 9]
# Video 0KqsD2FS-DM belongs to topics: [8, 12, 14]
# Video 0mDJwB6DLvg belongs to topics: [5]
# Video 0Mnau-zACiE belongs to topics: [0, 7]
# Video 0nRXbv67-4M belongs to topics: [0]
# Video 0O2i843tdU4 belongs to topics: [1, 14]
# Video 0ovXuSBwktM belongs to topics: [9]
# Video 0Qr12Zerphs belongs to topics: [3, 14]
# Video 0Rge7nN8wss belongs to topics: [0]
# Video 0rqsRvyIvIc belongs to topics: [2]
# Video 0s6stvGVAEk belongs to topics: [0]
# Video 0SlWsnwIWN4 belongs to topics: [3, 14]
# Video 0tA3LAVwkIo belongs to topics: [5]
# Video 0UDH4y28YVQ belongs to topics: [8]
# Video 0UFz5YQk8o0 belongs to topics: [6]
# Video 0uJu9JkxNwI belongs to topics: [0]
# Video 0zkiGw4F5Pw belongs to topics: [6]
# Video 1-4pxMY9rq8 belongs to topics: [9]
# Video 1-m9KLTaeaI belongs to topics: [2]
# Video 12t-wjHSq5c belongs to topics: [8, 14]
# Video 1427-FjkU3s belongs to topics: [10]
# Video 15O6Q7JINkE belongs to topics: [14]
# Video 18Iluqov9Xk belongs to topics: [0]
# Video 1A-RhyuOLYI belongs to topics: [10]
# Video 1aZ4UYjlHEA belongs to topics: [6, 10]
# Video 1C753eMNsKg belongs to topics: [0]
# Video 1Ccsgr9T69Q belongs to topics: [14]
# Video 1fSsyZeYVp8 belongs to topics: [0]
# Video 1GHM1QQDSrI belongs to topics: [0, 3]
# Video 1hCuqLQfmRw belongs to topics: [3]
# Video 1HEOo6a91yY belongs to topics: [3, 8]
# Video 1kErCqgIVMk belongs to topics: [2]
# Video 1kqTWaM9FsY belongs to topics: [10]
# Video 1o_Zw6LbLnU belongs to topics: [10]
# Video 1qvAJGZYr3E belongs to topics: [6]
# Video 1rvvN5No_Yk belongs to topics: [9, 14]
# Video 1Ucsm6J24Us belongs to topics: [8]
# Video 1yG9Kki_BNg belongs to topics: [10, 14]
# Video 1YXmTTKljwk belongs to topics: [0, 8]
# Video 20SwObTtOB8 belongs to topics: [0, 10, 14]
# Video 23GlZtU6eVY belongs to topics: [8]
# Video 23L8K7nOG_c belongs to topics: [6]
# Video 27yofdZnH9s belongs to topics: [1, 13]
# Video 2cj-ZOqXn0s belongs to topics: [14]
# Video 2cSj4R5OqN0 belongs to topics: [6]
# Video 2cXlM4qr8Lw belongs to topics: [10]
# Video 2DIqmd6yQBY belongs to topics: [3]
# Video 2Emt_xXktmI belongs to topics: [4]
# Video 2FHnLyeuvt0 belongs to topics: [13]
# Video 2ftG8JuMzz4 belongs to topics: [0, 2]
# Video 2g3Gu9cA_AU belongs to topics: [6, 14]
# Video 2G4w9gH8iEs belongs to topics: [6, 14]
# Video 2g63ty8ySoM belongs to topics: [4]
# Video 2gDO3w-Zv5Q belongs to topics: [10]
# Video 2HpGUdqGwdc belongs to topics: [3, 13]
# Video 2IhEU5rzUOE belongs to topics: [0, 5]
# Video 2iPplpNHjTQ belongs to topics: [14]
# Video 2JF7m9fNMBo belongs to topics: [9, 14]
# Video 2j_1TomiT9Q belongs to topics: [6, 10]
# Video 2l94S4_jMTY belongs to topics: [0, 10]
# Video 2lXdrSXl9Io belongs to topics: [0, 13]
# Video 2MJvug6QOgA belongs to topics: [0, 13]
# Video 2n67uXYSG5c belongs to topics: [6, 14]
# Video 2ncOVB0wTtc belongs to topics: [7, 14]
# Video 2pGWzr7QXtU belongs to topics: [7]
# Video 2Pn0MNwUjM0 belongs to topics: [8, 14]
# Video 2qgmxrekr0g belongs to topics: [7, 14]
# Video 2qqc_Mx3zuI belongs to topics: [0, 7]
# Video 2S4TBBvNJ7E belongs to topics: [8]
# Video 2S5dxNFf9zM belongs to topics: [4, 14]
# Video 2shoun41cW0 belongs to topics: [0]
# Video 2sZh5FtJRb8 belongs to topics: [0]
# Video 2TETrMU1Q3I belongs to topics: [8, 14]
# Video 2TkGKRUcH9M belongs to topics: [1, 14]
# Video 2TmagN6RhkI belongs to topics: [6]
# Video 2xD1WA0YVUE belongs to topics: [3]
# Video 2xLHVJNTjn4 belongs to topics: [7, 14]
# Video 2Y5LjRWFfkk belongs to topics: [0, 1, 14]
# Video 30f7VYKKd2s belongs to topics: [8, 14]
# Video 32nRdJOPP-4 belongs to topics: [10]
# Video 33Q14vlsZqo belongs to topics: [6]
# Video 344HnNjBD2Y belongs to topics: [14]
# Video 36NXapTl4Ts belongs to topics: [5]
# Video 3aoRaEgunEQ belongs to topics: [0, 3]
# Video 3B3unElpNwQ belongs to topics: [0, 14]
# Video 3b6lSIIqnUs belongs to topics: [12, 14]
# Video 3DJpy-yikrc belongs to topics: [10]
# Video 3DUQ5TCoQyk belongs to topics: [14]
# Video 3F0lW3HehjE belongs to topics: [0]
# Video 3GfHcEvWfIo belongs to topics: [7, 14]
# Video 3GkauoR2xgE belongs to topics: [7, 9]
# Video 3gXTOa6Zskw belongs to topics: [9, 14]
# Video 3hc7N_uOHdw belongs to topics: [2, 7]
# Video 3kftPeWMvLk belongs to topics: [7]
# Video 3ksZkJHTlOc belongs to topics: [1, 8]
# Video 3lO1tIs9IJc belongs to topics: [0]
# Video 3Lz2ntvDBFQ belongs to topics: [14]
# Video 3n1nspLgfd4 belongs to topics: [14]
# Video 3NHSsHi3h0M belongs to topics: [12]
# Video 3oTOIi8ysLo belongs to topics: [14]
# Video 3PKGOy6PoiQ belongs to topics: [8]
# Video 3QFkmOO9Tl8 belongs to topics: [0]
# Video 3rKffuFJYNk belongs to topics: [3]
# Video 3rRNKYvoDsQ belongs to topics: [2, 8]
# Video 3sNSRgq-4l8 belongs to topics: [9]
# Video 3sVrbsvXWQ0 belongs to topics: [7, 14]
# Video 3TxugOC8su0 belongs to topics: [0, 12]
# Video 3uEH8rj5cw8 belongs to topics: [8]
# Video 3uOf_FMbW54 belongs to topics: [14]
# Video 3vouclvykqE belongs to topics: [9]
# Video 3Wh8qKGc5K0 belongs to topics: [14]
# Video 3WQWPlvNZIo belongs to topics: [8, 14]
# Video 3xy9jS1KwvY belongs to topics: [0, 14]
# Video 3y0EwY-WGBQ belongs to topics: [0]
# Video 3_ms_C3ElA0 belongs to topics: [8]
# Video 401ZvQ11euA belongs to topics: [9, 14]
# Video 41WyfyapTw0 belongs to topics: [6]
# Video 42sibaGVjY8 belongs to topics: [0, 12]
# Video 42t6Jk4JXrA belongs to topics: [8]
# Video 45nukMR5A_c belongs to topics: [8]
# Video 479RSxJ3Ml4 belongs to topics: [0]
# Video 4ABk0y_RA9s belongs to topics: [0]
# Video 4AKZqHFjidg belongs to topics: [14]
# Video 4cCKve0dl3Y belongs to topics: [10]
# Video 4crqlin_s-I belongs to topics: [14]
# Video 4DEqwJI-vdg belongs to topics: [7]
# Video 4giM0wycDw8 belongs to topics: [9, 14]
# Video 4gjvGsxiTw0 belongs to topics: [10]
# Video 4gZVxxSeAn0 belongs to topics: [6, 10]
# Video 4JyhBkXMymo belongs to topics: [0, 9]
# Video 4j_8rEyYEXw belongs to topics: [0]
# Video 4kXOQ2NOkxY belongs to topics: [12]
# Video 4l2eIDF9HZA belongs to topics: [0, 12]
# Video 4OiOwDh5lKE belongs to topics: [0, 1, 7]
# Video 4OSt6WQ2K8A belongs to topics: [8, 14]
# Video 4OzEgHVD5PA belongs to topics: [0, 14]
# Video 4QJa07djrLY belongs to topics: [8, 12]
# Video 4QMHfDx_LpM belongs to topics: [14]
# Video 4RRAgEb5r7Q belongs to topics: [0]
# Video 4SOtYIJpO3w belongs to topics: [14]
# Video 4TcUHcCj6To belongs to topics: [0]
# Video 4uooe-9JKLI belongs to topics: [0, 3, 5]
# Video 4WQ17A_DBWs belongs to topics: [1]
# Video 4YxAhOFHLxs belongs to topics: [0, 3]
# Video 4ZlCwZj90Jk belongs to topics: [14]
# Video 4zzhCbQE5iQ belongs to topics: [0]
# Video 5-9kuktuMAY belongs to topics: [6, 14]
# Video 56_MEV8ClLg belongs to topics: [8]
# Video 57TY0y5zpe0 belongs to topics: [6, 10, 13]
# Video 58UzixzNCh4 belongs to topics: [8, 10]
# Video 5ABdJMdZX_s belongs to topics: [0, 13]
# Video 5AxdLyBlvhw belongs to topics: [6, 14]
# Video 5coE3hlNJ3I belongs to topics: [9, 14]
# Video 5dOG_pW1mk8 belongs to topics: [8, 12]
# Video 5eoPZMtIUBw belongs to topics: [7]
# Video 5FDFwEO5ErM belongs to topics: [9, 14]
# Video 5JAvzI-ZP14 belongs to topics: [6]
# Video 5Khf5QBf0ss belongs to topics: [10]
# Video 5KQH4Xvco4c belongs to topics: [2, 14]
# Video 5LW1VDVgr6k belongs to topics: [8]
# Video 5mlZPHOKh60 belongs to topics: [8]
# Video 5N6hNyg43IY belongs to topics: [6]
# Video 5OsH70IAD1A belongs to topics: [14]
# Video 5oZQfIs_-8s belongs to topics: [0]
# Video 5PT1wLx87UE belongs to topics: [0, 12]
# Video 5rRwJuCdNDo belongs to topics: [9, 14]
# Video 5seK3IKQZDw belongs to topics: [5]
# Video 5ux5BrTZwXM belongs to topics: [7, 14]
# Video 5VUN3h-yq6M belongs to topics: [10]
# Video 5VXiVRQIFLs belongs to topics: [7]
# Video 5wuUNfOBBjc belongs to topics: [13]
# Video 5XCy01h0N3w belongs to topics: [9, 14]
# Video 5xVeZrpVzow belongs to topics: [13]
# Video 60RF_6NQQu8 belongs to topics: [1, 10, 12]
# Video 61AVQo4qIYg belongs to topics: [6, 8]
# Video 675kMpNG0L8 belongs to topics: [5]
# Video 67n-hrCYiSI belongs to topics: [9]
# Video 69CZQlrfkkU belongs to topics: [9]
# Video 6br0dqmMfPo belongs to topics: [6, 14]
# Video 6BZm8EvZXpQ belongs to topics: [13]
# Video 6BzWXEy4t14 belongs to topics: [9, 14]
# Video 6DFsY_QS7Ag belongs to topics: [10]
# Video 6ftiWoCJ4dM belongs to topics: [0, 14]
# Video 6gCEl31uiE8 belongs to topics: [9, 12, 14]
# Video 6hIu5oIB9n0 belongs to topics: [3, 12]
# Video 6Jwm242qZzg belongs to topics: [3]
# Video 6Ko-j7nzMHg belongs to topics: [8]
# Video 6lZVXJlqN7s belongs to topics: [10]
# Video 6m57KaHerG0 belongs to topics: [8]
# Video 6MGjjWLbhD0 belongs to topics: [6, 13]
# Video 6Mhtr5yE-kc belongs to topics: [1, 10, 14]
# Video 6ndkOSiGOe4 belongs to topics: [14]
# Video 6p6ZYZ4vHE4 belongs to topics: [3, 8]
# Video 6RpKEGaChbg belongs to topics: [6, 14]
# Video 6sECozSy7FY belongs to topics: [0]
# Video 6SqnPdh85fw belongs to topics: [0, 1, 8]
# Video 6tHy-Kie0GY belongs to topics: [0]
# Video 6TiMvS0rE2I belongs to topics: [14]
# Video 6v04kR5QDOA belongs to topics: [8]
# Video 6VBPJGD2d7w belongs to topics: [0, 12]
# Video 6wA8OMptkio belongs to topics: [1]
# Video 6XyGH06X2aY belongs to topics: [0, 6, 14]
# Video 6ZxnCsOKDww belongs to topics: [9, 14]
# Video 72FTaFoM3Dk belongs to topics: [9]
# Video 736F9UPGb_k belongs to topics: [14]
# Video 736HThq9YRM belongs to topics: [0]
# Video 74Fz4onYqGY belongs to topics: [0]
# Video 77jBJ2oe7e0 belongs to topics: [5, 7]
# Video 79p57XNf8Os belongs to topics: [6]
# Video 7agexPKirHQ belongs to topics: [5, 14]
# Video 7Bd3IWiuVgE belongs to topics: [0, 5]
# Video 7Cj6-Vn8h8o belongs to topics: [14]
# Video 7DbQ0qmSrIc belongs to topics: [8]
# Video 7DkmB-btFfY belongs to topics: [0, 9]
# Video 7G38mOd4or8 belongs to topics: [13]
# Video 7i9At3fld3Q belongs to topics: [8]
# Video 7jDrzdX2Ucc belongs to topics: [9, 10]
# Video 7kE0sj0R8mE belongs to topics: [0]
# Video 7ngJLi9cgYs belongs to topics: [8, 14]
# Video 7NMm60VwNnU belongs to topics: [2, 8]
# Video 7ObTYEQRcBs belongs to topics: [1]
# Video 7OnrK3EmFa4 belongs to topics: [14]
# Video 7pD0XOWc5nU belongs to topics: [10, 14]
# Video 7rNoNprvS4U belongs to topics: [8]
# Video 7t1CKyKrfSU belongs to topics: [14]
# Video 7WCTTAGYN5Y belongs to topics: [0]
# Video 7WQdBSWfixI belongs to topics: [0]
# Video 7XPHGhEZF2A belongs to topics: [5]
# Video 7y6lHFHRrM0 belongs to topics: [9, 14]
# Video 7yEFkxss_i8 belongs to topics: [9, 14]
# Video 7zaMbzqj8AI belongs to topics: [10, 14]
# Video 7zNSjbWBo90 belongs to topics: [0, 11]
# Video 7_hNGE5sn-g belongs to topics: [0]
# Video 80GF1BTv-4w belongs to topics: [14]
# Video 80oICq8QAew belongs to topics: [10]
# Video 81u4_4_-ABg belongs to topics: [14]
# Video 82dNxf_pWFE belongs to topics: [14]
# Video 86gs985X5tU belongs to topics: [0, 13]
# Video 87If-Q2pJWQ belongs to topics: [0]
# Video 87q34iZbUXM belongs to topics: [10]
# Video 8a1Hsah_yuA belongs to topics: [9]
# Video 8AoRrFwRcZc belongs to topics: [2, 3, 7]
# Video 8aV0SxSbzvY belongs to topics: [14]
# Video 8d8tfV1uBn4 belongs to topics: [0, 2]
# Video 8DMKzuGsBao belongs to topics: [0]
# Video 8DYPxsr7kDI belongs to topics: [8, 14]
# Video 8f0-OcYW5zA belongs to topics: [8]
# Video 8G6-h5XFgbM belongs to topics: [0, 9]
# Video 8HG8lmI2Dyg belongs to topics: [13]
# Video 8kcD3vk12AY belongs to topics: [5]
# Video 8KIMFLiprXo belongs to topics: [0]
# Video 8KSP_ZW76QE belongs to topics: [12]
# Video 8mPk9KW_5XE belongs to topics: [7]
# Video 8MWkMwNAZHo belongs to topics: [14]
# Video 8N8jgfmZQOo belongs to topics: [2]
# Video 8nuQJvVQR8Y belongs to topics: [6, 14]
# Video 8nYDDMN3JlA belongs to topics: [6]
# Video 8P9QdIHT3sk belongs to topics: [8]
# Video 8qCqpy2emLk belongs to topics: [10, 14]
# Video 8Rg0U7RW1ww belongs to topics: [7, 14]
# Video 8shGtApcXNU belongs to topics: [10]
# Video 8UQB5t_euOI belongs to topics: [0]
# Video 8w-X-NU-p9U belongs to topics: [10]
# Video 8WOHRXf1sj0 belongs to topics: [0, 7]
# Video 8xdch6aTDAg belongs to topics: [14]
# Video 8XMh30agFpk belongs to topics: [2, 8]
# Video 8X_d-IVydP4 belongs to topics: [8]
# Video 8zDbtAfmokY belongs to topics: [11]
# Video 8Zw4O3ZXdfQ belongs to topics: [8]
# Video 8_A_aV_PjYE belongs to topics: [10, 13]
# Video 92rUJQFLbnI belongs to topics: [0, 8]
# Video 97mkEBhvnNU belongs to topics: [10, 14]
# Video 9au-Wi7_rS0 belongs to topics: [0, 5]
# Video 9BH-FsQS_Y8 belongs to topics: [1, 14]
# Video 9BIzz1Fqhgk belongs to topics: [1]
# Video 9bW4p2CvkNY belongs to topics: [9]
# Video 9E0_8KPvOt0 belongs to topics: [5, 14]
# Video 9eeejXbcOa4 belongs to topics: [0, 13]
# Video 9GckZ7AmgNw belongs to topics: [3]
# Video 9H891iA0xGk belongs to topics: [5, 14]
# Video 9hWiKgR22YQ belongs to topics: [12, 14]
# Video 9iinyVgYTu8 belongs to topics: [8]
# Video 9IiRJUesFNk belongs to topics: [0, 14]
# Video 9Iuafbk1eBE belongs to topics: [0]
# Video 9jTY_F3I8OI belongs to topics: [14]
# Video 9mC5dqQohKI belongs to topics: [6, 14]
# Video 9mR4asD1Rw4 belongs to topics: [14]
# Video 9nbuNLU2S-U belongs to topics: [0]
# Video 9pyrNSKb16Y belongs to topics: [9, 14]
# Video 9Q5NLLmgCFw belongs to topics: [10]
# Video 9Qlof7jPQpg belongs to topics: [2, 8]
# Video 9sAZ50a_l5M belongs to topics: [2, 8]
# Video 9SXB-fOg9Qg belongs to topics: [0, 9]
# Video 9t6PWAbylh4 belongs to topics: [8]
# Video 9vYMByRngU8 belongs to topics: [0, 10]
# Video 9XZDbjG2Hf8 belongs to topics: [13]
# Video 9zoaiIkFwiI belongs to topics: [0, 2]
# Video 9_7UvrHiy6k belongs to topics: [10]
# Video 9_Iu3w6DVyQ belongs to topics: [0, 13]
# Video A-qi6EZGJgM belongs to topics: [14]
# Video A08KjPeqgl4 belongs to topics: [0, 1]
# Video a1g3kt4XLfo belongs to topics: [0]
# Video a1jF-AokfCQ belongs to topics: [12]
# Video a1Pd3XPaAuE belongs to topics: [0]
# Video A1tEA4AGJIE belongs to topics: [8]
# Video A2bdBzrRHfs belongs to topics: [7, 14]
# Video A2_vSVmLeQs belongs to topics: [8]
# Video A54fT5PWTIc belongs to topics: [0]
# Video A6jYxNYpT5A belongs to topics: [2, 8]
# Video a9PyRuEJlbM belongs to topics: [7]
# Video aA8hpFdp8rk belongs to topics: [5, 7, 8]
# Video aBBKBpmtfTU belongs to topics: [10, 14]
# Video Abq7F6HGIX8 belongs to topics: [0, 7]
# Video ABUx5euD2vk belongs to topics: [12, 14]
# Video aDAR65Fcp7E belongs to topics: [2]
# Video Ae9RLvFXChQ belongs to topics: [14]
# Video AEp-JC1jHvw belongs to topics: [0, 13]
# Video AeQZH56GWiA belongs to topics: [6, 12]
# Video agJmf_4RkHQ belongs to topics: [7]
# Video AI7Us_5-IaQ belongs to topics: [1, 8]
# Video AinyNd4rv2I belongs to topics: [6]
# Video AIVU8Rg7Jpo belongs to topics: [8]
# Video AJ1dWqy_rws belongs to topics: [1, 3]
# Video aJ3H99d41l0 belongs to topics: [0]
# Video aj6yPs9Z5sc belongs to topics: [0, 7]
# Video aj7o4FXVsFE belongs to topics: [7, 14]
# Video AJF7cjAgZ9M belongs to topics: [0]
# Video aKAUrBBUfhU belongs to topics: [0]
# Video AKjlkab1YRo belongs to topics: [14]
# Video Al7xFwszHQM belongs to topics: [0, 2]
# Video Alm47PX09ho belongs to topics: [2]
# Video Am22VdC_3qk belongs to topics: [14]
# Video AmgEFzgnvP4 belongs to topics: [5]
# Video AMjJd3fnND0 belongs to topics: [14]
# Video anOwLiXRa5w belongs to topics: [14]
# Video ANpbL70-1VI belongs to topics: [0]
# Video anSOkTr4ugk belongs to topics: [9, 14]
# Video aNTEtfr81E4 belongs to topics: [6]
# Video AoCEIX9sHYk belongs to topics: [0]
# Video aPgwD05HHKE belongs to topics: [6]
# Video AQBE65iSM-E belongs to topics: [6]
# Video AqT2DLoO7Gs belongs to topics: [6]
# Video AQtTuTZyNiA belongs to topics: [6, 9, 14]
# Video aRhLGffqjgk belongs to topics: [10]
# Video ARMdb7fgfQU belongs to topics: [0]
# Video ARnFU7iPCa0 belongs to topics: [4, 6]
# Video asVHaM9QXzQ belongs to topics: [0]
# Video aTiISTBaLkg belongs to topics: [14]
# Video atMwIFVnrnk belongs to topics: [9, 14]
# Video ATurpKuYqg4 belongs to topics: [5, 9]
# Video AUMItA0qvqw belongs to topics: [14]
# Video AV8WgtQu6JE belongs to topics: [0, 5]
# Video AVRltPV1VQE belongs to topics: [0]
# Video avVOKbL4dpI belongs to topics: [9]
# Video aW1C2JvSSHg belongs to topics: [8, 12]
# Video AwD4OYyEOUA belongs to topics: [6]
# Video AwWl2LwQ2-c belongs to topics: [0, 9, 14]
# Video AxJ1YGnc1nY belongs to topics: [0, 13]
# Video AY57GEPf2DQ belongs to topics: [9]
# Video aYJ0w1ZQfYg belongs to topics: [14]
# Video AYr7y-JfhN8 belongs to topics: [0, 3]
# Video aYxT9tCrADc belongs to topics: [8]
# Video AyZZUJGMrio belongs to topics: [11, 14]
# Video A_HLtsg4TVA belongs to topics: [0, 7]
# Video a_nHmORJuW0 belongs to topics: [14]
# Video B-Ux7ehmojs belongs to topics: [10, 14]
# Video b0Sd5upIc6o belongs to topics: [8, 14]
# Video b21dwnHHSig belongs to topics: [7]
# Video b4lIezLc0ZY belongs to topics: [0]
# Video B5gs2MyCiRY belongs to topics: [1, 7]
# Video b5tDEbQggXM belongs to topics: [0, 2]
# Video B7bX5AlQu6c belongs to topics: [8]
# Video B7Rz5IHjXWc belongs to topics: [8, 14]
# Video B7SbnMo9r5Q belongs to topics: [7]
# Video B8d7D1Idinw belongs to topics: [0]
# Video B8Ra9V5Novs belongs to topics: [8]
# Video b9oguyK0IPQ belongs to topics: [1, 8]
# Video B9UfnHQWJZc belongs to topics: [6]
# Video baIR7eMg5Ug belongs to topics: [0, 13]
# Video bAn0qP3BHcI belongs to topics: [2, 8, 14]
# Video BaxCa7M2I_s belongs to topics: [12, 14]
# Video BbfRMeClL5M belongs to topics: [14]
# Video bbkUGFFjX_c belongs to topics: [0, 14]
# Video BboemeR1PcA belongs to topics: [6]
# Video bC0eqpysh-k belongs to topics: [6, 14]
# Video BcNZNEZvU84 belongs to topics: [0]
# Video BD2RRl7wPMw belongs to topics: [6, 10]
# Video bDhhBLga2I0 belongs to topics: [0]
# Video bfn9tndD9iM belongs to topics: [0, 3]
# Video Bfr7zkTXL9A belongs to topics: [9]
# Video BfyuKROBWyE belongs to topics: [0]
# Video BgC1dsQDFRU belongs to topics: [1]
# Video bGpXVxq_7iU belongs to topics: [0, 10, 13]
# Video BHR9ht4QVuM belongs to topics: [0, 11]
# Video bH_TiXuz5ng belongs to topics: [1, 12, 14]
# Video bi__9Vzhnc4 belongs to topics: [2]
# Video bj4tLSZnIqM belongs to topics: [0, 2]
# Video BjaKfnWjX9Y belongs to topics: [14]
# Video bJHVULK8pAs belongs to topics: [13]
# Video bKCr62Dk7Us belongs to topics: [0]
# Video BKi1QTM3Rto belongs to topics: [5, 13, 14]
# Video bkjKixwujk0 belongs to topics: [8]
# Video bksKSfElfX0 belongs to topics: [14]
# Video BMCKKkbhQpc belongs to topics: [14]
# Video BnxSe7m6CKo belongs to topics: [5, 6]
# Video bPmYS3LC01w belongs to topics: [0]
# Video BppgvPJZMlA belongs to topics: [8, 14]
# Video bQBVLIkzcrw belongs to topics: [0]
# Video bqO6iZcLrv4 belongs to topics: [2, 8]
# Video BROKaSugx-Q belongs to topics: [14]
# Video bsTb5vMw1dQ belongs to topics: [2]
# Video Bta_XWrA5lA belongs to topics: [14]
# Video BtcnosuTnTQ belongs to topics: [0, 5]
# Video btEYK52Dwsc belongs to topics: [9, 14]
# Video BTkkdlCE-7c belongs to topics: [0]
# Video bTLMJvuPbZc belongs to topics: [0, 3]
# Video BUCANbJ9rZs belongs to topics: [0, 7]
# Video BulWyYdhpFE belongs to topics: [8]
# Video Bv0XZHD98ss belongs to topics: [0, 5]
# Video BvIL0PWj5_A belongs to topics: [8]
# Video BWCUwXAEaPk belongs to topics: [9]
# Video bwQ1ifGRKGY belongs to topics: [6, 14]
# Video BXfleP_adiQ belongs to topics: [0]
# Video BXSZVp68G_M belongs to topics: [0, 13]
# Video bxU3BHbt4ZY belongs to topics: [1, 2, 3]
# Video BYqGB4NyzDI belongs to topics: [0, 7]
# Video BZA1TUcHa4k belongs to topics: [0]
# Video BZNzNVKim6w belongs to topics: [5]
# Video B_h7W5zTbnk belongs to topics: [8]
# Video c-fijV9L28k belongs to topics: [0]
# Video c0_yjwProzU belongs to topics: [0, 8]
# Video c12zRnFUTdo belongs to topics: [0]
# Video c185R3zpFQk belongs to topics: [9, 14]
# Video C1EwhDGdv14 belongs to topics: [6]
# Video C1ME3ETxuls belongs to topics: [5]
# Video c4kMjhSt73k belongs to topics: [10, 14]
# Video c64OjV9lNvw belongs to topics: [0]
# Video C7JiTweF3xY belongs to topics: [14]
# Video C8O7aUkka4o belongs to topics: [11, 14]
# Video cANij8_TIdI belongs to topics: [0, 7]
# Video cApYOQViXbo belongs to topics: [1, 8, 12]
# Video cARc1t-KsqU belongs to topics: [1, 14]
# Video CBmNk9pSsy4 belongs to topics: [13, 14]
# Video cBXHIQdKWBM belongs to topics: [9, 14]
# Video cCGGFF_fq8k belongs to topics: [0, 3]
# Video cDa3rn2haL4 belongs to topics: [6]
# Video cDaBzBo6JOU belongs to topics: [0, 8]
# Video cDfcwMk03SU belongs to topics: [7]
# Video CEfyMNrHkMs belongs to topics: [8]
# Video cENNaC4LkC8 belongs to topics: [9]
# Video Cf3Xnr120c0 belongs to topics: [5, 10]
# Video CfCIaFiJPBs belongs to topics: [1]
# Video cfgd4erLBL4 belongs to topics: [13]
# Video cFSIBImwMR0 belongs to topics: [2, 12]
# Video cFWKWEGIiOc belongs to topics: [7, 10]
# Video cgCt4TRvrmo belongs to topics: [7]
# Video cgnBQ9qOqmY belongs to topics: [14]
# Video cHc0025eF_4 belongs to topics: [10]
# Video CI8PSPP9vlE belongs to topics: [14]
# Video ciBt2cteN-U belongs to topics: [8, 14]
# Video CIvsSPNAzGg belongs to topics: [8]
# Video CIzI1u5i8B8 belongs to topics: [2, 14]
# Video cjOMiFsjCvY belongs to topics: [4]
# Video CKPXaDT-8ps belongs to topics: [2]
# Video CksMrhlgIc0 belongs to topics: [2, 8, 14]
# Video cLWymhJnwts belongs to topics: [4]
# Video cm2oIEkmbGk belongs to topics: [14]
# Video cm4yNGTlQOw belongs to topics: [3]
# Video cm9m-gyMlXs belongs to topics: [14]
# Video cMfqUT8RW80 belongs to topics: [1, 2]
# Video cMKx2sNhyfo belongs to topics: [8]
# Video cmv5gtLAWPM belongs to topics: [9]
# Video cNJDwmEiie8 belongs to topics: [0]
# Video CO418oACsEk belongs to topics: [0]
# Video coayhixmBBk belongs to topics: [8, 14]
# Video coIXi26Ktk8 belongs to topics: [10]
# Video COMqkO_Q_X4 belongs to topics: [10, 13]
# Video CoqKIUMLLCY belongs to topics: [9, 14]
# Video cp0wyuBU7Oc belongs to topics: [0]
# Video cPeu09bCPwA belongs to topics: [0]
# Video CQ0T7YZI2BM belongs to topics: [1]
# Video CQ5YPzimHiw belongs to topics: [9, 14]
# Video cQdlPyDBHcw belongs to topics: [7]
# Video cRop2TQOFOw belongs to topics: [6]
# Video Ct9V0Tca4go belongs to topics: [9]
# Video CUlbqob5Njg belongs to topics: [0]
# Video CuLmlHo7Wrk belongs to topics: [11]
# Video cUsVaMMdicc belongs to topics: [8]
# Video CvGutuE0Klg belongs to topics: [7]
# Video cVkJ6Qn5JNI belongs to topics: [14]
# Video CVx_BaMGkZk belongs to topics: [10]
# Video cwklx0IhAxs belongs to topics: [10, 14]
# Video cwxu2dA5Dv4 belongs to topics: [0]
# Video CXDbQA56OQU belongs to topics: [14]
# Video CxVeCZTZQGQ belongs to topics: [10]
# Video cYDdNL_rF9A belongs to topics: [8]
# Video cz2xBnhjY6U belongs to topics: [5, 14]
# Video C_CGOd61JFM belongs to topics: [9, 14]
# Video C__iyWJkjgc belongs to topics: [0, 12]
# Video d-GbnwI0jcs belongs to topics: [2, 9, 14]
# Video d17jz3qfKUg belongs to topics: [14]
# Video d2I4jSEAHyc belongs to topics: [7]
# Video D31_n-pcFTo belongs to topics: [0, 13]
# Video d3dRw-098OQ belongs to topics: [6, 8]
# Video d51Kl8fdOPg belongs to topics: [0]
# Video D5fEwumpUj8 belongs to topics: [13, 14]
# Video d8Pm0p-g23k belongs to topics: [6, 7, 10]
# Video d9KaWtyIqYg belongs to topics: [9, 14]
# Video DA9_bU3NGbk belongs to topics: [0]
# Video datYaDOz2R8 belongs to topics: [3, 14]
# Video dbdGpkHLx9Y belongs to topics: [8]
# Video DBpt9uDRdsY belongs to topics: [8, 10, 13]
# Video DCpP4sxcDXw belongs to topics: [1]
# Video dD3jQhawZ7g belongs to topics: [2, 9]
# Video DEJ_ma-gvsM belongs to topics: [8]
# Video DERY5U0IUAI belongs to topics: [0]
# Video dFB91YBhoYY belongs to topics: [8, 14]
# Video DFbN0VZLWKQ belongs to topics: [6, 10, 14]
# Video DFWtrZTfyAg belongs to topics: [14]
# Video DFX3IvmoO18 belongs to topics: [10]
# Video DG-ZLIbE4Xs belongs to topics: [3, 11]
# Video dGIZPdLOYQ8 belongs to topics: [1, 14]
# Video dGM9kDXdWcQ belongs to topics: [14]
# Video dGxnilrs8aU belongs to topics: [4]
# Video DHNrVmGb_Us belongs to topics: [0]
# Video DhpouIFVLIU belongs to topics: [0]
# Video DiYTTHUchMc belongs to topics: [9]
# Video DJNNrntBTjQ belongs to topics: [4, 14]
# Video DjUfn_34WjY belongs to topics: [10]
# Video dkd_72evovo belongs to topics: [6]
# Video Dl8-_rRDfgE belongs to topics: [8, 9]
# Video DlgVulo8lAA belongs to topics: [0, 11]
# Video dlHS2kdmxNE belongs to topics: [14]
# Video DliuTxsLJ1g belongs to topics: [6, 7, 14]
# Video DNCsUcracsY belongs to topics: [1, 9]
# Video dnvb9MRVJd4 belongs to topics: [0]
# Video doapxNsSkrY belongs to topics: [10, 14]
# Video DrGY4BXhxGc belongs to topics: [0, 13]
# Video dRidbogoKLo belongs to topics: [0, 13]
# Video DRVaUJy89tQ belongs to topics: [10]
# Video dshX0csKCoE belongs to topics: [10]
# Video dSpW5Xc180Q belongs to topics: [0, 14]
# Video dSqIcdng1hM belongs to topics: [8, 12]
# Video DTcQGJh0vSQ belongs to topics: [1]
# Video dtzX0da4h9k belongs to topics: [7, 13, 14]
# Video DT_R3PqXKi8 belongs to topics: [7]
# Video DuK3sXMBbGo belongs to topics: [13, 14]
# Video DUxM2nWpz5A belongs to topics: [2]
# Video DvHDwXBVXoc belongs to topics: [2, 8]
# Video dVWiQDALCoY belongs to topics: [2, 14]
# Video dVYCpiIzIKQ belongs to topics: [2, 14]
# Video dWhyFfsb74g belongs to topics: [10]
# Video DwqWeMOkaPU belongs to topics: [0, 1]
# Video Dxcj73yBJus belongs to topics: [2, 4]
# Video DyLgj2-1T9I belongs to topics: [6]
# Video DYrwSmgq9Xc belongs to topics: [2, 7]
# Video dyzpn_ggo3g belongs to topics: [0]
# Video dZdOnCkA988 belongs to topics: [3]
# Video dzg9C7KsP4M belongs to topics: [0, 5]
# Video d_pI6qPlizQ belongs to topics: [8, 10]
# Video E0_OqkMMWaU belongs to topics: [10]
# Video E1b2T_ar1tU belongs to topics: [14]
# Video e2W9UaVhsX0 belongs to topics: [14]
# Video E2ytEt7JoMM belongs to topics: [3]
# Video E35_9w4SyWk belongs to topics: [3, 9]
# Video e5mAUbRosCY belongs to topics: [14]
# Video E6iIgJEMXec belongs to topics: [7, 14]
# Video e7eggKProwI belongs to topics: [3, 9]
# Video e8d-RyhSehM belongs to topics: [0, 3]
# Video E9DVdojR_DM belongs to topics: [6, 12]
# Video E9sRk8dmC1c belongs to topics: [0, 3, 4]
# Video ebQ6Ev1-4rc belongs to topics: [14]
# Video eB_2R_Pockc belongs to topics: [0, 10]
# Video ECPGO9m7ALc belongs to topics: [8]
# Video ecv6X5ZWGnQ belongs to topics: [11]
# Video ED9vNES6L9o belongs to topics: [12, 14]
# Video EesEuIeDRQg belongs to topics: [2, 3, 8]
# Video EF5hPPSj5ik belongs to topics: [0]
# Video eFgpfgkhalM belongs to topics: [6]
# Video EhjwtOwsfCQ belongs to topics: [0]
# Video EhM_vQTe6dg belongs to topics: [4, 8]
# Video EhUq2lQGSLE belongs to topics: [8, 12]
# Video EI5eZb5zYXc belongs to topics: [0]
# Video EIFjXZ4E9Yk belongs to topics: [0, 5]
# Video eiP4XJAsrLY belongs to topics: [0, 13]
# Video EjIfBv8ZNts belongs to topics: [0]
# Video EJJZLKmWH6A belongs to topics: [13, 14]
# Video ejnZYVzPPLw belongs to topics: [4, 14]
# Video eJukunJZDU8 belongs to topics: [0, 2]
# Video EKNuv99XeCA belongs to topics: [6]
# Video eKPzWxJ4nKI belongs to topics: [14]
# Video emt2OKarVZM belongs to topics: [1, 14]
# Video Eo4HBgsItcU belongs to topics: [0, 5]
# Video eOyIpRJqw20 belongs to topics: [8]
# Video EQEVdaDUkJs belongs to topics: [6]
# Video eQgF7_x5fmY belongs to topics: [0]
# Video eqqVFOvtOcs belongs to topics: [2]
# Video erI3UulSmSw belongs to topics: [0]
# Video erOy91eDW5w belongs to topics: [0, 9]
# Video eRq_6dNf7cc belongs to topics: [12, 14]
# Video ETQScTYYQRU belongs to topics: [6, 10]
# Video eTx-r4ZI0Q0 belongs to topics: [0]
# Video EUkFRzflw20 belongs to topics: [0, 2]
# Video eUmMxxACvLU belongs to topics: [10, 14]
# Video EUnaQzzjaas belongs to topics: [3, 14]
# Video EUscV0NKT5A belongs to topics: [5]
# Video ev6GL49Qcgo belongs to topics: [9]
# Video evTFGDVlQ4s belongs to topics: [13, 14]
# Video EW_xym12SoY belongs to topics: [0]
# Video exB--zv3N4U belongs to topics: [8]
# Video eyqPUI8wKdc belongs to topics: [3]
# Video eyydfWC9N_w belongs to topics: [8, 10]
# Video EzkKTRyNnRk belongs to topics: [2]
# Video ezYVlu1hx_k belongs to topics: [8]
# Video f0PA-yr-OHo belongs to topics: [0]
# Video f0rq_-Wupeg belongs to topics: [12, 14]
# Video F4A56Fm9eLY belongs to topics: [0, 5]
# Video f4AsvKY-wBk belongs to topics: [9]
# Video F59W77FEm8c belongs to topics: [2, 14]
# Video f5fD_oFGdzU belongs to topics: [0]
# Video F5yCChwGHzM belongs to topics: [0, 2]
# Video f6UXRBaKPU0 belongs to topics: [0]
# Video f706f6KNCEM belongs to topics: [3]
# Video F9z7b9ei2Lg belongs to topics: [5]
# Video fA0m-LaA_7c belongs to topics: [0]
# Video FA8H_7DPkb0 belongs to topics: [6]
# Video fBVhdswz8Is belongs to topics: [0]
# Video FBWBu3LOz4k belongs to topics: [0]
# Video fChooDx5q-s belongs to topics: [1, 8]
# Video fD8CxHFngFk belongs to topics: [1]
# Video FEIgBk9fJCM belongs to topics: [0]
# Video fFsR_vs4_sE belongs to topics: [14]
# Video fg-aZiawDDI belongs to topics: [0, 14]
# Video FgHt-nEd_e0 belongs to topics: [3, 6]
# Video fGHZBpxJkrw belongs to topics: [10, 14]
# Video FHWph0x6D2o belongs to topics: [12, 14]
# Video fi-1XRsB_CM belongs to topics: [10]
# Video fI6f3sGZmz0 belongs to topics: [12]
# Video Fi8gTif6kpE belongs to topics: [10]
# Video firToZ3-2uk belongs to topics: [6]
# Video fi_yKfF-VWs belongs to topics: [2, 14]
# Video fJJgE8K2u2w belongs to topics: [0, 5]
# Video fJZ0IQQBOvw belongs to topics: [14]
# Video FkBRtBZhNyc belongs to topics: [7, 8]
# Video FKeHVxJdXVg belongs to topics: [7]
# Video FKH-4n-D9jc belongs to topics: [0]
# Video fkOld9v1k9c belongs to topics: [1, 12]
# Video fKW8cSIw50A belongs to topics: [0]
# Video Fl-SivJGwiU belongs to topics: [0]
# Video FlEz4gs_LUA belongs to topics: [0, 13]
# Video FlrYASSTeqc belongs to topics: [10]
# Video fLuv234IqaI belongs to topics: [0]
# Video FmdpQzURvDQ belongs to topics: [5]
# Video fMvXX6sYPp0 belongs to topics: [0]
# Video FO6mvnRPbZk belongs to topics: [10]
# Video Foa5W5bVUEQ belongs to topics: [0]
# Video fOE4NCgK4DI belongs to topics: [3, 6]
# Video fp19JCP2pCs belongs to topics: [0, 8]
# Video FqxdJ7XPB7U belongs to topics: [8]
# Video FQXl6SFVZs8 belongs to topics: [7]
# Video Fr9KGPq93Fw belongs to topics: [0, 7]
# Video frFCKsWidu8 belongs to topics: [0, 11]
# Video fSExytZS5Qo belongs to topics: [3]
# Video FsFKueX-BL0 belongs to topics: [5, 9]
# Video FTimsLaPV_Q belongs to topics: [8]
# Video ftwXLK-RYvQ belongs to topics: [6]
# Video fujA6IeNcZA belongs to topics: [14]
# Video FUMnwUjs0BI belongs to topics: [14]
# Video FUNVx1HqOKY belongs to topics: [14]
# Video Fvs5JlRVEGE belongs to topics: [10, 13]
# Video fvzcwqQtk4I belongs to topics: [0]
# Video fVZqyIJNmbg belongs to topics: [0]
# Video fwBAEa4VFUc belongs to topics: [2, 7, 14]
# Video FwtwO6lf2aA belongs to topics: [9, 14]
# Video Fw_AW_gWl5o belongs to topics: [3, 14]
# Video fXg9Ybo0P-M belongs to topics: [8]
# Video FXnVfuiMQjg belongs to topics: [14]
# Video FxyNnhXSHmM belongs to topics: [8, 10]
# Video fYEtozCbX-g belongs to topics: [13, 14]
# Video FyUl4XfJw1c belongs to topics: [8, 14]
# Video fZ4XAWBDpFc belongs to topics: [12, 14]
# Video F_Qdk9bD-a4 belongs to topics: [1, 7]
# Video f_zPPqUdWCg belongs to topics: [14]
# Video G19tOR4S2fM belongs to topics: [8, 14]
# Video g2QVIR2UGyM belongs to topics: [6, 10, 14]
# Video G2WlfS4ixYU belongs to topics: [8]
# Video G44IUjZ1vOw belongs to topics: [0, 2, 7]
# Video g5ADP70RX5I belongs to topics: [12]
# Video g7H5W79J3fc belongs to topics: [9, 10, 14]
# Video G8-Jhb9UhWw belongs to topics: [9]
# Video g9lf5YyB4Nc belongs to topics: [10]
# Video G9wo06s2yec belongs to topics: [7]
# Video GAsowcnp9Es belongs to topics: [12]
# Video gC4nON-snQM belongs to topics: [7, 8]
# Video gca99X5zCuE belongs to topics: [8]
# Video gcjP_DqdA28 belongs to topics: [2]
# Video gCq3LL5YKc0 belongs to topics: [14]
# Video GCrIWEB4bcc belongs to topics: [0]
# Video GDdvwefLXWY belongs to topics: [0]
# Video gdpF56G4_mo belongs to topics: [0, 6, 9]
# Video gEdn370z8Qg belongs to topics: [7, 8, 14]
# Video ge_Aax3qguI belongs to topics: [14]
# Video gFOYVZiyCXA belongs to topics: [0]
# Video gGlQ3dPGLOg belongs to topics: [8]
# Video GH4gd0X9K_E belongs to topics: [4, 8]
# Video GHOWbGqY2r4 belongs to topics: [14]
# Video giuIZyBvR78 belongs to topics: [11, 13]
# Video gJ9rEQGJBF4 belongs to topics: [0]
# Video GJNDPuy7ER8 belongs to topics: [9]
# Video GjVBD9OYzOo belongs to topics: [14]
# Video Gj_HrXrNUYc belongs to topics: [8]
# Video Gl2RpA1xS6M belongs to topics: [7, 10]
# Video glHqnIsRB9o belongs to topics: [6, 10, 14]
# Video GLmdX92Z-GE belongs to topics: [0, 10]
# Video gneWTTqkMb0 belongs to topics: [14]
# Video GNlbItng_RE belongs to topics: [0, 13]
# Video gnYEDeL-jys belongs to topics: [0]
# Video gOLEdV2Ry64 belongs to topics: [14]
# Video GOnvVafj31k belongs to topics: [7]
# Video gQU_GTWKHyA belongs to topics: [6]
# Video GqyT13H6sws belongs to topics: [9]
# Video GR8etyMA6-Q belongs to topics: [5]
# Video GtBth3A_C9A belongs to topics: [2, 7]
# Video gtmx2uDj6lA belongs to topics: [2, 8]
# Video gu3UXQ57Ixc belongs to topics: [0, 13]
# Video Gv0s9AJHG0M belongs to topics: [1, 14]
# Video GVTBdnW7Gck belongs to topics: [1, 8, 9]
# Video gXm5OrH8lAA belongs to topics: [9]
# Video Gy-8lssJcYU belongs to topics: [8]
# Video GYEAvNO1afo belongs to topics: [3]
# Video gYW5By-VDYs belongs to topics: [0]
# Video GZT76v0h46A belongs to topics: [0]
# Video G_4kOyEUek8 belongs to topics: [0, 13]
# Video G_WEK9DAR9I belongs to topics: [1, 9]
# Video H-xGGNYjv4U belongs to topics: [0, 8]
# Video h0_SUfJyUNE belongs to topics: [0]
# Video h1C0BhDX_J0 belongs to topics: [0, 5]
# Video h4Az7Vp2d5c belongs to topics: [8]
# Video H4tGheX1GWE belongs to topics: [0, 7]
# Video H8FCZSOqzds belongs to topics: [0]
# Video H8qLpIt_Bqs belongs to topics: [0]
# Video H8yvD6Rgz44 belongs to topics: [13, 14]
# Video H9DCKJwUnWA belongs to topics: [12]
# Video H9yhYBQYqh8 belongs to topics: [5, 14]
# Video Hb6ZBFuM3fU belongs to topics: [0]
# Video Hbms3mmZWL4 belongs to topics: [14]
# Video HBqFfthfJCU belongs to topics: [7]
# Video HByXqP7uy00 belongs to topics: [14]
# Video HcRh8IrwbCA belongs to topics: [0, 13]
# Video HDb52NrpSyE belongs to topics: [9, 14]
# Video hdo7ZFTK4ZE belongs to topics: [0]
# Video hDqk1d-s-0s belongs to topics: [0, 11]
# Video HfJjo_Y9miA belongs to topics: [13]
# Video hFTeMAm_-SY belongs to topics: [1]
# Video hgulTvzsAHk belongs to topics: [12, 14]
# Video hGycDlUAM5w belongs to topics: [9]
# Video hh2IkTHssl8 belongs to topics: [13]
# Video hHBhgilEpYo belongs to topics: [0]
# Video HhJ-j_Y2-fo belongs to topics: [0, 2]
# Video HHOAg9XyA70 belongs to topics: [0]
# Video HjElH_pDbU8 belongs to topics: [2, 14]
# Video hjfRy74D8os belongs to topics: [0, 2]
# Video HkRKi7_Iywc belongs to topics: [14]
# Video HL1UJYugSA8 belongs to topics: [8, 12]
# Video HLcnwnJMgd8 belongs to topics: [14]
# Video HOCAYxtfSks belongs to topics: [3]
# Video HOk3y5y__TQ belongs to topics: [0]
# Video hp6WBMNS9p8 belongs to topics: [14]
# Video HpUD_FjHI8I belongs to topics: [9]
# Video hp_gdBK2_y0 belongs to topics: [14]
# Video hqSAIh6wLSg belongs to topics: [0, 8]
# Video hrECwxk0Tvo belongs to topics: [5, 7]
# Video ht-EU_RWPg0 belongs to topics: [13]
# Video HUaC1mVw7oA belongs to topics: [0, 5, 8]
# Video HUk622Y1qX8 belongs to topics: [8]
# Video hUogazKVhDQ belongs to topics: [10]
# Video HuwWfuiI30I belongs to topics: [8]
# Video hWIMspWuVEI belongs to topics: [8, 14]
# Video hWUdgZbOD6o belongs to topics: [0]
# Video hWw6Ua4wyMs belongs to topics: [9]
# Video hwxmHRrlMwY belongs to topics: [0, 13]
# Video hXSsMzaopZo belongs to topics: [14]
# Video hyaQkvX-gOs belongs to topics: [0, 10]
# Video HYwBHEIfj_U belongs to topics: [10]
# Video I-7MaQTYhV8 belongs to topics: [12]
# Video i-jUGRMh3vQ belongs to topics: [0, 2]
# Video I-vJ_fSA9Wg belongs to topics: [0]
# Video I-z3hDWHZoU belongs to topics: [9, 14]
# Video i0AjtpI81xs belongs to topics: [2]
# Video I10c2BUazL4 belongs to topics: [0]
# Video i2ivLsfmFoQ belongs to topics: [0, 3]
# Video I37aQmrLwiQ belongs to topics: [0, 3]
# Video I3jdiRTbiRI belongs to topics: [6, 14]
# Video i3jJKdIw3ms belongs to topics: [8]
# Video i3Y9xl9ckWU belongs to topics: [7]
# Video I5PDOjBfC3A belongs to topics: [8]
# Video I5SKFXqR9r8 belongs to topics: [12, 14]
# Video I6Fi22hxITM belongs to topics: [2, 9]
# Video I6qSF2tKdkI belongs to topics: [9, 14]
# Video I71Fpu_mmcg belongs to topics: [8]
# Video i73vBiLo2PA belongs to topics: [0, 5]
# Video I8McPt1ux9U belongs to topics: [3, 14]
# Video I8q2eutBoXk belongs to topics: [14]
# Video i8qS2r4Mws0 belongs to topics: [0]
# Video i9vGQ0kx-fQ belongs to topics: [8]
# Video IaEj2mNTg3o belongs to topics: [8, 14]
# Video IaOE08wtI2o belongs to topics: [13, 14]
# Video Ib2Y0kt_6Ok belongs to topics: [2, 3]
# Video iC2Q4euQZws belongs to topics: [0]
# Video iCCuWDTfYY8 belongs to topics: [8]
# Video Idmu78v5TeE belongs to topics: [8, 10, 14]
# Video iDTQDzqoWyk belongs to topics: [8]
# Video IdUZHc7nqnE belongs to topics: [0, 7]
# Video iDXYFRX5RP4 belongs to topics: [1, 8]
# Video ifLKnE2WgPE belongs to topics: [0]
# Video igKebYBEP14 belongs to topics: [10]
# Video IGROEaoT7zY belongs to topics: [8, 9]
# Video igSoZvr7lnw belongs to topics: [3, 9]
# Video iha3y_Oj_-o belongs to topics: [10, 14]
# Video ihEQOF8_SXs belongs to topics: [0, 10]
# Video IhnioRvjlAU belongs to topics: [2]
# Video iHQ2lhGvL7Y belongs to topics: [9, 14]
# Video iHyEzFFHD1g belongs to topics: [0]
# Video IiCfEzRvUIQ belongs to topics: [0, 6]
# Video iii3w48jeJU belongs to topics: [0]
# Video IindYQBGmRQ belongs to topics: [1, 8]
# Video IIxlljazVf8 belongs to topics: [0, 5]
# Video Ij7d7wZ5qqc belongs to topics: [5, 7]
# Video IkeDmcu8-2o belongs to topics: [1, 2, 14]
# Video Ikm4UITCSKA belongs to topics: [0, 13]
# Video ikODCYiD1FE belongs to topics: [8, 10]
# Video IkSQHSccOrw belongs to topics: [14]
# Video IkusGn6DhGo belongs to topics: [6]
# Video ilvgg0xoqXg belongs to topics: [0]
# Video iM43LN5gdgs belongs to topics: [13]
# Video im9_1MMzw3c belongs to topics: [14]
# Video ImeZpAX1RIA belongs to topics: [0]
# Video IN2S_grP2ZE belongs to topics: [9, 14]
# Video InHXOZbufdw belongs to topics: [2]
# Video InP5_mgUUfE belongs to topics: [8]
# Video IoFKtGYM6I0 belongs to topics: [0]
# Video iOIgLr2nxbg belongs to topics: [1, 9]
# Video IsgC81D2O8w belongs to topics: [11]
# Video ISmQJQJxxPs belongs to topics: [6, 14]
# Video iSRAQkTwCzw belongs to topics: [2, 5]
# Video it4RYgwYIDg belongs to topics: [3]
# Video iTeW0PTPEwE belongs to topics: [0, 12]
# Video ItLm-3J2bX8 belongs to topics: [0, 2, 3]
# Video IuRDt2Wvo5o belongs to topics: [5]
# Video Ivn4-GzrETM belongs to topics: [3, 10]
# Video iWMyjfgyCYU belongs to topics: [8, 9, 14]
# Video ix3pRU76vIc belongs to topics: [0, 12]
# Video iXd277VEQuI belongs to topics: [1]
# Video IxD2NbXzgpQ belongs to topics: [0, 5]
# Video IZA1t7vmai4 belongs to topics: [6, 10]
# Video IzAW6O5YWBU belongs to topics: [1, 8]
# Video j1knOWYwnMM belongs to topics: [10]
# Video j2YWXAqzmX4 belongs to topics: [13]
# Video J4dz7tiXNEc belongs to topics: [5, 14]
# Video J4H-0ue4gXk belongs to topics: [0, 3]
# Video j4pBIs30HQc belongs to topics: [1]
# Video j4yx3NvLEH0 belongs to topics: [14]
# Video J5LWi9sqvQk belongs to topics: [10]
# Video j5wy6RXVVCY belongs to topics: [14]
# Video j69a0yB08gs belongs to topics: [4]
# Video j75LDK7JDSs belongs to topics: [0, 7]
# Video j7HlJ4Nm-4Y belongs to topics: [0]
# Video J7IGbrXZEZI belongs to topics: [6, 14]
# Video j7u0a_WH7hQ belongs to topics: [14]
# Video Ja2nNDd9fjg belongs to topics: [2]
# Video jahAi_wkHAs belongs to topics: [14]
# Video jB3WygJ47A0 belongs to topics: [5]
# Video jbdN_Uwuosc belongs to topics: [0]
# Video Jc2hb8-rcrY belongs to topics: [0, 13]
# Video jC86fVeUeZA belongs to topics: [10]
# Video jDtgVcVUTVs belongs to topics: [0]
# Video Jf2tNIE-IHE belongs to topics: [0, 10]
# Video JFzRQ3TqhPs belongs to topics: [10]
# Video jgSxogFcp3U belongs to topics: [10]
# Video jI23S-mYYeg belongs to topics: [0]
# Video JiBsFTdOs1Y belongs to topics: [6]
# Video jiQ7Grr33oA belongs to topics: [0]
# Video jJaymuewPYw belongs to topics: [3]
# Video JJcY3gQsBu4 belongs to topics: [9, 12, 14]
# Video jJyZzmYeHiQ belongs to topics: [4]
# Video JKBWGVoPbRY belongs to topics: [8]
# Video JlrWlTMAqr0 belongs to topics: [9, 10]
# Video JM14c0yL29I belongs to topics: [12, 14]
# Video jMLdbmElS8w belongs to topics: [6, 7]
# Video jmntzm5yBYY belongs to topics: [0, 7]
# Video jNh9sBsYgss belongs to topics: [6, 14]
# Video JNUQ72ZHlZs belongs to topics: [6, 8]
# Video joeAUU_Gwko belongs to topics: [2, 7]
# Video jOwLMt8-WQs belongs to topics: [0, 12]
# Video JpbO1V9XuVg belongs to topics: [6, 10, 14]
# Video jpBpQKazIsk belongs to topics: [5]
# Video jPUSclSyUiQ belongs to topics: [1]
# Video JQ-eZkZC5nA belongs to topics: [6, 12]
# Video jQaxzqZztNM belongs to topics: [0]
# Video jqKQfexB7To belongs to topics: [8]
# Video JQpjfWV_p6E belongs to topics: [9]
# Video jqrEYX5MMks belongs to topics: [0]
# Video jQSa-RVxOGw belongs to topics: [14]
# Video jrppaG01-F0 belongs to topics: [0]
# Video jrzvf28SgyA belongs to topics: [1, 8]
# Video JRzVGCUDuC0 belongs to topics: [0, 2, 14]
# Video jSVt-jwgQ1U belongs to topics: [12, 13]
# Video Jsz4MSGM-08 belongs to topics: [9]
# Video JT5AVuqTeaE belongs to topics: [2, 8]
# Video jTPe32FwjEI belongs to topics: [14]
# Video JUcqMXi38So belongs to topics: [7]
# Video jUL1cRzKQlE belongs to topics: [8]
# Video jumDvsiJ9BI belongs to topics: [14]
# Video jVtWRVmMVGg belongs to topics: [1]
# Video jw7ykAwVGH0 belongs to topics: [10]
# Video JwIeegXNZ9c belongs to topics: [14]
# Video JXxBmfyw6Xc belongs to topics: [8]
# Video jxZgccTWzcg belongs to topics: [12, 14]
# Video jyNFfoeQkDc belongs to topics: [14]
# Video JyuDpnjCK_U belongs to topics: [8, 14]
# Video jyWS46pHtdA belongs to topics: [2, 7]
# Video JZIEfgYvQio belongs to topics: [0]
# Video jZn35O_ja4Q belongs to topics: [7]
# Video JZnvP1MWBlk belongs to topics: [10]
# Video J_BQmskzXDk belongs to topics: [0, 7]
# Video j_G9pHUL-wY belongs to topics: [0]
# Video K-mSi0GNWN8 belongs to topics: [14]
# Video K-W7_RY8d4M belongs to topics: [7, 9]
# Video K05mhgf0Lj4 belongs to topics: [0]
# Video K0FmdB8uGKA belongs to topics: [5, 9]
# Video K4BnzGb1FGQ belongs to topics: [5]
# Video k4cn8eVRCDo belongs to topics: [1, 14]
# Video k4VbpUl8U9I belongs to topics: [7, 8]
# Video k5iXUMHPXb8 belongs to topics: [0]
# Video k5To-PlW3C4 belongs to topics: [14]
# Video K6dZW1V3-FU belongs to topics: [0, 5]
# Video K9h7xBf9uzA belongs to topics: [10, 14]
# Video K9Tfe4x_wro belongs to topics: [9, 14]
# Video K9_kfYsDQgw belongs to topics: [0, 5]
# Video kAsWumwTUjQ belongs to topics: [0]
# Video KAWBqgvlhfo belongs to topics: [14]
# Video KBckeRChNT4 belongs to topics: [0, 5]
# Video kBRmepdDuGk belongs to topics: [2, 12]
# Video kceHa2XteNs belongs to topics: [0]
# Video kcUTnM5Flpg belongs to topics: [8, 14]
# Video KD2wKZfqlZU belongs to topics: [1, 14]
# Video kd3VpvLtCdo belongs to topics: [10]
# Video kdQjdQUFzBo belongs to topics: [1, 8]
# Video kEdhl7xNluM belongs to topics: [0]
# Video KelcDGzQRKg belongs to topics: [1]
# Video KewTOAuam4s belongs to topics: [0, 3]
# Video kFBwyWHgkXg belongs to topics: [10]
# Video KG2lonDcGCU belongs to topics: [3]
# Video KG5Ov18N26U belongs to topics: [5, 14]
# Video kgG1oJiE5qs belongs to topics: [10, 14]
# Video Kgr7qGU_sJw belongs to topics: [3, 14]
# Video kIbd4DORB-8 belongs to topics: [8, 14]
# Video kImXctXCmLs belongs to topics: [11, 14]
# Video KIrpiNTl1qo belongs to topics: [5]
# Video KJrmE8BNCuM belongs to topics: [0]
# Video Kk4YL2CZGPI belongs to topics: [0, 11]
# Video kkiNTet5G-Q belongs to topics: [14]
# Video kL1xAYUTx2o belongs to topics: [0]
# Video klMo0d2-VOs belongs to topics: [10]
# Video klx-_N0XMEY belongs to topics: [0]
# Video KmWoT5FmtTk belongs to topics: [0, 7]
# Video konXumXsoFE belongs to topics: [6, 10, 14]
# Video KPOFO1kxckg belongs to topics: [0, 14]
# Video KPU07Ee_j_Y belongs to topics: [1]
# Video kq2oO7fRbB4 belongs to topics: [14]
# Video KqItPSo7R58 belongs to topics: [0]
# Video KrbZE3SL1vU belongs to topics: [1]
# Video KRj2QZgUqlU belongs to topics: [5, 8, 14]
# Video ks8kkvFdD0A belongs to topics: [1]
# Video KSrS_KmFcmM belongs to topics: [7]
# Video kssJ-jhOFPA belongs to topics: [2]
# Video KTBkJEkTicw belongs to topics: [0, 7]
# Video kTrjYBGGol0 belongs to topics: [0]
# Video KUinzmCRI3k belongs to topics: [6]
# Video kupDrmKBW4w belongs to topics: [10]
# Video kv7cn2yuUCc belongs to topics: [14]
# Video kVfqhcWspQw belongs to topics: [0, 14]
# Video KWEY2yJfy_E belongs to topics: [13]
# Video kWRYJ4P1h-A belongs to topics: [1]
# Video KwTtV2ZJZ7U belongs to topics: [10, 14]
# Video kWXTPmPd_gk belongs to topics: [14]
# Video kXPQK-Gxkl8 belongs to topics: [7]
# Video kYTUmK8f52A belongs to topics: [14]
# Video kz8L5quDgYU belongs to topics: [0]
# Video l-lPCxX7ySg belongs to topics: [3]
# Video l0eB8kD2EHY belongs to topics: [0, 5]
# Video l37i8s1uUx0 belongs to topics: [6]
# Video l4EuyIXEFoQ belongs to topics: [14]
# Video l5K-jH6FWcQ belongs to topics: [2, 8]
# Video L79qy1_s3Ak belongs to topics: [0]
# Video l9hIJpOP5Fo belongs to topics: [2, 8]
# Video LA8U3Lqr3b0 belongs to topics: [0, 6]
# Video LAfchScmbVY belongs to topics: [0, 3]
# Video LB20skQI1_k belongs to topics: [13]
# Video LCPdReRvd00 belongs to topics: [10]
# Video LCpmr8NTkzQ belongs to topics: [1, 8]
# Video LcsTba_KQXM belongs to topics: [0, 3, 7]
# Video lDkAhaR_cyA belongs to topics: [8, 13]
# Video LdqzS4LW4aI belongs to topics: [6, 14]
# Video LEF7IUO1crU belongs to topics: [1]
# Video LFkSktRSJpM belongs to topics: [14]
# Video LfPx5Ygzr9A belongs to topics: [2, 14]
# Video lfq08YKgIDE belongs to topics: [8, 14]
# Video lG54jwwvTrc belongs to topics: [0]
# Video lGlWteaA0G4 belongs to topics: [0, 7]
# Video lH-ebkL3l9w belongs to topics: [5]
# Video lHdUFJCkAfQ belongs to topics: [5]
# Video LhNm4ygDueQ belongs to topics: [3, 10]
# Video lkJ2Zj82u4g belongs to topics: [1]
# Video lLQcFpgbMOk belongs to topics: [0]
# Video Lm3Z-ZnXsws belongs to topics: [0]
# Video LmBtqFkvIn0 belongs to topics: [0, 12]
# Video lmisnxYQvhg belongs to topics: [0, 7]
# Video lmrf2EjUVa0 belongs to topics: [0, 7]
# Video LNin1zdtACc belongs to topics: [0, 3]
# Video lNndYqSObXs belongs to topics: [0]
# Video LNtFTq32huA belongs to topics: [0]
# Video LP7b--mUOtQ belongs to topics: [9]
# Video lPCnUCvh-pg belongs to topics: [1, 8]
# Video Lqznip8oO9M belongs to topics: [0, 2, 7]
# Video lQ_4IeSVUrQ belongs to topics: [0]
# Video LRt24SRWmrs belongs to topics: [5, 14]
# Video LsCHNOZ3htY belongs to topics: [14]
# Video LsFTrq6vAus belongs to topics: [0]
# Video lSNCL4_9PRQ belongs to topics: [9]
# Video LTonXvxR7wg belongs to topics: [0, 14]
# Video LtrL-cCzoNo belongs to topics: [14]
# Video LtXiRN0P2VY belongs to topics: [10]
# Video LU3dP_VdymQ belongs to topics: [1, 8]
# Video lUm0atjqE28 belongs to topics: [2, 8, 14]
# Video lUy-hP3V-1o belongs to topics: [0, 7]
# Video lvaLXUyP_OA belongs to topics: [14]
# Video LVaz4TG41r8 belongs to topics: [0, 3]
# Video LVFIaiY5x9w belongs to topics: [8]
# Video LVxfqOe3MFE belongs to topics: [10]
# Video lw0W4iSHbaw belongs to topics: [0]
# Video lx21W-OILMA belongs to topics: [0, 9]
# Video LyiAFZFC0NI belongs to topics: [8, 12]
# Video lylnNLNNcbA belongs to topics: [6, 10]
# Video lyoIryqJ08A belongs to topics: [0, 7]
# Video L_h9HRJ79-E belongs to topics: [0, 7]
# Video m-s5vnq0n-w belongs to topics: [9, 10]
# Video M071g-kdsrs belongs to topics: [8]
# Video M0lKXfyJh-I belongs to topics: [0, 12]
# Video m1tQXkTN47Y belongs to topics: [8, 12]
# Video M1_FZDANQWI belongs to topics: [0, 10]
# Video M2Cf7-JpIUo belongs to topics: [1, 7, 14]
# Video m42_YBQeQ7w belongs to topics: [4, 10]
# Video M6PeY_lZJk0 belongs to topics: [0]
# Video M7nAZgyp9I0 belongs to topics: [0, 1, 14]
# Video M8MG_3YB3b8 belongs to topics: [5, 6, 14]
# Video M9C3dF4FjpQ belongs to topics: [2]
# Video M9tx5tggT-k belongs to topics: [7, 14]
# Video mBFUFsBtQX8 belongs to topics: [4, 14]
# Video mBqdFmLnKCE belongs to topics: [0, 7]
# Video MBtWxCM7NYg belongs to topics: [1, 9]
# Video mCGanrWZeu0 belongs to topics: [6, 14]
# Video mCGXIuMuMkM belongs to topics: [3, 13, 14]
# Video mcWEmkXF4ik belongs to topics: [3]
# Video MdRI-Yy1jkY belongs to topics: [7]
# Video mD_eFV8Igr8 belongs to topics: [14]
# Video MEDamnVjgXI belongs to topics: [8]
# Video mEGowrcIw9E belongs to topics: [14]
# Video mE_u_aqJxMU belongs to topics: [5, 9]
# Video mF98At7oSY4 belongs to topics: [3, 5]
# Video MfftS_h6sNQ belongs to topics: [9]
# Video MGSnNfM2Suw belongs to topics: [0]
# Video mgwJt140qFI belongs to topics: [11, 14]
# Video mHSzgYb-6iI belongs to topics: [3, 14]
# Video mIghkGjG3oI belongs to topics: [9]
# Video MIiVqUYh_eo belongs to topics: [0, 2]
# Video mIWo9H1wfc4 belongs to topics: [10]
# Video mJECT0x7ick belongs to topics: [5]
# Video MjL05yopUzw belongs to topics: [12]
# Video mjZXOo365-E belongs to topics: [2, 8]
# Video mKa-PucSqdY belongs to topics: [6, 14]
# Video MKBogPOM3Ao belongs to topics: [0]
# Video MKgOWgUwTrU belongs to topics: [0]
# Video MlGE038jc4k belongs to topics: [8]
# Video MLQ2ZT_v7WI belongs to topics: [6]
# Video Mm2I5N5xfes belongs to topics: [3, 14]
# Video MMOR5h6gS8s belongs to topics: [6]
# Video MNtJxjc0Agc belongs to topics: [2, 14]
# Video MovIpxxyOlo belongs to topics: [0, 4]
# Video MoWue2YAvJE belongs to topics: [14]
# ...
# Video UkwwzJwcwJE belongs to topics: [7]
# Video ulGmdV_1Zyc belongs to topics: [0, 14]
# Video ULuet4N8eoU belongs to topics: [1]
# Video Um5Ps_krL7I belongs to topics: [0, 12]
# Video UM72FFHja04 belongs to topics: [2]
# Video um8hZrjflRA belongs to topics: [6]
# Video UmYskm92Zpo belongs to topics: [7, 8]
# Video uNCO4gPu3C0 belongs to topics: [0]
# Video UNfq6ITddXI belongs to topics: [3, 13]
# Video unnmgu4MUWA belongs to topics: [9]
# Video uOzvJDk6ZiQ belongs to topics: [13]
# Video uphWgpwpxT0 belongs to topics: [0, 7]
# Video uq1trByhmfc belongs to topics: [0, 11]
# Video UTHUma6LUjA belongs to topics: [8]
# Video uTPpdi5OIig belongs to topics: [9]
# Video uvh2XtMN9W8 belongs to topics: [7]
# Video uWBzWoEpZt8 belongs to topics: [2, 8, 13]
# Video uWdQxpfwWs4 belongs to topics: [8]
# Video Ux-54H76Deo belongs to topics: [2, 7]
# Video UXBd8hvKHzA belongs to topics: [3]
# Video Uxfu4ZEy7X0 belongs to topics: [7, 8]
# Video uXjQAtBEuds belongs to topics: [12, 14]
# Video UXPqbMZG5ts belongs to topics: [14]
# Video UxRTmlmTlp8 belongs to topics: [14]
# Video UxskTdzfIlI belongs to topics: [0]
# Video Uz80mFnPR1w belongs to topics: [10]
# Video uZo00oLFS0s belongs to topics: [14]
# Video UzrtzYFkCyI belongs to topics: [6]
# Video UZXyOudgYpE belongs to topics: [7]
# Video V-r2M6E4iDM belongs to topics: [8]
# Video V0gH56RlhPQ belongs to topics: [1]
# Video v2DFIQl3JjQ belongs to topics: [7, 14]
# Video v2vBaW9CmRw belongs to topics: [0]
# Video V3t0eCwBv5U belongs to topics: [7, 8]
# Video V3TCTZuCGy4 belongs to topics: [0, 14]
# Video v4EwZ2B05qM belongs to topics: [0, 10]
# Video v5AZyo6G2eE belongs to topics: [13, 14]
# Video v8RYbc8PvuY belongs to topics: [8, 14]
# Video VA36h1gjHg8 belongs to topics: [12, 14]
# Video VbOmWcb5_B0 belongs to topics: [0, 1]
# Video VBpyfBGjHJQ belongs to topics: [0]
# Video VccHOpKy06Q belongs to topics: [2, 7]
# Video VD5E8E_6jPk belongs to topics: [8]
# Video VD5u8UqW_WI belongs to topics: [14]
# Video vDyDvo-4tg0 belongs to topics: [6]
# Video vE-aYCxIRaQ belongs to topics: [0]
# Video ve-gGv0VjDM belongs to topics: [0, 5]
# Video Ve2u-FIEzgY belongs to topics: [14]
# Video vfsJ9M74ZP4 belongs to topics: [0]
# Video vge15YEaLbk belongs to topics: [1, 13]
# Video vGj44tTlVIs belongs to topics: [9, 14]
# Video VIBpeTBlF4c belongs to topics: [0]
# Video ViKahoBCRcw belongs to topics: [5, 14]
# Video vjg1AXumXR4 belongs to topics: [3, 10]
# Video vJs4hZVbcEs belongs to topics: [10]
# Video vJTj_7fLTzM belongs to topics: [7]
# Video vk7_uI-V_9I belongs to topics: [9, 12]
# Video vl0HKxs2Q6k belongs to topics: [0]
# Video VlDzJIgBk4w belongs to topics: [2, 3]
# Video vlXUmXkTaCs belongs to topics: [0]
# Video VMCjnPNXoM8 belongs to topics: [0, 3]
# Video VmO94k6De_k belongs to topics: [0, 5]
# Video voJl8cH8Zpo belongs to topics: [10]
# Video volmZv1dva8 belongs to topics: [0]
# Video VoUdWRHkDwA belongs to topics: [8]
# Video vpGYmk0kg1E belongs to topics: [0, 13]
# Video VPrX23ORDaQ belongs to topics: [7]
# Video VRswO3n1d40 belongs to topics: [0]
# Video vrwkd3W1lD0 belongs to topics: [0]
# Video VS8CzcfvUVw belongs to topics: [7, 14]
# Video vSJ-MNUKzVU belongs to topics: [0]
# Video vT0d85_9n30 belongs to topics: [0]
# Video vuQqCtkpOTc belongs to topics: [6]
# Video VVh-iUfdHQs belongs to topics: [7]
# Video VW1fCBRUBYk belongs to topics: [1]
# Video vwIIeiOhTJ0 belongs to topics: [1, 14]
# Video VwWCkl-CglI belongs to topics: [6]
# Video vwwKin-TBRk belongs to topics: [6, 12]
# Video Vx0TqLbcVpc belongs to topics: [10]
# Video VX3AgEC1JJ0 belongs to topics: [3, 5]
# Video vyezxhPOZsg belongs to topics: [9, 14]
# Video VYMSkjeA0qg belongs to topics: [14]
# Video vzcfL9C9TEg belongs to topics: [9, 14]
# Video vZMYvrUw8jc belongs to topics: [2]
# Video vzSmLYoOMc0 belongs to topics: [10]
# Video W-ADbqq6ZQA belongs to topics: [14]
# Video w-uejeoxpLg belongs to topics: [8, 14]
# Video w01-9uhP6qk belongs to topics: [14]
# Video w0J2LGBV6-I belongs to topics: [8]
# Video w3XLgvayYFs belongs to topics: [10, 14]
# Video w46Fslwmujo belongs to topics: [0, 13]
# Video W6OXvnrq5fA belongs to topics: [5]
# Video W7I3qmSf9NI belongs to topics: [5]
# Video w8GdDhQDvsM belongs to topics: [10]
# Video W9a4a1WXAuM belongs to topics: [0, 12]
# Video W9OyX8n8cRk belongs to topics: [3, 8]
# Video wa9nSRu9bA0 belongs to topics: [0, 14]
# Video WaDHQ4QHRdI belongs to topics: [1, 14]
# Video wax0d3rTiJU belongs to topics: [8]
# Video wB-NrGhIW6s belongs to topics: [0]
# Video WbRUmB0fkX4 belongs to topics: [8]
# Video WCsNRqG0PIM belongs to topics: [0, 8, 14]
# Video wDqIA8MYXYI belongs to topics: [9]
# Video wDtgH88TpmU belongs to topics: [5, 14]
# Video wfch_D1JahM belongs to topics: [8]
# Video Wfjhdicwj60 belongs to topics: [10]
# Video wGyBP1ec3Kc belongs to topics: [8]
# Video wHGYz9tbcEw belongs to topics: [0, 7]
# Video WHl8KIkWauY belongs to topics: [14]
# Video whOVT9bgvg8 belongs to topics: [0]
# Video whQvP6x2yMY belongs to topics: [3, 8]
# Video WI-TR7Ljjas belongs to topics: [0]
# Video wi2JR9vZvm4 belongs to topics: [5, 14]
# Video wira2nf3DFo belongs to topics: [0]
# Video WiwntzOmL8s belongs to topics: [2, 14]
# Video wiZfB517o3I belongs to topics: [0, 14]
# Video wkBlLJhebX0 belongs to topics: [0]
# Video wKlxcr-judM belongs to topics: [14]
# Video WkRpk4bxUIc belongs to topics: [0]
# Video WL89vihzjjk belongs to topics: [0, 5, 13]
# Video WMR0eH5kM6I belongs to topics: [0]
# Video Wmthd_tHH8E belongs to topics: [7]
# Video wMW_Uk9M5CY belongs to topics: [0, 13]
# Video Wnc6d-DQpNs belongs to topics: [14]
# Video WnlivU5fYD4 belongs to topics: [3, 9]
# Video wNoxFXUQqWc belongs to topics: [12, 14]
# Video wOI7I95Oxsg belongs to topics: [14]
# Video WPimWiBBrVY belongs to topics: [0]
# Video wpnWOgl3MVc belongs to topics: [5]
# Video WpTu2EmNRJI belongs to topics: [0]
# Video wQlPhqtjSVg belongs to topics: [0]
# Video Wr1PRU25AE0 belongs to topics: [8, 14]
# Video WRHwXkLghAQ belongs to topics: [0]
# Video Wrlx37DRrrs belongs to topics: [11]
# Video WS8eYFLtwSY belongs to topics: [6]
# Video Wst4kBA9jnQ belongs to topics: [4, 11]
# Video WtunSqKWMcY belongs to topics: [14]
# Video wtutMF2rOqA belongs to topics: [3]
# Video WUfRtk1F6ps belongs to topics: [0, 7]
# Video wv0dKyMn3HA belongs to topics: [3]
# Video WWyZKkQecY4 belongs to topics: [10]
# Video Wx-K2LXrxxM belongs to topics: [0, 5]
# Video WX0t13vt5h4 belongs to topics: [0]
# Video wx3uGOoKJRc belongs to topics: [0]
# Video WxudL917gkA belongs to topics: [5]
# Video wYK5yOptg9g belongs to topics: [14]
# Video Wyu0OCB7dn4 belongs to topics: [0]
# Video X0y3NKQwTUs belongs to topics: [0, 14]
# Video X3csbe8mZnY belongs to topics: [9, 14]
# Video X3LS5ja0sqk belongs to topics: [2, 14]
# Video x5BPfHKtH_Q belongs to topics: [2, 14]
# Video X6qNGn3QxTU belongs to topics: [8, 14]
# Video x7djETYCzu0 belongs to topics: [14]
# Video X7QwsSVQKD4 belongs to topics: [6]
# Video X8n3RZ9pjYo belongs to topics: [14]
# Video x9ONPpzEytw belongs to topics: [9]
# Video XAWlVODAJ5s belongs to topics: [12]
# Video xayG_VtzUIE belongs to topics: [1, 10]
# Video XCnOh8Vp4fA belongs to topics: [8]
# Video xdD7iQ6sEK4 belongs to topics: [0, 7]
# Video XdmzMZkk0co belongs to topics: [8]
# Video xedLjMIRRRE belongs to topics: [0, 8]
# Video XF3-hRlrfNQ belongs to topics: [0]
# Video XfHV3FHwMI8 belongs to topics: [0, 7]
# Video Xfz_kglF6ZU belongs to topics: [0, 6]
# Video Xg7V4R6oiNg belongs to topics: [14]
# Video xg98i7oWINE belongs to topics: [14]
# Video XHgxISMPs5M belongs to topics: [0, 2]
# Video xHrqHulxK7c belongs to topics: [5]
# Video XI0AsIl2bZ0 belongs to topics: [1, 8]
# Video XiAeP_bcYvk belongs to topics: [0, 12]
# Video xid2dKmJKbU belongs to topics: [2, 5]
# Video xiMoenxcnbU belongs to topics: [6, 14]
# Video Xiy9sQRt6Lw belongs to topics: [14]
# Video XJDPP26KS_o belongs to topics: [0, 4]
# Video xJqJLaox2Yw belongs to topics: [8]
# Video xkNjdS5myEk belongs to topics: [0, 3]
# Video xKOsZCpCVm4 belongs to topics: [14]
# Video xLbvAdzxmhY belongs to topics: [8]
# Video XMfnDnulMLo belongs to topics: [0]
# Video xmJ8TmUtpdg belongs to topics: [6]
# Video XMPOW5DS71Q belongs to topics: [0, 6, 13]
# Video xN-bsk3LZ0I belongs to topics: [5, 14]
# Video xNhBvveK9rM belongs to topics: [10]
# Video XOwJsnCILhw belongs to topics: [0]
# Video xq6cedD4-eo belongs to topics: [3, 13]
# Video xrKtvEh2wO8 belongs to topics: [2, 6, 14]
# Video xSDlst1c67U belongs to topics: [0, 11]
# Video XUqomp-z5T8 belongs to topics: [10]
# Video XvUxJAtnxwQ belongs to topics: [8]
# Video xY6FZioxlgw belongs to topics: [14]
# Video xYmlSjp22wo belongs to topics: [6]
# Video xyZH8XQqjEk belongs to topics: [2, 12, 14]
# Video xZBccbBIV7U belongs to topics: [7, 8]
# Video y-cb3qVBDb8 belongs to topics: [8]
# Video y0ArM7kMPnA belongs to topics: [14]
# Video y0gG7Tc-wHw belongs to topics: [0]
# Video y0i2HU4C3R0 belongs to topics: [7]
# Video Y11ih1OEszY belongs to topics: [4]
# Video y12Ms-DaXv8 belongs to topics: [14]
# Video Y2VvAiXtP_Y belongs to topics: [0]
# Video Y3GdJZiemDk belongs to topics: [9]
# Video y3UA461qou4 belongs to topics: [0, 9]
# Video y6uJTEA_I6M belongs to topics: [8]
# Video y6yrAADHdog belongs to topics: [2, 8]
# Video y7ECCYITe9U belongs to topics: [14]
# Video y7fYG7n55p4 belongs to topics: [0, 2, 7]
# Video Y8-4rbZnrIk belongs to topics: [6, 14]
# Video y8txqt2exjQ belongs to topics: [0, 8]
# Video y9ApSkrvLKg belongs to topics: [2, 3]
# Video y9iCFcSaD58 belongs to topics: [0]
# Video y9xOKcZD0xE belongs to topics: [8, 14]
# Video YamEZfcS3mU belongs to topics: [1]
# Video Yao1GGe9HQI belongs to topics: [14]
# Video yaTecmbw82Q belongs to topics: [1, 10]
# Video yBeRdhX1FMk belongs to topics: [14]
# Video YCFNwp8TH90 belongs to topics: [8, 9]
# Video ydk4GIjo4cU belongs to topics: [0]
# Video YE6BquBXgmo belongs to topics: [0, 8]
# Video ye9AqyZ9B84 belongs to topics: [0, 13]
# Video YFOx5_ozQH8 belongs to topics: [5]
# Video yGULu6ml0mg belongs to topics: [12, 14]
# Video YhL6ZF2luIc belongs to topics: [9, 14]
# Video YhVy0eZdUb8 belongs to topics: [7]
# Video YJn6kJcDDTA belongs to topics: [1]
# Video Yk-C5nmpVIQ belongs to topics: [6, 14]
# Video YK8hGMfNgzE belongs to topics: [14]
# Video YLPogsvk7ew belongs to topics: [5]
# Video ylwiOLab5AA belongs to topics: [2]
# Video YMblJMX0G40 belongs to topics: [5]
# Video YNjluhmwrOk belongs to topics: [0]
# Video YO49D7SH130 belongs to topics: [4, 8]
# Video yOw0sYXvbIc belongs to topics: [0, 5]
# Video yPUCs7KoFXQ belongs to topics: [10]
# Video YQ5Jv4x_Hp0 belongs to topics: [13]
# Video yQX0pb0wbiI belongs to topics: [0, 13]
# Video yR6a9-ufsZc belongs to topics: [0, 13]
# Video yRD2VSyC9n4 belongs to topics: [7, 14]
# Video YrUIlaG0c3c belongs to topics: [9, 14]
# Video ysLKE6PrK8k belongs to topics: [0]
# Video yT-AvSw1sfQ belongs to topics: [14]
# Video YtZKFFtX-G0 belongs to topics: [8]
# Video yu0ln-ehXOw belongs to topics: [6]
# Video YUuJGAv3Tpc belongs to topics: [1, 14]
# Video YUxJ-pihbXc belongs to topics: [0, 3, 13]
# Video yv8Bi2xcSK4 belongs to topics: [4, 8]
# Video YVEXxOhYjrA belongs to topics: [6, 10]
# Video yvX6GqOU9OI belongs to topics: [2]
# Video YWAKuKOG4xU belongs to topics: [4]
# Video yWSK0yj7hw4 belongs to topics: [0]
# Video yWWj-45afQ8 belongs to topics: [0, 9]
# Video YxrNHJmh1OI belongs to topics: [14]
# Video yxwM2RwbT0s belongs to topics: [1]
# Video yy4-v6lxAIE belongs to topics: [1, 8, 14]
# Video Y_iMpzLuUUQ belongs to topics: [0]
# Video z-HStsCLZ9g belongs to topics: [0]
# Video z-jA5xiynNE belongs to topics: [0]
# Video Z-N_NyiQhbY belongs to topics: [1]
# Video z-t9cXwncQg belongs to topics: [14]
# Video Z2h_Jj0ahGc belongs to topics: [8, 14]
# Video Z5EEYQ-lepE belongs to topics: [0, 3]
# Video Z5koqfgUcls belongs to topics: [0]
# Video z71dKXpOaOs belongs to topics: [2, 14]
# Video z79phJOsx8k belongs to topics: [14]
# Video z8A61wzZV20 belongs to topics: [5, 9, 14]
# Video Z8g0zOt_c9g belongs to topics: [0, 9]
# Video z91GDl8-CgM belongs to topics: [4, 14]
# Video Z9M_EQ3hszQ belongs to topics: [10]
# Video Z9Uz-NUaCG8 belongs to topics: [3, 14]
# Video ZB1JAWYtIbg belongs to topics: [7, 10]
# Video zb79c2x8JY4 belongs to topics: [0, 6]
# Video zCgmAjnTu1o belongs to topics: [2]
# Video ZcyO-ggx5tQ belongs to topics: [0, 3]
# Video ZddfrVMyJH8 belongs to topics: [8]
# Video zdk8yETuBcw belongs to topics: [8]
# Video ZDQP4SRfrpg belongs to topics: [10]
# Video zedJAOBgHMw belongs to topics: [0]
# Video zEEH4Q0D4LE belongs to topics: [2, 14]
# Video zEKxj6RnLjc belongs to topics: [14]
# Video zem70-C1JaI belongs to topics: [14]
# Video ZEVLabGmE9w belongs to topics: [2]
# Video ZFpnR0xpdRI belongs to topics: [0]
# Video ZfRf8dyBgBg belongs to topics: [9, 14]
# Video zgvwrv3Q77U belongs to topics: [8]
# Video zHG8KJhnkNA belongs to topics: [14]
# Video zHlIB6ypY3A belongs to topics: [0]
# Video zhTGl8I3Z7Y belongs to topics: [7, 14]
# Video Zih_iGT9wM8 belongs to topics: [1, 8, 13]
# Video ZIrqsRSprnY belongs to topics: [7, 14]
# Video zJaj2kaCd74 belongs to topics: [0, 13]
# Video zjJOawV31lo belongs to topics: [10]
# Video zjLcCRtS-Vc belongs to topics: [8, 14]
# Video ZKC2DpeBaOw belongs to topics: [0]
# Video ZKv35nYm5aw belongs to topics: [0]
# Video ZLfzADdFjMQ belongs to topics: [0, 5]
# Video zlnkzcqwe3E belongs to topics: [0]
# Video ZLZYGufLzE4 belongs to topics: [0, 13]
# Video ZMHdMN0B3QI belongs to topics: [0, 7]
# Video ZMHvYD5TXb4 belongs to topics: [0]
# Video zNxi-9LlS6g belongs to topics: [0, 8]
# Video zOk103o-LDg belongs to topics: [0]
# Video Zoo8qhijf5Y belongs to topics: [0, 13]
# Video zpT46etTP6E belongs to topics: [1, 10, 14]
# Video ZPZD8BZjXX4 belongs to topics: [0]
# Video zPZjoBJikro belongs to topics: [14]
# Video zrUXJ9Ul4ak belongs to topics: [1, 8]
# Video Zs6Gpbw29ZQ belongs to topics: [14]
# Video zSSGBbOkxUM belongs to topics: [10]
# Video zTcCSyucYqI belongs to topics: [0]
# Video zTCNb5qPw3A belongs to topics: [12]
# Video ZtFc9FT0N2c belongs to topics: [8]
# Video ZTiFnGBMgKU belongs to topics: [0, 3]
# Video zud0s365CNY belongs to topics: [8]
# Video zurBNvmMQ2Y belongs to topics: [1]
# Video ZUWFIXxkWhs belongs to topics: [10, 14]
# Video zVarrDvOmIc belongs to topics: [10, 14]
# Video ZvRGNzNuUx8 belongs to topics: [0]
# Video Zw9Cj-bT-5U belongs to topics: [0, 6]
# Video zWexXpego-o belongs to topics: [14]
# Video ZWGDjgZ76q8 belongs to topics: [0, 14]
# Video zwOJjQuL4i4 belongs to topics: [5, 6, 13]
# Video ZwpVhNFsfPM belongs to topics: [0]
# Video ZXJ1Ebsux4g belongs to topics: [1, 14]
# Video ZxL58tCcTOQ belongs to topics: [6]
# Video ZXRChhajpic belongs to topics: [14]
# Video zYZfK4WvGhk belongs to topics: [9]
# Video zZqpG54vou8 belongs to topics: [4]
# Video Z_-0yXSa-tM belongs to topics: [1, 14]
# Video Z_hNMcayu2A belongs to topics: [1]
# Video _1IE7uMo8iU belongs to topics: [14]
# Video _3hVuFqtGA8 belongs to topics: [12, 14]
# Video _4SSzYOzkG0 belongs to topics: [3]
# Video _79OZZQRZN4 belongs to topics: [7, 9]
# Video _8WB6DhU0PE belongs to topics: [12]
# Video _8Zl2WqkLkA belongs to topics: [10]
# Video _aE7MDvvfJc belongs to topics: [14]
# Video _AWKKCUJnk0 belongs to topics: [8, 14]
# Video _axaqyGbSmk belongs to topics: [9]
# Video _c4HJnpPJJM belongs to topics: [0, 5]
# Video _DWXlySq7p4 belongs to topics: [0]
# Video _eeqXw2u67c belongs to topics: [0, 11]
# Video _eGxfDkte9Y belongs to topics: [14]
# Video _hFmYL8mBUg belongs to topics: [0, 7, 14]
# Video _HSQsi3Ol-Q belongs to topics: [9]
# Video _I8wNd_0Cng belongs to topics: [3, 14]
# Video _iwYr_FG9f8 belongs to topics: [2]
# Video _jiVtXsfupo belongs to topics: [1, 2, 14]
# Video _KB5xVXcRUs belongs to topics: [0]
# Video _kIxo5o5w5Y belongs to topics: [3, 7]
# Video _kKm-OqzmWs belongs to topics: [0, 7]
# Video _M3ScFB7d8w belongs to topics: [0]
# Video _MRKWqd3L3w belongs to topics: [9]
# Video _NIcXlLGzmo belongs to topics: [0]
# Video _nJkaMeJESU belongs to topics: [12]
# Video _NzvNZ-dMuA belongs to topics: [8]
# Video _oqTNpCNkWs belongs to topics: [8, 12]
# Video _qoxcsCD7kw belongs to topics: [0]
# Video _qWi95cDlAA belongs to topics: [9]
# Video _qZsmW5IW20 belongs to topics: [8]
# Video _sR1cALLCVg belongs to topics: [9, 14]
# Video _VyIplCMi4A belongs to topics: [0, 5]
# Video _ximeemA3OI belongs to topics: [6, 14]
# Video _xuMLlPPhtc belongs to topics: [0]
# Video _YzEYbX8Ju0 belongs to topics: [14]
# Video __MnmdBYVoc belongs to topics: [8]
#
# Number of videos per topic:
# Topic 0: 580 videos
# Topic 1: 138 videos
# Topic 2: 137 videos
# Topic 3: 121 videos
# Topic 4: 43 videos
# Topic 5: 108 videos
# Topic 6: 160 videos
# Topic 7: 171 videos
# Topic 8: 301 videos
# Topic 9: 179 videos
# Topic 10: 197 videos
# Topic 11: 29 videos
# Topic 12: 85 videos
# Topic 13: 108 videos
# Topic 14: 580 videos

# %%
from gensim.models.coherencemodel import CoherenceModel
def display_wordclouds_grid(lda_model, num_words=50):
    """
    Displays WordClouds for each topic in a grid layout.
    Skips topics with no words to plot.
    
    Args:
        lda_model: Trained LDA model.
        num_words: Number of top words to consider for WordCloud.
    """
    num_words = int(num_words)  # Ensure num_words is an integer
    topics = lda_model.show_topics(num_words=num_words, formatted=False)
    
    # Filter out topics with no words
    valid_topics = [(t, words) for t, words in topics if words]

    if not valid_topics:
        print("No topics available to plot.")
        return  # Exit if no valid topics

    num_topics = len(valid_topics)
    num_cols = 2  # Two columns for side-by-side comparison
    num_rows = (num_topics + num_cols - 1) // num_cols  # Calculate required rows

    # Create subplots dynamically
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 5 * num_rows))
    axes = axes.flatten()  # Flatten to easily iterate over

    for i, (t, words) in enumerate(valid_topics):
        # Generate word frequency dictionary for WordCloud
        word_freq = {word[0]: word[1] for word in words}
        wordcloud = WordCloud(width=400, height=200, background_color="white").generate_from_frequencies(word_freq)

        # Display the WordCloud
        axes[i].imshow(wordcloud, interpolation="bilinear")
        axes[i].set_title(f"Topic {t}", fontsize=12)
        axes[i].axis("off")

    # Hide unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])  # Remove empty subplots

    plt.subplots_adjust(hspace=0.3, wspace=0.2)  # Adjust spacing between rows and columns
    plt.show()

# Function to display LDA evaluation metrics
def display_lda_evaluation_metrics(lda_model, corpus, dictionary):
    """
    Displays evaluation metrics for the LDA model.
    
    Args:
        lda_model: Trained LDA model.
        corpus: Gensim corpus.
        dictionary: Gensim dictionary.
        preprocessed_doc: Preprocessed document content.
    """
    # Calculate perplexity
    perplexity = lda_model.log_perplexity(corpus)
    print(f"\nPerplexity: {perplexity}")
    
    # Calculate coherence score
    coherence_model = CoherenceModel(model=lda_model, texts=[doc.split() for doc in all_documents], dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    print(f"Coherence Score: {coherence_score}")

# Function to display filtered/non-filtered topic-word distributions
def display_topic_word_distributions(lda_model, num_words=20):
    """
    Displays topic-word distributions before and after filtering repeated words.
    
    Args:
        lda_model: Trained LDA model.
        num_words: Number of top words to display per topic.
    """
    # Get non-filtered topics
    non_filtered_topics = lda_model.show_topics(num_words=num_words, formatted=False)
    
    for t, words in non_filtered_topics:
        print(f"Topic {t}: {words}")

display_topic_word_distributions(lda_model)
display_lda_evaluation_metrics(lda_model, corpus, dictionary)
display_wordclouds_grid(lda_model, num_words=20)
# Out:
# Topic 11: [('vendor', 0.16111776), ('puril', 0.1384203), ('magician', 0.08216912), ('mango', 0.04044029), ('chavacano', 0.039596923), ('piroshki', 0.023406342), ('meat', 0.022085678), ('recipe', 0.014813994), ('art', 0.012978482), ('trike', 0.012641235), ('mousse', 0.011175595), ('lumpia', 0.009742818), ('cabbage', 0.0092641665), ('cap', 0.009119545), ('dough', 0.00896865), ('baseball', 0.008884823), ('market', 0.0087091075), ('twist', 0.008264632), ('driver', 0.0061506983), ('hotel', 0.0060893735)]
# Topic 4: [('god', 0.0787743), ('pension', 0.078367166), ('government', 0.06765819), ('lord', 0.050343778), ('programme', 0.035891194), ('slide', 0.027959889), ('jesus', 0.027844707), ('amen', 0.027621882), ('christ', 0.021199629), ('corporation', 0.021150615), ('bus', 0.020945892), ('money', 0.01700648), ('africa', 0.016668653), ('tax', 0.010755855), ('budget', 0.010581945), ('tunnel', 0.009508079), ('cost', 0.008987453), ('protection', 0.008463442), ('wheel', 0.008199994), ('nurse', 0.007745836)]
# Topic 12: [('lord', 0.11455534), ('egg', 0.0434337), ('veronica', 0.03734041), ('god', 0.034593485), ('bohol', 0.032257672), ('bike', 0.026121669), ('chocolate', 0.023549952), ('vanessa', 0.02296068), ('movie', 0.020581787), ('brother', 0.01762102), ('carl', 0.013184971), ('jesus', 0.012609348), ('christ', 0.011664824), ('carol', 0.011186933), ('duck', 0.011000521), ('rain', 0.009812313), ('merrell', 0.009270108), ('park', 0.008282399), ('event', 0.0077833836), ('liberty', 0.007344917)]
# Topic 6: [('golf', 0.086330555), ('voice', 0.08503016), ('mark', 0.07076973), ('cheesecake', 0.05502967), ('song', 0.031769305), ('cake', 0.030327428), ('anton', 0.0266293), ('squid', 0.021665374), ('relationship', 0.0163368), ('drug', 0.013305911), ('vibrato', 0.0129168825), ('list', 0.011171301), ('singer', 0.010807164), ('reby', 0.009385027), ('residence', 0.009118419), ('morissette', 0.008021459), ('cheese', 0.0069230823), ('flynn', 0.0064368024), ('street', 0.006394459), ('performance', 0.0060245893)]
# Topic 2: [('mcdonalds', 0.08912752), ('jollibee', 0.06596294), ('water', 0.041018825), ('spaghetti', 0.03592685), ('chicken', 0.022622753), ('rice', 0.021213671), ('coconut', 0.01728183), ('mads', 0.017063309), ('liver', 0.013649741), ('singapore', 0.01332336), ('sauce', 0.012459073), ('tuna', 0.010755075), ('banaue', 0.008942749), ('peso', 0.008674741), ('butt', 0.008623707), ('dugong', 0.008318205), ('burger', 0.006767938), ('soda', 0.006640226), ('durian', 0.006605625), ('city', 0.006492396)]
# Topic 10: [('language', 0.08719823), ('john', 0.08383178), ('manila', 0.07637665), ('audience', 0.07474142), ('city', 0.030586598), ('song', 0.021817492), ('mia', 0.02032048), ('haircut', 0.019926712), ('choir', 0.018304607), ('tagalog', 0.017031325), ('bgc', 0.015692977), ('park', 0.0092242155), ('gelo', 0.0076917866), ('mall', 0.0075880266), ('museum', 0.0075661577), ('disney', 0.00704341), ('walk', 0.006859007), ('street', 0.0062605646), ('makati', 0.0055858577), ('market', 0.0054032826)]
# Topic 9: [('family', 0.113401525), ('mall', 0.038821068), ('salad', 0.032795124), ('duterte', 0.021822272), ('lady', 0.021209847), ('president', 0.019606622), ('stuff', 0.01607502), ('trump', 0.015643016), ('potato', 0.015603681), ('house', 0.015268286), ('war', 0.012754091), ('nation', 0.010695707), ('train', 0.010184803), ('care', 0.009867472), ('bobby', 0.009494827), ('money', 0.008927464), ('cemetery', 0.007873174), ('pmsk', 0.007589203), ('job', 0.00758803), ('maria', 0.0071710474)]
# Topic 8: [('island', 0.11738803), ('visa', 0.0654039), ('boat', 0.05549184), ('water', 0.038132727), ('tour', 0.02335913), ('beach', 0.020663641), ('nido', 0.018229686), ('street', 0.017300325), ('fish', 0.016770022), ('gourd', 0.008639814), ('volcano', 0.008130399), ('experience', 0.008011574), ('lagoon', 0.007972501), ('ferry', 0.0078116814), ('trip', 0.007727709), ('spot', 0.0076109204), ('sea', 0.007450211), ('town', 0.006439432), ('city', 0.0063439254), ('tourist', 0.0062891757)]
# Topic 0: [('rice', 0.06030999), ('sauce', 0.042071145), ('pork', 0.035720687), ('taste', 0.034923688), ('dish', 0.0315078), ('flavor', 0.030239994), ('meat', 0.02067858), ('egg', 0.017975308), ('christmas', 0.01726589), ('coffee', 0.015442743), ('chicken', 0.014909551), ('vinegar', 0.014487983), ('soup', 0.014227636), ('eat', 0.012984377), ('spicy', 0.012030053), ('coconut', 0.010116574), ('snack', 0.009424233), ('adobo', 0.008278571), ('breakfast', 0.007990171), ('restaurant', 0.0076013845)]
# Topic 14: [('city', 0.039136194), ('money', 0.033733416), ('cebu', 0.023258986), ('girl', 0.014704514), ('car', 0.013918628), ('stuff', 0.013604632), ('business', 0.01220126), ('birthday', 0.011049155), ('book', 0.01054692), ('gun', 0.0092119975), ('damian', 0.009209205), ('experience', 0.007815273), ('night', 0.007595941), ('relationship', 0.0069558155), ('class', 0.0067642876), ('wife', 0.006529367), ('share', 0.0065120123), ('party', 0.0063007534), ('province', 0.0061096693), ('reason', 0.005983507)]
#
# Perplexity: -6.13609426465814
# Coherence Score: 0.4742896696792784
