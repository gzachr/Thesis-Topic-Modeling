# %%
# Store topics as list of lists
import json
# Load the JSON file
filename = 'T3.nodes.json'
filepath = '../output-jsons/' + filename
with open(filepath, 'r') as f:
    data = json.load(f)

def flatten_tree(node, depth=1, result=None):
    if result is None:
        result = []
    """Recursively flattens a tree structure into a list."""
    result.append({
        "id": node["id"],
        "texts": node["text"].split(),
        "level": depth
    })
    
    for child in node.get("children", []):
        flatten_tree(child, depth + 1, result)
    
    return result

# Process each root node in the JSON
flat_list = []
for root in data:
    flat_list.extend(flatten_tree(root))

print(flat_list)
# Out:
# [{'id': 'Z35', 'texts': ['mango', 'fruit', 'milk', 'banana', 'vegetable', 'coconut', 'bread'], 'level': 1}, {'id': 'Z214', 'texts': ['mango', 'banana', 'pineapple', 'orange', 'apple', 'peach', 'banana-banana'], 'level': 2}, {'id': 'Z170', 'texts': ['pineapple', 'orange', 'apple', 'cut'], 'level': 3}, {'id': 'Z172', 'texts': ['banana', 'banana-banana'], 'level': 3}, {'id': 'Z171', 'texts': ['mango', 'peach'], 'level': 3}, {'id': 'Z213', 'texts': ['fruit', 'milk', 'vegetable', 'coconut', 'bread', 'bean', 'dip'], 'level': 2}, {'id': 'Z168', 'texts': ['milk', 'coconut'], 'level': 3}, {'id': 'Z167', 'texts': ['vegetable', 'fruit'], 'level': 3}, {'id': 'Z169', 'texts': ['bread', 'bean', 'tea', 'dip', 'jelly'], 'level': 3}, {'id': 'Z315', 'texts': ['game', 'play', 'basketball', 'dance', 'competition', 'player', 'kick'], 'level': 1}, {'id': 'Z242', 'texts': ['dance', 'competition', 'kick', 'winner', 'training', 'dancing', 'knee'], 'level': 2}, {'id': 'Z1161', 'texts': ['competition', 'kick', 'winner'], 'level': 3}, {'id': 'Z1162', 'texts': ['dance', 'dancing'], 'level': 3}, {'id': 'Z1160', 'texts': ['training', 'train', 'knee', 'enemy', 'leg', 'mission', 'final'], 'level': 3}, {'id': 'Z244', 'texts': ['brother', 'mother', 'father', 'eye', 'sister', 'uncle', 'blood'], 'level': 2}, {'id': 'Z1170', 'texts': ['eye', 'pop', 'poor', 'fair', 'decent', 'nose', 'perspective'], 'level': 3}, {'id': 'Z1166', 'texts': ['brother', 'jay', 'pipe'], 'level': 3}, {'id': 'Z1169', 'texts': ['girl-girl', 'contact', 'specific', 'intense', 'angry', 'dress', 'percent'], 'level': 3}, {'id': 'Z1168', 'texts': ['mother', 'father'], 'level': 3}, {'id': 'Z1167', 'texts': ['sister', 'uncle', 'blood', 'cousin', 'speed', 'afraid', 'scared'], 'level': 3}, {'id': 'Z243', 'texts': ['game', 'play', 'basketball', 'player', 'sport', 'shoot', 'shot'], 'level': 2}, {'id': 'Z1163', 'texts': ['game', 'play'], 'level': 3}, {'id': 'Z1164', 'texts': ['basketball', 'player', 'sport', 'gold', 'gun'], 'level': 3}, {'id': 'Z1165', 'texts': ['shoot', 'shot', 'ball'], 'level': 3}, {'id': 'Z37', 'texts': ['singer', 'song', 'singing', 'sing', 'voice', 'song-song', 'fish'], 'level': 1}, {'id': 'Z222', 'texts': ['song', 'singer', 'singing', 'sing', 'voice', 'song-song'], 'level': 2}, {'id': 'Z196', 'texts': ['song', 'sing'], 'level': 3}, {'id': 'Z197', 'texts': ['singer', 'singing', 'voice', 'song-song'], 'level': 3}, {'id': 'Z221', 'texts': ['fish', 'shrimp', 'seafood', 'tomato', 'rice-rice', 'fish-fish', 'pot'], 'level': 2}, {'id': 'Z193', 'texts': ['fish-fish', 'fish'], 'level': 3}, {'id': 'Z195', 'texts': ['tomato', 'rice-rice', 'pot', 'chef', 'pasta', 'kitchen', 'mushroom'], 'level': 3}, {'id': 'Z194', 'texts': ['seafood', 'shrimp'], 'level': 3}, {'id': 'Z312', 'texts': ['island', 'beach', 'palawan', 'nido', 'boracay', 'tourist', 'beach-beach'], 'level': 1}, {'id': 'Z235', 'texts': ['palawan', 'nido', 'boracay', 'paradise', 'lagoon', 'coron', 'kayak'], 'level': 2}, {'id': 'Z1144', 'texts': ['nido', 'boracay', 'paradise', 'kayak'], 'level': 3}, {'id': 'Z1143', 'texts': ['palawan', 'lagoon', 'coron', 'coral'], 'level': 3}, {'id': 'Z234', 'texts': ['island', 'beach', 'tourist', 'beach-beach'], 'level': 2}, {'id': 'Z1141', 'texts': ['tourist', 'island'], 'level': 3}, {'id': 'Z1142', 'texts': ['beach', 'beach-beach'], 'level': 3}, {'id': 'Z31', 'texts': ['vocal', 'feature-feature', 'latino', 'podcast', 'opm', 'lyric', 'artist'], 'level': 1}, {'id': 'Z21', 'texts': ['vocal', 'opm', 'lyric', 'artist', 'performance', 'karaoke', 'tiktok'], 'level': 2}, {'id': 'Z11', 'texts': ['performance', 'band', 'concert', 'stage', 'studio'], 'level': 3}, {'id': 'Z15', 'texts': ['karaoke', 'machine'], 'level': 3}, {'id': 'Z13', 'texts': ['vocal', 'opm', 'lyric', 'tiktok'], 'level': 3}, {'id': 'Z17', 'texts': ['technique', 'control', 'note'], 'level': 3}, {'id': 'Z14', 'texts': ['listen', 'mate', 'sing-song', 'range', 'bloody', 'ridiculous', 'gentleman'], 'level': 3}, {'id': 'Z12', 'texts': ['artist', 'indu ...

# %%
import pandas as pd

# Create the dataframe from flat_list
df = pd.DataFrame(flat_list)

# Rename columns as needed
df = df.rename(columns={'id': 'Id', 'level': 'level', 'texts': 'texts'})

# Add empty columns for 'general category' and 'specific category'
df['general category'] = ''
df['specific category'] = ''

df = df[['Id', 'level', 'texts', 'general category', 'specific category']]

df['texts'] = df['texts'].apply(lambda x: ' '.join(x))

df.columns = [col.title() for col in df.columns]
df.head()

df.to_csv('categories.csv', index=False)
