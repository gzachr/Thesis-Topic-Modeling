# %%
import os
import re
import pandas as pd

# Create Initial Dataframe with all video IDs
dataset_folder = "./Previous_THS-ST2_Files/standard_dataset_old"
data_records = []

# Regex pattern to extract Video Id and Title from the filename
filename_pattern = re.compile(r"^(.*)_(.*?)_captions\.txt$")

for file in sorted(os.listdir(dataset_folder)): 
    if file.endswith("_captions.txt"):  # Ensure it's a valid transcript file
        match = filename_pattern.match(file)
        if match:
            video_id, video_title = match.groups()  # Extract Video Id and Title
            file_path = os.path.join(dataset_folder, file)

            # Append data to the list
            data_records.append({
                "Video Title": video_title,
                "Link": f"https://www.youtube.com/watch?v={video_id}",
                "BERTopic Topics": None
            })

# Convert to DataFrame
topics_per_video_df = pd.DataFrame(data_records)
topics_per_video_df.set_index("Video Title", inplace=True)

topics_per_video_df
# Out:
#                                                                                            Link  \
# Video Title
# $200 Luxury Beach Hotel in The Philippines ðŸ‡µ...  https://www.youtube.com/watch?v=--8n6A8Q6M0
# Philippines Army vs Thailand Army                   https://www.youtube.com/watch?v=0IMWasj76yU
# Tour of The House We Built in The Philippines       https://www.youtube.com/watch?v=1kErCqgIVMk
# VOCAL COACH REACTS - REGINE VELASQUEZ - Araw-Gabi   https://www.youtube.com/watch?v=2TmagN6RhkI
# Top 5 Exotic Foods in the Philippines The BRAVE...  https://www.youtube.com/watch?v=2ftG8JuMzz4
# ...                                                                                         ...
# PHILIPPINES STREET FOOD Tour - INSANELY DELICIO...  https://www.youtube.com/watch?v=y9iCFcSaD58
# We arrived in Philippines. Manila. Towards The ...  https://www.youtube.com/watch?v=y9xOKcZD0xE
# ChowKing for the first time - FilipinoChinese f...  https://www.youtube.com/watch?v=yR6a9-ufsZc
# WILD WINGS DAVAO - BEST CHICKEN WINGS, BILAO FI...  https://www.youtube.com/watch?v=zTcCSyucYqI
# (ENG) SB19 Dance Cover BTS Boy With Luv & Idol ...  https://www.youtube.com/watch?v=zwOJjQuL4i4
#
#                                                    BERTopic Topics
# Video Title
# $200 Luxury Beach Hotel in The Philippines ðŸ‡µ...            None
# Philippines Army vs Thailand Army                             None
# Tour of The House We Built in The Philippines                 None
# VOCAL COACH REACTS - REGINE VELASQUEZ - Araw-Gabi             None
# Top 5 Exotic Foods in the Philippines The BRAVE...            None
# ...                                                            ...
# PHILIPPINES STREET FOOD Tour - INSANELY DELICIO...            None
# We arrived in Philippines. Manila. Towards The ...            None
# ChowKing for the first time - FilipinoChinese f...            None
# WILD WINGS DAVAO - BEST CHICKEN WINGS, BILAO FI...            None
# (ENG) SB19 Dance Cover BTS Boy With Luv & Idol ...            None
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Get the dataset

# %%
# Initialize list to store data
experiment_records = []

# Iterate through transcript files
for file in os.listdir(dataset_folder):
    if file.endswith("_captions.txt"):  # Ensure it's a valid transcript file
        match = filename_pattern.match(file)
        if match:
            video_id, _ = match.groups()  # Extract Video ID
            file_path = os.path.join(dataset_folder, file)

            # Read transcript content
            with open(file_path, "r", encoding="utf-8") as f:
                transcript = f.read().strip()  # Remove extra spaces/newlines

            # Append data to list
            experiment_records.append({
                "Video Id": video_id,
                "Transcript": transcript
            })

# Convert to DataFrame
experiment_df = pd.DataFrame(experiment_records)

# Display the first few rows to verify
experiment_df
# Out:
#        Video Id                                         Transcript
# 0   MBtWxCM7NYg  this did not go to plan when i was like it's \...
# 1   O0cIJww_amw  I once talked to a filipina. Then she said, wh...
# 2   R8-LyHgcl5I  hi my name is josie and this is \nboracay isla...
# 3   Gl2RpA1xS6M  good morning everyone we're Nicole and Mico \n...
# 4   4OiOwDh5lKE  today is the day we're going to the philippine...
# ..          ...                                                ...
# 95  vwIIeiOhTJ0  From dogs riding motorcycles, to inmates danci...
# 96  8DYPxsr7kDI  [Music]\ntoday's video is going to primarily b...
# 97  S4bNEgM483k  Hello and welcome back to my brand new channel...
# 98  NdLjKxqzDbA  welcome welcome back to Pinoy Planet I'm \nexc...
# 99  REvaHqT3uro  My friends and good afternoon welcome back to ...
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Initial Pre-procssing (Minimal)
#
# removal of timestamps, numbers, contents inside parentheses, leading & trailing whitespaces, square brackets etc.

# %%
# initial pre-processing (minimal)

# Define a minimal preprocessing function
def minimal_preprocessing(text):
    # Remove timestamps and other non-verbal elements (like "(music)")
    text = re.sub(r'\[.*?\]', '', text)  # Remove content in square brackets (e.g., music)
    text = re.sub(r'\(.*?\)', '', text)  # Remove content in parentheses (e.g., [music], (child speaking))
    text = re.sub(r'\d+', '', text)     # Remove numbers
    text = re.sub(r'\s+', ' ', text)    # Replace multiple spaces with one
    text = text.strip()                 # Remove leading and trailing whitespace
    return text

# Apply the preprocessing to the 'Transcript' column
experiment_df['cleaned_transcript'] = experiment_df['Transcript'].apply(minimal_preprocessing)

# Display the cleaned data
experiment_df[['Transcript', 'cleaned_transcript']]
# Out:
#                                            Transcript  \
# 0   this did not go to plan when i was like it's \...
# 1   I once talked to a filipina. Then she said, wh...
# 2   hi my name is josie and this is \nboracay isla...
# 3   good morning everyone we're Nicole and Mico \n...
# 4   today is the day we're going to the philippine...
# ..                                                ...
# 95  From dogs riding motorcycles, to inmates danci...
# 96  [Music]\ntoday's video is going to primarily b...
# 97  Hello and welcome back to my brand new channel...
# 98  welcome welcome back to Pinoy Planet I'm \nexc...
# 99  My friends and good afternoon welcome back to ...
#
#                                    cleaned_transcript
# 0   this did not go to plan when i was like it's g...
# 1   I once talked to a filipina. Then she said, wh...
# 2   hi my name is josie and this is boracay island...
# 3   good morning everyone we're Nicole and Mico we...
# 4   today is the day we're going to the philippine...
# ..                                                ...
# 95  From dogs riding motorcycles, to inmates danci...
# 96  today's video is going to primarily be towards...
# 97  Hello and welcome back to my brand new channel...
# 98  welcome welcome back to Pinoy Planet I'm excit...
# 99  My friends and good afternoon welcome back to ...
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Transcript Segmentation

# %%
import torch
import nltk
import swifter
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

from nltk.tokenize import sent_tokenize

# Load mBERT tokenizer and model
model_name = "bert-base-multilingual-cased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Use Apple's Metal (MPS) for acceleration if available
device = "mps" if torch.backends.mps.is_available() else "cpu"
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(119547, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def encode_sentences(sentences, batch_size=16):
    """Encodes sentences into vector representations using mBERT."""
    embeddings = []
    for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i+batch_size]
        encoded_inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to(device)
        with torch.no_grad():
            outputs = model(**encoded_inputs)
        batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu()  # Move to CPU for further processing
        embeddings.append(batch_embeddings)
    return torch.cat(embeddings, dim=0)

# %%
def compute_cosine_similarities(embeddings):
    """Computes cosine similarity efficiently in batch."""
    return cosine_similarity(embeddings[:-1], embeddings[1:]).diagonal()

# %%
def segment_transcript(transcript, threshold=0.7, min_length=30):
    """Segments transcript into meaningful chunks based on sentence similarity."""
    sentences = nltk.sent_tokenize(transcript)
    sentences = [s.strip() for s in sentences if s.strip()]

    if len(sentences) < 2:
        return [transcript]  # Return the whole text if it's too short

    # Encode sentences
    sentence_embeddings = encode_sentences(sentences)

    # Compute cosine similarity between consecutive sentences
    similarities = compute_cosine_similarities(sentence_embeddings)

    # Identify segment boundaries where similarity drops below threshold
    boundaries = [0] + [i + 1 for i, sim in enumerate(similarities) if sim < threshold] + [len(sentences)]

    # Create segments
    segments = [" ".join(sentences[boundaries[i]:boundaries[i + 1]]) for i in range(len(boundaries) - 1)]

    # Merge small segments
    processed_segments, temp_segment = [], ""
    for segment in segments:
        if len(segment) + len(temp_segment) < min_length:
            temp_segment += " " + segment
        else:
            if temp_segment:
                processed_segments.append(temp_segment.strip())
            temp_segment = segment
    if temp_segment:
        processed_segments.append(temp_segment.strip())

    # Ensure at least two segments
    if len(processed_segments) == 1:
        mid = len(sentences) // 2
        processed_segments = [" ".join(sentences[:mid]), " ".join(sentences[mid:])]

    return processed_segments

# %% [markdown]
# Segment

# %%
# Apply segmentation using parallel processing
experiment_df['Segments'] = experiment_df['cleaned_transcript'].swifter.apply(segment_transcript)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Pandas Apply:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Convert to list of dictionaries
segmented_transcripts = [
    {"Video Id": row["Video Id"], "Segment #": i + 1, "Segment": segment}
    for _, row in experiment_df.iterrows()
    for i, segment in enumerate(row["Segments"])
]

# %%
# Convert to DataFrame
segmented_df = pd.DataFrame(segmented_transcripts)

# Display segmented transcripts
print(segmented_df)
# Out:
#          Video Id  Segment #  \
# 0     MBtWxCM7NYg          1
# 1     MBtWxCM7NYg          2
# 2     O0cIJww_amw          1
# 3     O0cIJww_amw          2
# 4     O0cIJww_amw          3
# ...           ...        ...
# 6696  REvaHqT3uro         24
# 6697  REvaHqT3uro         25
# 6698  REvaHqT3uro         26
# 6699  REvaHqT3uro         27
# 6700  REvaHqT3uro         28
#
#                                                 Segment
# 0     this did not go to plan when i was like it's g...
# 1     in australia so pretty expensive not the cheap...
# 2                          I once talked to a filipina.
# 3     Then she said, why are you like that? Then I a...
# 4     She said, because of your accent. Why is your ...
# ...                                                 ...
# 6696  liters per person and basically put so we almo...
# 6697                                                Oh!
# 6698  it looks like they're building a brand new Spa...
# 6699                                     Hello El Nido.
# 6700  Guys we've got a rainbow in the distance I don...
#
# [6701 rows x 3 columns]

# %%
# Display segmented transcripts in a structured way
for video_id, group in segmented_df.groupby("Video Id"):
    print(f"\n==== Transcript for Video Id: {video_id} ====")
    for index, row in group.iterrows():
        print(f"\nSegment {row['Segment #']}:\n{row['Segment']}")
    print("\n" + "=" * 50)  # Separator for clarity
    
    
# txt
# Out:
# ==== Transcript for Video Id: --8n6A8Q6M0 ====
#
# Segment 1:
# Oh, my God.
#
# Segment 2:
# It is just the perfect recipe for a good day.
#
# Segment 3:
# Want some beer? Sure.
#
# Segment 4:
# Oh, it's big bottle. Oh my goodness.
#
# Segment 5:
# Three Tarzan?
#
# Segment 6:
# Good morning from Bohol here in the Philippines.
#
# Segment 7:
# Everybody guys, this look how gorgeous this place is.
#
# Segment 8:
# Crystal clear water.
#
# Segment 9:
# It's just honestly such a vibe, perfect temperature to be spending the day by the beach. And that is exactly what we're gonna do today because I'm staying about meters up that way at a $ per night hotel on there for the next couple of nights.
#
# Segment 10:
# And I arrived in the, uh, last night.
#
# Segment 11:
# Uh, it was raining.
#
# Segment 12:
# It was kind of a little bit miserable. So I was like, you know what?
#
# Segment 13:
# We'll wait until the weather is good and boy, or boy did the weather turn out good today.
#
# Segment 14:
# This water guys, if you know me, I'm Australian.
#
# Segment 15:
# I live in Sydney.
#
# Segment 16:
# I live by the beach and I absolutely love being by the beaches.
#
# Segment 17:
# So it is just absolute paradise right here, right by the beach, uh, the hotel, super nice room overlooking, uh, the water.
#
# Segment 18:
# There's a really nice mall next to it.
#
# Segment 19:
# Uh, they have like kayaking paddle boarding that you can do.
#
# Segment 20:
# We can see somebody over there doing some paddle board and a really cool thing about this area of the beach is that right now it's high tide in low tide.
#
# Segment 21:
# It actually goes like all the way out.
#
# Segment 22:
# So you can like walk basically to like where all those boats are. I don't even know if they would be like in a couple hours, they're gonna be beached.
#
# Segment 23:
# So we are gonna be expanding the day here, enjoying the luxury.
#
# Segment 24:
# Uh, and we'll bring you all along for the journey.
#
# Segment 25:
# So Tara na and, uh, join me.
#
# Segment 26:
# As we explore the luxury hotel here in Cebu $ per night and worth every cent.
#
# Segment 27:
# We got a little photo shoot going on here. I think for the hotel, I saw them setting up all the cameras, uh, up at the pool area. But, uh, man, look at all that we've got a DLSR. We've got another DLSR, not like five DLSR.
#
# Segment 28:
# And here I am just with a GoPro, but, uh, yeah, I think that's to do with the hotel. But as I was saying, I have like plenty of kayaks and paddle boards here, the hotels actually just up there.
#
# Segment 29:
# Um, but this whole beach area here is all a private access for the guests.
#
# Segment 30:
# Here we go.
#
# Segment 31:
# Kayaks and whatnot.
#
# Segment 32:
# So we'll definitely take out the kayaks today.
#
# Segment 33:
# It is damn hot.
#
# Segment 34:
# I'll tell you that much.
#
# Segment 35:
# Um, but yeah, the Modala beach resort, this is where it is and uh, that is where we are heading.
#
# Segment 36:
# It's honestly like such a beautiful area. Like right now it's super hot, so it's perfect time to be swimming.
#
# Segment 37:
# So we'll head up to the pool.
#
# Segment 38:
# Um, but in the evening time, when I arrived here, it's just like so beautiful.
#
# Segment 39:
# Just walking along here, walking along the strip, there's a, a big, like, kind of mall area with like some really nice restaurants and stuff.
#
# Segment 40:
# But here we go.
#
# Segment 41:
# This is the entrance.
#
# Segment 42:
# Oh, the beach front entrance.
#
# Segment 43:
# Wow wow. Wow.
#
# Segment 44:
# Does it get much better than this?
#
# Segment 45:
# I don't think so.
#
# Segment 46:
# Look at that.
#
# Segment 47:
# Palm trees, ocean mountains in the background.
#
# Segment 48:
# And an infinity pool.
#
# Segment 49:
# So we're gonna have a quick little swim to, uh, start the day off right.
#
# Segment 50:
# Get all the batteries and phones out.
#
# Segment 51:
# My feet are super Sandy, so gonna shower off quickly.
#
# Segment 52:
# There we go.
#
# Segment 53:
# Some countries that I've noticed actually require you to, um, kind of shower before you actually get in into pools.
#
# Segment 54:
# But all right, look at this guys.
#
# Segment 55:
# Beach chairs and whatnot, but.
#
# Segment 56:
# This is paradise.
#
# Segment 57:
# Look at this.
#
# Segment 58:
# Honestly, like I've stayed at some pretty nice places around the world, but I think an infinity pool overlooking a beach, like right here, honestly, like I don't think it can. There's very few places in the world that could beat this.
#
# Segment 59:
# And I'm just super stoked to be staying here for the next couple of nights on Cebu island.
#
# Segment 60:
# It, uh, but honestly, I should be, I should be showing that way.
#
# Segment 61:
# I shouldn't be showing the view of my face when there's this beautiful view of the beach just over there.
#
# Segment 62:
# Damn. That is good.
#
# Segment 63:
# Let's go under.
#
# Segment 64:
# They also got a bar here for the guests.
#
# Segment 65:
# Let's see what they have on the menu.
#
# Segment 66:
# Oh, Hey brother.
#
# Segment 67:
# Do you have a menu that I could look at please?
#
# Segment 68:
# Serving all kinds of alcohol drinks.
#
# Segment 69:
# Perfect. Thank you.
#
# Segment 70:
# All right so we got appetizers pizzas sandwiches, which one is the best cocktail? You want a sweet cocktail, strong cocktail or? Yeah, like a sweet cocktail.
#
# Segment 71:
# Uh, margarita.
#
# Segment 72:
# All right, I'll have one, uh, classic margarita, please.
#
# Segment 73:
# Okay. You want frozen or, uh.
#
# Segment 74:
# Yeah, frozen. Thank you.
#
# Segment 75:
# Can life get much better than this?
#
# Segment 76:
# A frozen margarita on the pool in Cebu?
#
# Segment 77:
# I don't think so.
#
# Segment 78:
# So, uh, where's margarita classic margarita, .
#
# Segment 79:
# That is around just under four us dollars.
#
# Segment 80:
# So actually very affordable for the price that the menus actually like, actually that's very cheap for drinks. Um, the food like sandwiches, beef burger, that's like us dollars pizza around like seven us dollars for that one.
#
# Segment 81:
# Um, it's nice.
#
# Segment 82:
# All right margarita is in the works.
#
# Segment 83:
# You can see it there.
#
# Segment 84:
# All the materials and ingredients are being added to that one and, uh, a bit of ice.
#
# Segment 85:
# Oh yeah.
#
# Segment 86:
# We did ask for frozen.
#
# Segment 87:
# So that's a cool machine.
#
# Segment 88:
# That'd definitely chop your fingers off if you had 'em in the wrong areas.
#
# Segment 89:
# So let's see. Oh perfect.
#
# Segment 90:
# Nothing like a margarita and an infinity pool on the side of the beach.
#
# Segment 91:
# You might have to get jet skis later on.
#
# Segment 92:
# That looks so it's like so much fun. All right guys, I put two and two together.
#
# Segment 93:
# It's a wedding.
#
# Segment 94:
# So I'm guessing the people that I was filming earlier, the bride, uh, not the bridesmaid, the best men, the groomsmen, and there's either a bridesmaid or a, the wife.
#
# Segment 95:
# Um, so that understands.
#
# Segment 96:
# Ah, thank you very much, brother.
#
# Segment 97:
# Amazing little margarita, frozen margarita here on the, uh, the water.
#
# Segment 98:
# Get a, a cheeky thumbnail.
#
# Segment 99:
# Oh, that's good, Marky.
#
# Segment 100:
# Very delicious. Thank you.
#
# Segment 101:
# How good?
#
# Segment 102:
# You know, sometimes they don't let glasses in the pool, but these are actually plastic ones.
#
# Segment 103:
# So no chance of them breaking, but wow, this is just incredible.
#
# Segment 104:
# It's actually really nice margarita as well. Some margaritas have had super, uh, like they add just so much salt to the edges, but this is like a nice balance.
#
# Segment 105:
# And you always gotta go to the frozen margaritas guys. You can't be having the normal margaritas on tropical islands like this.
#
# Segment 106:
# You gotta get the frozen one to combat the summer heat.
#
# Segment 107:
# And guys just look how beautiful this is the contrast to colors.
#
# Segment 108:
# It's kinda like white sand to turquoise water.
#
# Segment 109:
# And then you have the blue water, like the deep blue, and then the dark blue sky.
#
# Segment 110:
# It is just the perfect recipe for a good day.
#
# Segment 111:
# All right guys done at the pool.
#
# Segment 112:
# When I was walking down here earlier, I saw her on the right side, little koi pond.
#
# Segment 113:
# Look at all these guys, big, some big ones in there as well, but here they're all like gathering over to the side.
#
# Segment 114:
# Maybe they think that I'm gonna feed them or something?
#
# Segment 115:
# No, I don't have any cheese paratha for you guys.
#
# Segment 116:
# I'm sorry.
#
# Segment 117:
# Not here in the Philippines.
#
# Segment 118:
# Unfortunately.
#
# Segment 119:
# I can ship them over to you, maybe like a three day delivery.
#
# Segment 120:
# So I, yeah, hour wait for that, but this is, uh, kind of the main lobby area, again, like just, we're kind of like on the edge of Cebu, so I'm right near the airport, right?
#
# Segment 121:
# Like five minute drive from the airport.
#
# Segment 122:
# So it's kind of just like this one strip of land that separates that side of the ocean and also on that side of the ocean. So you literally have kind of like views everywhere you go in the water here. It's just like literally the perfect like climate, like apparently it's rainy season right now, yesterday was really the only kind of rain that I experience so far, which is just like in the evening time. But apart from that, like the weather is still so like goddamn good here even during the rainy season.
#
# Segment 123:
# So you gonna head up to the room now and I'll give you guys a quick little tour of that one.
#
# Segment 124:
# Uh, pretty nice room.
#
# Segment 125:
# Good view.
#
# Segment 126:
# Nice, uh, nice amenities and whatnot, level five top floor for the king.
#
# Segment 127:
# And, uh, yeah, let's go into the room, Tara na.
#
# Segment 128:
# All right guys.
#
# Segment 129:
# We are back in the room.
#
# Segment 130:
# So as I was saying, $ per night to stay at this place has amazing facilities and everything.
#
# Segment 131:
# The pool, the beach, absolutely incredible private beach access for all hotel guests.
#
# Segment 132:
# But the room is actually really nice room, as you can expect for paying $ per night.
#
# Segment 133:
# So this is kind of like the first, uh, look in point little bit, uh, oversaturated there.
#
# Segment 134:
# So you can't see the view, but I'll show you that in a moment, let's go into the bathroom.
#
# Segment 135:
# You guys all know how much I absolutely love the good old bathroom reviews.
#
# Segment 136:
# Of course, we got the bum gun.
#
# Segment 137:
# Tell you what I was back in Australia a couple weeks ago.
#
# Segment 138:
# And, uh, it is a travesty that we don't have the bum gun in Australia, or it's not like normalized.
#
# Segment 139:
# I don't know.
#
# Segment 140:
# I don't know what the hell people in Australia, the us, all those countries, what are you doing?
#
# Segment 141:
# Adopt the bum gun. You need the bum gun.
#
# Segment 142:
# It is the most practical, efficient thing in the world.
#
# Segment 143:
# I don't know why Australia doesn't have it. but fortunately there is one thing Australia does have, and that is showers, uh, just like everywhere else in the world. But these showers here, guys tell you what, this is actually a very underrated, um, kind of design here, a shower that gets pushed in. So a lot of the shower, uh, doors, they kind of get pushed out and then they collide with the big door.
#
# Segment 144:
# So, you know, little, uh, architectural design there that actually helps the functioning of the bathroom.
#
# Segment 145:
# So got our shower gels, the bad glee Ishka shower, gel conditioner shampoo.
#
# Segment 146:
# And of course got like a stainless steel.
#
# Segment 147:
# Um, shower, head, and you all know how much I love the taps or the shower heads that come from the floor. not, not the floor, come the floor, or we gonna have it down there. Shouldn't straight up at us.
#
# Segment 148:
# No.
#
# Segment 149:
# I mean, from the roof, um, that actually enables it to simulate a rain forest or some rain here in the tropical island of Cebu.
#
# Segment 150:
# So I love that kind of stuff, but more importantly, guys, I have stayed here for a night and big statement here, but this could be the best bum gun I've ever used in my life. That's why I was, uh, raving on about it so much earlier.
#
# Segment 151:
# But look at this, how good is that guys?
#
# Segment 152:
# Perfect radius, perfect strength.
#
# Segment 153:
# And it cleans all the areas that you are in need of.
#
# Segment 154:
# So out for the bun gun.
#
# Segment 155:
# I approve.
#
# Segment 156:
# It is, uh, coming in handy when I need it the most now heading on in to the closet here, we've got two bathrobes. Unfortunately I'm only needing one at this present point in time, but they're still there if you need it.
#
# Segment 157:
# You know, you come back from the beach, you have a shower, you wanna sit on your balcony. You don't wanna come in, your singlet.
#
# Segment 158:
# Or, you know, your, your wet clothes, chop on your bathrobe and enjoy the, uh, enjoy the view, which I will show you in at one second time. Now I checked in yesterday and I slept on that bed and I left this one perfectly, just so you guys could see the, uh, the welcome home, uh, thing made out of, I think, uh, Palm leaves or Palm tree leaves, something like that.
#
# Segment 159:
# But now that I've done this video, I can mess it up.
#
# Segment 160:
# done.
#
# Segment 161:
# You're not welcome home anymore, Luke Uh, but yeah, this is the bed. Uh, we got two beds there.
#
# Segment 162:
# Not really sure what the purpose of that is.
#
# Segment 163:
# I'm only one person and we've got a big couch here that is actually like recently comfy.
#
# Segment 164:
# No, it's not.
#
# Segment 165:
# I thought it was comfortable.
#
# Segment 166:
# Maybe it's comfortable cause there's about , pillows there on it. Uh, giving us a little bit of cushioning, but you know, I guess it serves its purpose.
#
# Segment 167:
# You don't want to be sitting on your bed all day or sitting in the office chair. You can, uh, kind of like lounge back a bit, read your book, uh, watch your Luke Damant, videos, whatever you want in life.
#
# Segment 168:
# Um, but yeah, nice little workstation here with some Molo water.
#
# Segment 169:
# That's actually the name of the hotel.
#
# Segment 170:
# Not sponsored, I'm paying full price for this.
#
# Segment 171:
# And then of course, heading on out to.
#
# Segment 172:
# The balcony, everybody.
#
# Segment 173:
# This is where the fun happens.
#
# Segment 174:
# Nice little drying rack.
#
# Segment 175:
# There.
#
# Segment 176:
# It is super hot when you compare this to the AC room in there, but couple chairs.
#
# Segment 177:
# Uh, but yeah, I'm glad we got the fifth level.
#
# Segment 178:
# Cause we get a view.
#
# Segment 179:
# Of all the water there and all the water on that side, as well as I was saying this kind of stripper land, like the airport is maybe like a couple kilometers that way. And it's just like this big strip of land in either side. It's just like surrounded, uh, with ocean water. So it's a beautiful view, you know, that's the, the checkin area, the reception, there's the koi fish, uh, pond over there.
#
# Segment 180:
# Uh, and you just sort of enter through there.
#
# Segment 181:
# Oh, look, a little Jeepney tricycle tuk tuk combination.
#
# Segment 182:
# I've never seen one.
#
# Segment 183:
# That's like fully enclosed.
#
# Segment 184:
# It's like a tuk tuk, but on a motorbike wheel.
#
# Segment 185:
# Interesting.
#
# Segment 186:
# Um, but yeah, this is the room.
#
# Segment 187:
# Everybody look out just, it is so beautiful.
#
# Segment 188:
# I just, I, I just can't get over it.
#
# Segment 189:
# Honestly.
#
# Segment 190:
# The Philippines, you just continue to impress me.
#
# Segment 191:
# It is God gorgeous out here.
#
# Segment 192:
# So as I was saying, guys, we're gonna be spending a day here. Uh, I'll be doing all the activities, the paddle boarding, the kayaking we'll explore around the area. And, uh, yeah, we'll just bring you along on the journey. So Tara na let's, uh, play the next clip tara na.
#
# Segment 193:
# Well, actually just quickly.
#
# Segment 194:
# I, uh, purposely left these in here from yesterday.
#
# Segment 195:
# I didn't wanna try them out, but there's mini fridge here. Uh, and there's these kind of weird, like interesting, uh, juices of some sort bought a Gatorade. We'll have to, uh, fill up the mini fridge later on with some goodies.
#
# Segment 196:
# There's a down the road, so we we'll go out there.
#
# Segment 197:
# Grab some chocolate, grab some, uh, Coke.
#
# Segment 198:
# Coca-Cola not Coke zero.
#
# Segment 199:
# We can't be, uh, having that kind of stuff in the body, even though Dale would not be too happy with that, but you gotta get the real stuff. You can't be having Coke and, uh, not having the, the, the real deal you can't be having zero sugar.
#
# Segment 200:
# What are we in .
#
# Segment 201:
# Anyways, I'm gonna try this thing.
#
# Segment 202:
# It kind of looks like pineapple juice.
#
# Segment 203:
# Um, looks a little bit fermented at the bottom now, but we will try it out.
#
# Segment 204:
# Okie dokey. Open it up.
#
# Segment 205:
# I think pineapple.
#
# Segment 206:
# Oh no, it's not.
#
# Segment 207:
# It's like it's citrusy and lemony it.
#
# Segment 208:
# It smells like lemon juice or orange, maybe a mixture of the two.
#
# Segment 209:
# Well, it's definitely not orange juice.
#
# Segment 210:
# I'll tell you that much.
#
# Segment 211:
# I think it's just mixed fruit, kind of like.
#
# Segment 212:
# I do not know what this is. I, I don't know.
#
# Segment 213:
# it has like a faint, uh, smell and taste of orange, but it's not like the full flavor that you get when you have orange juice. It does taste actually pretty nice though.
#
# Segment 214:
# So not sure what it is.
#
# Segment 215:
# Maybe if you're a Filipino watching this, have you seen anything like this?
#
# Segment 216:
# Um, here at the Philippines, maybe it's specific to this hotel, but I like it anyways, as I was saying, I'm looking out to the beautiful view.
#
# Segment 217:
# We are going to explore, uh, the rest of the resort and the nearby surroundings.
#
# Segment 218:
# Um, so tara na, let's bring you guys all along with the journey guys again, sorry for the interruption, but I'm feeling incredibly sad because I just finished that last clip about five minutes ago, reviewing the room.
#
# Segment 219:
# And I just realized I didn't do a bed test. I feel like I've lied to you guys. I feel, uh, I feel guilty for not doing the bed test two beds here. And your man can't even do one bed test.
#
# Segment 220:
# So I slept on that bed last night. I haven't even like touched this bed apart from smacking the, uh, the big leaves that were there saying welcome home.
#
# Segment 221:
# Um, so we'll do one here.
#
# Segment 222:
# That one, honestly, last night it was okay. It was pretty hard when I slept on it.
#
# Segment 223:
# I presume this is the same, maybe.
#
# Segment 224:
# Um, but yeah, it was like, okay, it was mediocre. And I, I got rid of the pillows, chucked. 'em over onto the big couch there.
#
# Segment 225:
# Cuz these pillows, I don't know why hotels ever add these ugly pillows.
#
# Segment 226:
# Like just gimme four super soft white pillows.
#
# Segment 227:
# I don't want this ugly artistic design.
#
# Segment 228:
# like, what is this color here?
#
# Segment 229:
# Come on. Like, what is that?
#
# Segment 230:
# It looks like you've used fishing line. That you got from the beach, wrapped it around a couple of chicken feathers.
#
# Segment 231:
# And that's your pillow done?
#
# Segment 232:
# But bed test everybody here in the Philippines in Sibu $ per night, a hotel , , , too hard, too hard.
#
# Segment 233:
# It is so hard.
#
# Segment 234:
# Just the exact same as the other one.
#
# Segment 235:
# Disappointing, to be honest, look like you can just tell this is a hard bed, right?
#
# Segment 236:
# Like just like, listen to that. Look at, listen to that.
#
# Segment 237:
# Thud.
#
# Segment 238:
# I don't know. That's interesting.
#
# Segment 239:
# I've had some really good beds here in the Philippines at the places that I've stayed at there. It's, it's hard, but the pillows, I think they make up for it a little bit. Not as soft as I would like, but I think you get like two. Yeah, this one's a little more softer.
#
# Segment 240:
# This is kind of like the firm one.
#
# Segment 241:
# And then you have these ones that completely useless.
#
# Segment 242:
# So, all right.
#
# Segment 243:
# I promise now after three interruptions, That we are going to go and explore the rest of the area, tara na.
#
# Segment 244:
# Let's do it.
#
# Segment 245:
# All right so we're just walking out of the resort at the moment.
#
# Segment 246:
# Uh, my room is, uh, which one is it somewhere on the top floor there.
#
# Segment 247:
# Uh, but I'm gonna go down to the street here because you can either access like the kind of shopping area from the beach front. Um, but I will actually just like show you the front entry of. I think it's at, oh, actually might just be here. Um, so we'll go in there in a second. All right, here we go.
#
# Segment 248:
# The Moadto strip.
#
# Segment 249:
# I don't have a mask, so I'm not sure how this is gonna end up.
#
# Segment 250:
# Hello, morning. How are you?
#
# Segment 251:
# Thank you.
#
# Segment 252:
# Oh, it's not that busy yesterday afternoon. It was super busy, everybody, I guess.
#
# Segment 253:
# Right now it's like : AM.
#
# Segment 254:
# So things are, uh, slowly, beginning to open up, but it's actually just like such a nice modern kind of, uh, area.
#
# Segment 255:
# It's so beautiful. It's beautiful grass here.
#
# Segment 256:
# The hop, skip jump.
#
# Segment 257:
# But you got so many beautiful restaurants. There's also like a second floor where there's some like, uh, beach cafes, some bars and whatnot, but man, this grass is nice.
#
# Segment 258:
# Super soft, super nice grass.
#
# Segment 259:
# So yeah, maybe later tonight we'll either get some food from here and then bring it back to the hotel room or we can get a, uh, a bit of food, uh, in room dining.
#
# Segment 260:
# But yeah, I think, I think this is, this has nothing to do.
#
# Segment 261:
# With the, uh, hotel.
#
# Segment 262:
# They're not affiliated, I don't believe, or that may be completely incorrect, cuz this is actually, oh, I just trot on that black bit.
#
# Segment 263:
# That is so hot.
#
# Segment 264:
# I may actually be wrong though, because this, um, this right here is actually part of the hotel as well.
#
# Segment 265:
# That is where I had breakfast this morning.
#
# Segment 266:
# Is it connected?
#
# Segment 267:
# No, it is not. Gee I'm lucky.
#
# Segment 268:
# I don't have a room over there.
#
# Segment 269:
# That would be absolutely horrible.
#
# Segment 270:
# So yeah.
#
# Segment 271:
# Completely different entities.
#
# Segment 272:
# We got the hotel room, we got the hotel establishment and then the Moadto - Oh it's Moadto strip right towards the beach.
#
# Segment 273:
# So let's go, uh, Oh, look at that thing.
#
# Segment 274:
# there's so many just cool, like little things on this beach.
#
# Segment 275:
# Let's go check that out.
#
# Segment 276:
# So again, I don't know if this is public or like, I think actually this is storm, so which one's storm, maybe one of the ones up on the roof, but I know that area is specifically for, uh, here. You can see there's a sign there exclusive for Modala guests only, but look at this, a USA army truck or something that is so sick.
#
# Segment 277:
# Wonder if we're allowed in, I guess so.
#
# Segment 278:
# Ah, where are the keys mate?
#
# Segment 279:
# Honk honk.
#
# Segment 280:
# This is actually so cool.
#
# Segment 281:
# Look at all the gears four drive low drive.
#
# Segment 282:
# We've got a couple of masks, down there.
#
# Segment 283:
# How many kilometers?
#
# Segment 284:
# Only , kilometers. Oh my God.
#
# Segment 285:
# That is crazy. That is so sick.
#
# Segment 286:
# I don't know if it is like a souvenir or what actually, what is the purpose of this, but either way, it looks super cool. As I was saying earlier in the day, though, guys, yesterday evening, this was just like all sand for like, like a hundred meters. So the tides here of like the depth of the ocean on the bank is just like, it's all flat. So when the tide does come in, it's like super, super low and super high.
#
# Segment 287:
# Oh, that's so gorgeous.
#
# Segment 288:
# Just literally clear water.
#
# Segment 289:
# You can see it all the way through.
#
# Segment 290:
# It's crazy.
#
# Segment 291:
# Hello, where can I get a towel from?
#
# Segment 292:
# Oh, he's oh, he's bringing some. Oh, what else you got?
#
# Segment 293:
# Jet skis. Horseback riding.
#
# Segment 294:
# Oh, you have horses? Yeah.
#
# Segment 295:
# Where are they? They're here.
#
# Segment 296:
# There.
#
# Segment 297:
# Ah, how much does it cost?
#
# Segment 298:
# One thousand five hundred.
#
# Segment 299:
# Oh, that's good price.
#
# Segment 300:
# It'll be criminal.
#
# Segment 301:
# Uh, not to get a horse later this evening.
#
# Segment 302:
# Maybe you can do it in high tide or you have to wait till low tide, Yeah. Yeah, you can do any time?
#
# Segment 303:
# Only for low tide sir.
#
# Segment 304:
# So this afternoon. Okay.
#
# Segment 305:
# Maybe we'll do that.
#
# Segment 306:
# So many cool things, but the, the paddle boarding and kayaking is free.
#
# Segment 307:
# Yeah. Okay, perfect.
#
# Segment 308:
# Maybe I'll I'll wait over at the beach.
#
# Segment 309:
# Thank you.
#
# Segment 310:
# Lots of activities that you can do.
#
# Segment 311:
# Plenty of fun for the day.
#
# Segment 312:
# The good thing is with the horseback riding is that it's a fixed price.
#
# Segment 313:
# You're not getting three tarzan at the end of your ride, or at least you hope not. Anyways, let's wait for a towel.
#
# Segment 314:
# And, uh, yeah, look so yesterday, as I was saying, it's, it's just crazy.
#
# Segment 315:
# Like this volleyball net was like in the, like middle of the beach, but it's just changed so much with the high tide.
#
# Segment 316:
# Fascinating.
#
# Segment 317:
# Honestly, I don't think there is many better things in life as getting into the ocean in super crystal clear water and uh, yeah, like it's getting, it's kind of just like, oh look, little fishy. It's kind of like just staying at this knee length or this knee height have water, but this is just unbelievable. This is just absolutely gorgeous, such an amazing place to stay right by the beach. This could be, uh, honestly, one of my top, uh, places I've stayed, but it is such a vibe. The Palm trees, there's all the, the bridesmaids for that wedding that I was mentioning earlier is just absolutely perfect.
#
# Segment 318:
# Seriously.
#
# Segment 319:
# I'm frosting it. I'm frothing. I love this.
#
# Segment 320:
# We've been walking for a couple minutes. We're about like meters offshore and it just keeps going.
#
# Segment 321:
# Same height.
#
# Segment 322:
# We're at like waist level at the moment.
#
# Segment 323:
# Oh, we're actually, we're reaching some, some seaweed now.
#
# Segment 324:
# Oh, it's actually, it's getting deeper. It's deceptively deeper.
#
# Segment 325:
# Now the water is like, literally so clear that it looks like it's shallower here, but I'm slowly getting submerged to neck height.
#
# Segment 326:
# Oh my God.
#
# Segment 327:
# I, when I was walking here, I was like, oh, it looks like it's getting shallow.
#
# Segment 328:
# It must be like a, a little bit of a sand bank here, but I'm almost fully submerged.
#
# Segment 329:
# This is so deep.
#
# Segment 330:
# It's so deceptive. Wow.
#
# Segment 331:
# Just so beautiful guys.
#
# Segment 332:
# Excuse me, ladies. Over there.
#
# Segment 333:
# The water may be getting a little bit warmer shortly, if you know what I mean, cuz I'm peeing.
#
# Segment 334:
# uh, you know, there's two types of people in this world, people that pee in the shower and people that lie about it oh my God, this is just absolute paradise.
#
# Segment 335:
# This is just incredible.
#
# Segment 336:
# I'm thoroughly enjoying this guys.
#
# Segment 337:
# You know, a lot of the hotel videos.
#
# Segment 338:
# They're, they're fun. They're fun to do the luxury ones, but I'm actually very, uh, content right now.
#
# Segment 339:
# I think it's just because we're by the ocean. This is like one of the first, uh, places that I've stayed at right by the ocean that I've actually filmed. and the fact that you just have like beach access, you walk like about meters from your hotel room to the beach.
#
# Segment 340:
# It makes an Aussie that grew up on the beaches, incredibly happy.
#
# Segment 341:
# Just one, please. Thank you. All right, let's do this.
#
# Segment 342:
# All right. Jet ski.
#
# Segment 343:
# Hey brother.
#
# Segment 344:
# Can I please do, um, what is the difference between beginner and advanced jet ski?
#
# Segment 345:
# Uh, the, difference sir is the beginner is, uh, low power.
#
# Segment 346:
# Oh, low power.
#
# Segment 347:
# Uh, it is, uh, a different one?
#
# Segment 348:
# - Same, same.
#
# Segment 349:
# Oh, same, but it is different power.
#
# Segment 350:
# All right.
#
# Segment 351:
# Well, I will, uh, so what we got advanced one hour, is it like, is it a big difference between beginner and advanced.
#
# Segment 352:
# So you think I should do advanced or beginner?
#
# Segment 353:
# - Up to you. All right.
#
# Segment 354:
# I like to go fast.
#
# Segment 355:
# Uh, we do, um, I'll do the advanced minutes jet ski, please.
#
# Segment 356:
# I can just do for my room, right? I can, uh - Room charge?
#
# Segment 357:
# Yeah yeah. That's okay?
#
# Segment 358:
# All right guys.
#
# Segment 359:
# So , pesos that's around $ us.
#
# Segment 360:
# The exchange rate is like pesos to a dollar.
#
# Segment 361:
# So you just kind of double it.
#
# Segment 362:
# It is by myself or somebody comes with me.
#
# Segment 363:
# Somebody here, if you want. Oh, who, who will come?
#
# Segment 364:
# Can I go by myself?
#
# Segment 365:
# That's okay.
#
# Segment 366:
# Not a first timer sir?
#
# Segment 367:
# No, not jet ski.
#
# Segment 368:
# I've done before I did it in Pakistan.
#
# Segment 369:
# Oh, perfect.
#
# Segment 370:
# Um, out there. Yeah, maybe.
#
# Segment 371:
# Ah, yeah. Jet ski.
#
# Segment 372:
# Yeah, you can leave there.
#
# Segment 373:
# Thank you. So.
#
# Segment 374:
# All right safety precautions are done.
#
# Segment 375:
# Let's go. What's your name?
#
# Segment 376:
# Lito. Lito. Yeah.
#
# Segment 377:
# You are the jet ski expert?
#
# Segment 378:
# Not, not really. Not really.
#
# Segment 379:
# That's not what I want to hear. You're meant to be an expert.
#
# Segment 380:
# All right. Here we go.
#
# Segment 381:
# Kawazaki.
#
# Segment 382:
# So I remember when I was in Pakistan in lake Attabad, we had like the two options.
#
# Segment 383:
# We had the Kawazaki, which was considered this like the Japanese brand, which it is, or then you had the local, uh, brand and like the Kawasaki was so much more expensive.
#
# Segment 384:
# Um, so I think we got the local one.
#
# Segment 385:
# It still went pretty fast though.
#
# Segment 386:
# Uh this is, low power. And this is the high power. Ah, so it's different key for the power.
#
# Segment 387:
# I was wondering how that worked.
#
# Segment 388:
# So it's so important.
#
# Segment 389:
# I hop on. Yeah. Okay.
#
# Segment 390:
# Wait, so you were coming with me or I'm going by myself.
#
# Segment 391:
# You by myself.
#
# Segment 392:
# Okay, good. Yeah.
#
# Segment 393:
# So how will I know? minutes.
#
# Segment 394:
# You will call me back? You want to test this one?
#
# Segment 395:
# Uh, can I switch outside?
#
# Segment 396:
# Yeah. Yeah.
#
# Segment 397:
# Just, uh, try to select this is the high power.
#
# Segment 398:
# Okay.
#
# Segment 399:
# And then if you want to use this one.
#
# Segment 400:
# Yeah, yeah. Uhhuh change.
#
# Segment 401:
# Okay. I start with the yellow.
#
# Segment 402:
# This is start. Yep.
#
# Segment 403:
# - This is a start. Yep.
#
# Segment 404:
# - Stop. Yep.
#
# Segment 405:
# - And then accelerator.
#
# Segment 406:
# There's no brake, right?.
#
# Segment 407:
# No, no brake, sir. Okay.
#
# Segment 408:
# Reverse. Ah, okay, perfect.
#
# Segment 409:
# So I start, start. Okay.
#
# Segment 410:
# Oh, all right. Thank you.
#
# Segment 411:
# We are off and racing everybody.
#
# Segment 412:
# Oh my God. These are fun.
#
# Segment 413:
# Haha. Oh yeah. Wow.
#
# Segment 414:
# I haven't rid the jet ski by myself ever.
#
# Segment 415:
# This is just pure bliss.
#
# Segment 416:
# Oh my God. It is fast.
#
# Segment 417:
# Oh yeah.
#
# Segment 418:
# This is low power as well.
#
# Segment 419:
# And it's fast. Oh my God.
#
# Segment 420:
# Look how pretty.
#
# Segment 421:
# This is everybody. Oh, my God.
#
# Segment 422:
# We're about to lose my hat. Wow guys, this is incredible.
#
# Segment 423:
# I didn't know how fun jet skis were.
#
# Segment 424:
# All right, let's stop this. Let's uh, put in the high key, baby.
#
# Segment 425:
# We're not here to go slow. We're here to get, oh no.
#
# Segment 426:
# Do I not put it in, right?
#
# Segment 427:
# Maybe it's the other way There we go.
#
# Segment 428:
# All right guys.
#
# Segment 429:
# I'm honestly, oh God, it is so much faster.
#
# Segment 430:
# Oh my God.
#
# Segment 431:
# The I'm putting, I'm taking my hat off.
#
# Segment 432:
# The difference is insane.
#
# Segment 433:
# Literally insane.
#
# Segment 434:
# Look how much like recoil layers.
#
# Segment 435:
# Oh my God Guys its so fast.
#
# Segment 436:
# Like I literally, this is crazy.
#
# Segment 437:
# Look how blue the water is.
#
# Segment 438:
# Oh my god.
#
# Segment 439:
# I lost my hat. I lost my hat. I lost my hat.
#
# Segment 440:
# My hat is over there.
#
# Segment 441:
# Guys we hit kilometers an hour.
#
# Segment 442:
# Oh no. Oh no.
#
# Segment 443:
# I went over my hat. All right I see my hat.
#
# Segment 444:
# I need to get it before it sinks. I don't really want to jump off this thing.
#
# Segment 445:
# Because then it could be a recipe for disaster.
#
# Segment 446:
# Come on. There we go.
#
# Segment 447:
# All right hat is secure guys.
#
# Segment 448:
# When I say this is fast, like I've rid motorbikes.
#
# Segment 449:
# I have my motorbike license. I used to have a motorbike at home.
#
# Segment 450:
# Uh, but this like the acceleration on this thing is absolutely Ludricous .
#
# Segment 451:
# Like ridiculous.
#
# Segment 452:
# Like there's actual G force on this thing.
#
# Segment 453:
# Oh my God. This is crazy.
#
# Segment 454:
# Absolutely ridiculous.
#
# Segment 455:
# You know?
#
# Segment 456:
# Oh guys, I'm actually just shocked at how much power this thing has.
#
# Segment 457:
# Like - Wow. Oh, my God.
#
# Segment 458:
# I, I got so scared that I went over my own wave. I tried to go on the outside of it, but I, it, it caught up to me. It is ridiculous how fast this thing is.
#
# Segment 459:
# Wow.
#
# Segment 460:
# I don't know how jet skis are measured.
#
# Segment 461:
# I know like motorbikes at.
#
# Segment 462:
# Maybe this is horsepower, but it is just ridiculous at the power that this thing has just look how beautiful the views are.
#
# Segment 463:
# Everybody like the water is just so clear.
#
# Segment 464:
# Well look at these beautiful like rock formations on the outside.
#
# Segment 465:
# I'm sure that we some like fish around, um, the, oh my God.
#
# Segment 466:
# All right.
#
# Segment 467:
# I think our minutes is up.
#
# Segment 468:
# I should really head back and just see how much longer we have back we go.
#
# Segment 469:
# I gotta be careful here.
#
# Segment 470:
# Just cause it's like, so shallow, lucky, like jet skis.
#
# Segment 471:
# They're not power by all right.
#
# Segment 472:
# We still got six minutes.
#
# Segment 473:
# He gave me the, the, uh, the thumbs up or saying six minutes or whatever.
#
# Segment 474:
# So we're gonna absolutely pin it outta here. I'll put you guys in my life jacket so I can have both hands.
#
# Segment 475:
# We'll do a donut, oh actually we'll go where the water's calm. All right, we'll do a donut here.
#
# Segment 476:
# Woohoo. Oh my God.
#
# Segment 477:
# This is just ridiculous.
#
# Segment 478:
# They're doing, uh, Oh, there's a flying fish.
#
# Segment 479:
# Hello? I, I saw a flying fish.
#
# Segment 480:
# These guys are doing super scuba diving.
#
# Segment 481:
# I literally saw a flying fish.
#
# Segment 482:
# Ah, we're low on fuel. Look fuel down.
#
# Segment 483:
# We've been shredding too much, or maybe that's the indicator of, uh, minutes.
#
# Segment 484:
# Damn.
#
# Segment 485:
# That was incredible guys.
#
# Segment 486:
# Good. We're coming into shore.
#
# Segment 487:
# Wow. It is very fast.
#
# Segment 488:
# like incredibly fast.
#
# Segment 489:
# Oh, it's just, thank you.
#
# Segment 490:
# This is how you know it's time because the fuel?
#
# Segment 491:
# - No. Oh, so it was - Yeah.
#
# Segment 492:
# All right.
#
# Segment 493:
# Brother thank you so much.
#
# Segment 494:
# That was so much fun.
#
# Segment 495:
# Gee, we should have done the kayaking first.
#
# Segment 496:
# I don't know how anything's gonna beat that now.
#
# Segment 497:
# Hey, very good. That's so much fun. It's so fast.
#
# Segment 498:
# Yeah, I should put, I'll put the here, uh, room number, sir.
#
# Segment 499:
# Uh, . Thank you so much.
#
# Segment 500:
# I'm back at the pool. I just realized I left my hat downstairs at the beach.
#
# Segment 501:
# All right. Got the hat.
#
# Segment 502:
# Let's go for another swim.
#
# Segment 503:
# All right back at the room guys.
#
# Segment 504:
# It is, uh, around like : PM. I think it is, uh, :.
#
# Segment 505:
# It is damn hot outside.
#
# Segment 506:
# Um, so I'm seeking cover in the AC for a little bit.
#
# Segment 507:
# We'll chill out when it cools down in the afternoon.
#
# Segment 508:
# We'll uh, explore some more areas out in the paradise.
#
# Segment 509:
# Absolutely loving the vibe here.
#
# Segment 510:
# Just Palm trees, all that good stuff.
#
# Segment 511:
# So much greenery, so much blue.
#
# Segment 512:
# It is, uh, yeah, the perfect combinations to, uh, have a good time here.
#
# Segment 513:
# So tara na.
#
# Segment 514:
# We'll uh, see you later this afternoon.
#
# Segment 515:
# All right.
#
# Segment 516:
# So it's around : at the moment, had a quick little nap and got a red bull for, uh, some energy, but we're backed down at the beach.
#
# Segment 517:
# So this is the, the Moadto strip that I was speaking about.
#
# Segment 518:
# When I was mentioning saying that yesterday, it was super busy. It just clocked in my mind yesterday was a Sunday. So obviously it was a weekend. Today is Monday and the resort that I was staying at, uh, and just this whole area, it's so much quieter on a, uh, on a weekday.
#
# Segment 519:
# So it's good.
#
# Segment 520:
# When you hear, especially on a Monday after it's really busy, uh, during the weekend, but the tide is starting to come out like, uh, it's going into low tide, so you can see, like, that's what I was saying about all the boats.
#
# Segment 521:
# There's a couple boats in there that are literally beached.
#
# Segment 522:
# The jet skis are beach.
#
# Segment 523:
# Uh, there's no, uh, you're not gonna be able to drag those jet skis through meters of sand to get to the deeper water. Um, but yeah, we're just gonna roam around the evening.
#
# Segment 524:
# Enjoy the, uh, the cooler weather with a little bit of red, red bull for some caffeine, but you can tell every single afternoon and evening, uh, in the Philippines is always a lot more cloud cover, especially in the rainy season. So we, uh, are expecting probably a little bit of rain in the next hour or two, uh, given the cloud formation.
#
# Segment 525:
# So.
#
# Segment 526:
# Let's enjoy the sun while we have it, I suppose let's do it.
#
# Segment 527:
# So yeah, all of this, just like a couple hours ago was all underwater and these are all like little crab holes and these little, uh, bits of small rolls of sand have been crabs that have, oh, look, there's crab right there.
#
# Segment 528:
# Is he dead?
#
# Segment 529:
# I don't know. He's not moving.
#
# Segment 530:
# He must to be dead, but all these crabs, I think have dug little holes. Sort of rolled up the little bits of sand, but they are everywhere. It's so like satisfying walking on this soft little bit of sand here and look at all these like little squiggly ones. They're like little, uh, dog poos.
#
# Segment 531:
# that is so funny.
#
# Segment 532:
# Anyways, we're gonna walk up this way. I haven't walked up this side yet, so, uh, we'll go and do that.
#
# Segment 533:
# Yeah.
#
# Segment 534:
# So all these holes here, there's all just like crab holes.
#
# Segment 535:
# So give you like kick over where the mounds are.
#
# Segment 536:
# You can see little holes of crabs that have gone in like this one here.
#
# Segment 537:
# It's a crab hole. That one there, another crab hole.
#
# Segment 538:
# It's crazy.
#
# Segment 539:
# All this has just been done.
#
# Segment 540:
# Since the tide's gone out.
#
# Segment 541:
# Look, that's a big one.
#
# Segment 542:
# Massive crab in there.
#
# Segment 543:
# Surely it's a huge hole.
#
# Segment 544:
# Anyways.
#
# Segment 545:
# We'll stop disturbing the wildlife and we'll make our way down here.
#
# Segment 546:
# Whoa. Look at this.
#
# Segment 547:
# A massive jellyfish.
#
# Segment 548:
# I'm not gonna touch it cuz you never know.
#
# Segment 549:
# If, uh, they're poisonous or whatnot, there's a couple of jellyfish, um, in Australia that are really, really dangerous box jellyfish, IgE, tiny little ones, but usually the big ones they're not too, too dangerous.
#
# Segment 550:
# So maybe, I don't know. I don't even want to, I don't wanna risk it.
#
# Segment 551:
# who knows what's out here in the Philippines that can get you killed, could be a massive venomous jellyfish that you die instantly.
#
# Segment 552:
# And, but it's so cool.
#
# Segment 553:
# Just coming down to the wildlife here and as the tide goes out and just seeing what was under the ocean, uh, previously, but here here's another one over here.
#
# Segment 554:
# This poor little guy he's gotten stuck.
#
# Segment 555:
# I don't really know what else I can do for you, buddy, but I'll give you some more water.
#
# Segment 556:
# Yeah, they, they just get caught in the tide because it goes out so rapidly. There's no way that they can get out and they probably just get roasted in the sun.
#
# Segment 557:
# Hello?
#
# Segment 558:
# What are you searching for?
#
# Segment 559:
# Oh, worms. Whoa. Oh.
#
# Segment 560:
# Oh, you have one? Oh my God.
#
# Segment 561:
# No, no. Oh no. What is that?
#
# Segment 562:
# Oh, it's a stick.
#
# Segment 563:
# What is, this is worm?
#
# Segment 564:
# And you find them in. Sand.
#
# Segment 565:
# Yeah. Oh, wow. Try.
#
# Segment 566:
# You can eat? Really? Yeah.
#
# Segment 567:
# You cook or you eat raw?
#
# Segment 568:
# Delicious masarap? All right.
#
# Segment 569:
# See, look at this little guy.
#
# Segment 570:
# He was running around my feet.
#
# Segment 571:
# Look at him. Look how fast they are down.
#
# Segment 572:
# Boy, go on quick, quick, quick run, run, run.
#
# Segment 573:
# no, that's so agile. It's crazy. Now he's playing.
#
# Segment 574:
# Daddy thinks that I don't see him in the sand.
#
# Segment 575:
# They camouflage really well though.
#
# Segment 576:
# Perfect color against the sand.
#
# Segment 577:
# You see a couple of them.
#
# Segment 578:
# When you walking by, they kind of feel your foot steps underneath, run off into their little holes.
#
# Segment 579:
# It's hundreds down there.
#
# Segment 580:
# Guarantee it everywhere.
#
# Segment 581:
# Well, I just noticed here, I saw one starfish and I started to look closer and there's literally like hundreds and hundreds of starfish just around.
#
# Segment 582:
# Look how big they are. They're moving.
#
# Segment 583:
# I didn't know.
#
# Segment 584:
# They moved that fast. Jeez, they're flying.
#
# Segment 585:
# But in this, this little area here.
#
# Segment 586:
# Oh look, you can see, this is where they previously were or is that that?
#
# Segment 587:
# Oh, that's one now. Oh, I thought that was like the out mark of another one.
#
# Segment 588:
# So, wow.
#
# Segment 589:
# There's so many here. They're all under the sand. Some have moved, I think.
#
# Segment 590:
# Yeah so that one, there was the outline there of one, but they made their way into the water, but just look how cool that is.
#
# Segment 591:
# Ooh.
#
# Segment 592:
# there are hundreds and hundreds of them.
#
# Segment 593:
# I don't, I don't wanna tread on.
#
# Segment 594:
# But yeah, you can see like the out outline of them.
#
# Segment 595:
# They've obviously realized that they're gonna end up here for a couple hours stuck in the sun.
#
# Segment 596:
# So they make their way over into, into the water.
#
# Segment 597:
# That's so cool. Those are really cool.
#
# Segment 598:
# Kind of like beach restaurant, they got music blaring on the speaker.
#
# Segment 599:
# We better stay away.
#
# Segment 600:
# So we don't get copyrighted but, uh, maybe that will be the move coming, uh, here.
#
# Segment 601:
# Later tonight for like a dinner on the beach.
#
# Segment 602:
# Uh, or maybe even my hotel.
#
# Segment 603:
# I think actually my hotel maybe has, uh, a few seats on the beach area that you can use to, uh, to eat your dinner at, which would be beautiful, you know, as long as it's not raining. But I think, I don't know, starting to get a little bit more gray, so the rain might be coming soon.
#
# Segment 604:
# Oh my goodness.
#
# Segment 605:
# Do you guys see what I see?
#
# Segment 606:
# Look at that.
#
# Segment 607:
# It's darling, the tarzan horse, but the brown version darling was white in, uh, Karachi, but now he's brown.
#
# Segment 608:
# What do you do with the jet ski now?
#
# Segment 609:
# It's beach. It goes up?
#
# Segment 610:
# Yeah yeah. Ah, so you have to push it up.
#
# Segment 611:
# Yeah.
#
# Segment 612:
# And then where does it go up there? Up there?
#
# Segment 613:
# Ah, it's too heavy. It's too heavy.
#
# Segment 614:
# You need, uh, big muscles.
#
# Segment 615:
# Yeah.
#
# Segment 616:
# Do you need, you need, do you need my help?
#
# Segment 617:
# Uh three tarzan behind me, jet ski, man behind me and a beautiful ocean view.
#
# Segment 618:
# Does it get much better than that?
#
# Segment 619:
# Oh, she's getting a three tarzan ride.
#
# Segment 620:
# Watch out.
#
# Segment 621:
# It should only be doso don't pay anything more.
#
# Segment 622:
# Just for context, the volleyball net.
#
# Segment 623:
# Remember how I was saying like five hours ago, it was like literally up to like knee length. Now it's like completely beach and you can actually play volleyball.
#
# Segment 624:
# So that just gives you an idea of how much this tide actually comes out.
#
# Segment 625:
# From the land.
#
# Segment 626:
# It's just so shallow. It's crazy.
#
# Segment 627:
# Look at this guy.
#
# Segment 628:
# This guy's got a crab in his nippers.
#
# Segment 629:
# He's moving.
#
# Segment 630:
# So look, buddy, you dropped your, you dropped your crab mate.
#
# Segment 631:
# Here you go. Have it back.
#
# Segment 632:
# He's just there. Yeah.
#
# Segment 633:
# I left it for you. I'll leave you alone. You can go back.
#
# Segment 634:
# It's so fun.
#
# Segment 635:
# Just playing with the wildlife here and seeing everything.
#
# Segment 636:
# I love this kind of stuff.
#
# Segment 637:
# Hello. Where are you from sir?
#
# Segment 638:
# Australia. Thank you.
#
# Segment 639:
# Oh you drinking red horse? Yeah, want some beer?
#
# Segment 640:
# Sure.
#
# Segment 641:
# Oh, it's big bottle. Oh my goodness.
#
# Segment 642:
# Is this your boat?
#
# Segment 643:
# No, the, uh, other one.
#
# Segment 644:
# Oh, the other one. Yeah.
#
# Segment 645:
# Uh, you're looking for the boat?
#
# Segment 646:
# Oh no. Tomorrow I'm leaving.
#
# Segment 647:
# I fly back to Manila.
#
# Segment 648:
# Oh, okay.
#
# Segment 649:
# But thank you for the red horse.
#
# Segment 650:
# Did you visit already Virgin island?
#
# Segment 651:
# No, not yet.
#
# Segment 652:
# Just like five minutes from here.
#
# Segment 653:
# Oh, on the boat? Yeah.
#
# Segment 654:
# You can, uh, witness the sandbar out there.
#
# Segment 655:
# The sand bar. Yeah.
#
# Segment 656:
# Long white sandbar.
#
# Segment 657:
# Ah, and there's like fishing stuff or it's just sand.
#
# Segment 658:
# Just sand. Yeah, just sand.
#
# Segment 659:
# But this place was good for snacking.
#
# Segment 660:
# Yeah, maybe I'll take the ice out. Oh, you don't need the ice.
#
# Segment 661:
# Okay. Okay.
#
# Segment 662:
# Because sometimes the water is not good.
#
# Segment 663:
# Yeah yeah. Yeah.
#
# Segment 664:
# for like foreigner for you guys.
#
# Segment 665:
# It's okay. Yeah. Oh, nice.
#
# Segment 666:
# What's your name?
#
# Segment 667:
# Joseph. Joseph. I'm Luke.
#
# Segment 668:
# Luke. Nice to meet you.
#
# Segment 669:
# You're just alone going here?
#
# Segment 670:
# Yeah, just here for a few weeks.
#
# Segment 671:
# Ah, okay. Travel.
#
# Segment 672:
# So how's the weather condition in Australia?
#
# Segment 673:
# Cold, cold, like degrees.
#
# Segment 674:
# a lot better here. It's nice.
#
# Segment 675:
# Yeah, you can, even though it's rainy season, it's still, you can have good weather.
#
# Segment 676:
# There's a private beach there.
#
# Segment 677:
# Oh, up here. Yeah.
#
# Segment 678:
# Then you can see the sunset, uh, over on that side.
#
# Segment 679:
# Yeah, yeah, yeah.
#
# Segment 680:
# Maybe I'm I'm going that direction.
#
# Segment 681:
# So, uh, okay.
#
# Segment 682:
# You just bring slippers cause uh, the way going out there is not really safe. Ah it's it's like hard. No, there's some rocks, so - I'm Australian we don't wear shoes. Ah we have like always barefoot.
#
# Segment 683:
# Okay. Do you need slippers?
#
# Segment 684:
# Or you are yeah. Used to it.
#
# Segment 685:
# You just go in the white sand, wait, Yeah. But if you just pass, like where's, the horses are going there, so, oh. That's where the horses are going.
#
# Segment 686:
# Ah, I see.
#
# Segment 687:
# ...
#
# ==== Transcript for Video Id: y9xOKcZD0xE ====
#
# Segment 1:
# We are gonna fly to the Philippines we had seats in the middle, not the best ones But they moved us to emergency exit wide place, places for each For Vania and me and there's a white girl she also got this place it's because we're white no no no because the plane will crash and we will need to open these doors we might to survive, because we are white actually, we have to help others to evacuate those who sit here no, that’s because we must survive that we might be saved it is important to read this thing some instruction especially this one, right wait, sorry, this is my magazine here it is we will learn all this and we'll jump on this thing where did you get the information that this plane is going to crash?
#
# Segment 2:
# I know!
#
# Segment 3:
# why else they put us here? otherwise, why they gathered all us together?
#
# Segment 4:
# the island called us we were instructed... she knows something I do not understand anything but she knows that the plane will crash you should have heard her she came and said You need to learn how to open the door just in case it's cool I like the flight Vania likes to die no, we'll save everybody everybody?
#
# Segment 5:
# or kill everybody So wet! So hot We still have so much cloths on!
#
# Segment 6:
# now I'm not cold We spent the night at the airport went outside - the rain comes but hot the air is very humid it's hard to breathe but Ivan likes it is so soft and warm and according to the forecast it’s gonna be rain for three days we go to eat to eat! first impressions Philippines is a country of Filipinos I've seen a lot of Filipinos in Hong Kong but here literally everyone is Filipino! and authentic… these ones… minibus it's just the tuk-tuk and minibuses are cool we met some beggars our first meal in the Philippines we came to some... I do not dare to call it a cafe a yard with kids pesos for the local portion it is exactly us dollar.
#
# Segment 7:
# Exactly!
#
# Segment 8:
# Not that much but potatoes with meat, rice and here's the minibus looks like that cool, isn't it?
#
# Segment 9:
# Suddenly we were on the cemetery I don't know is there ash or bones inside Or a body completely Don’t know A car squirted us!
#
# Segment 10:
# so Ivan grabbed the coconut under a palm tree around if they’ll squirt us next time he will throw a coconut another coconut!
#
# Segment 11:
# Don’t you dare do it again!
#
# Segment 12:
# hi!
#
# Segment 13:
# pesos for a ride in metro Terminal gave me This broken card but price is very fair WTF watch, look!
#
# Segment 14:
# let's put another bag there what the hell at all?
#
# Segment 15:
# we waited there, the train came here he's kind of short in the Philippines we can eat enough it costs meat, eggs, rice Some sauce I ate two pies for pesos each we are traveling in this...
#
# Segment 16:
# I don't know what to call it... Not a bus… Not a jeep as well… and how much for a ride, bro?
#
# Segment 17:
# "jeepneys".
#
# Segment 18:
by boiling and then by sauteing them in the pan so those of you who love seafood they would love to see this scene right now of shrimpies i think it's made up of garlic yeah it's sorted with garlic yeah so there's something still left guys i don't know what it is they're going to surprise now so still more garlic is going on so those of you who love the dragon breath smell of garlic and along with this they'll be even giving you dipping sauce i think some dipping sauce so that you can dip your things in that only the food nothing else don't take it to the wrong way so now came the lechon so what is this called lechon yeah the lecture on roll and as i've been told earlier that the le ...
#
# ==================================================
#
# ==== Transcript for Video Id: zwOJjQuL4i4 ====
#
# Segment 1:
# It's my first time seeing this... and I see this with you... Don't be long... Why I really like seeing a man's body from behind... Because it looks like broad and certainly handsome guys... Lots of decoration like stars... like smiley emojis... Their style is nuanced in black and white... I really love it when they shake their bodies like this... Whoa...Stell's face is so handsome here... Woww...Their aura is the same as BTS... Really cool... I love Stell's black hair colour here... Looks more handsome...
#
# Segment 2:
# Oh...I want to watch their concert live...
#
# Segment 3:
# Ouch...There's a woman blocking...
#
# Segment 4:
# They remain powerful... In every appearance, they're always powerful...
#
# Segment 5:
# then...I really like their style...
#
# Segment 6:
# I've never seen their style complicated... Their style is simple and pleasing to the eye... Who is this?
#
# Segment 7:
# Justin...right?
#
# Segment 8:
# Still my favorite is Sejun and Stell... Gosh...Stell is really handsome here with his black hair... See...Really Powerful... Among them, people wear black long jeans... and... people wear white long jeans... Gosh...
#
# Segment 9:
# I feel like watching their concert live guys... Amazing...My goodness... For me, my goodness they're so cool... They can already be aligned with BTS... Because of any dance they can do it...My goodness... and in their every move, when they bring a song or dance cover is always powerful... Gosh...Full of energy... then here, as usual I always focus on my favorites "Sejun and Stell" and here, I really love seeing Stell... Stell with his black hair... As usual too, I always like their style I've never seen SB style complicated... Their style is always simple and really pleasing to the eye...
#
# Segment 10:
# Here seems to be dominated by black and white colour...
#
# Segment 11:
# Earlier, there were some who wear black long jeans... and there were people wear white long jeans...
#
# Segment 12:
# Gosh...I feel like watching their concert live...
#
# Segment 13:
# When do they have a concert in Indonesia?
#
# Segment 14:
# Oh...I want to watch their live while carrying their photos...
#
# ==================================================

# %% [markdown]
# ### Feed segments to BERTopic

# %%
import pandas as pd
import re
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = nltk.WordNetLemmatizer()

def preprocess_segments(text):
    """Apply basic text preprocessing steps."""
    text = text.lower()  # Lowercasing
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation & special characters
    words = word_tokenize(text)  # Tokenization
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # Remove stopwords & lemmatize
    return ' '.join(words)

# Apply preprocessing directly to 'Segment' column
segmented_df["Segment"] = segmented_df["Segment"].apply(preprocess_segments)

segmented_df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/josephmiguela.maristela/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/josephmiguela.maristela/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/josephmiguela.maristela/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#          Video Id  Segment #  \
# 0     MBtWxCM7NYg          1
# 1     MBtWxCM7NYg          2
# 2     O0cIJww_amw          1
# 3     O0cIJww_amw          2
# 4     O0cIJww_amw          3
# ...           ...        ...
# 6696  REvaHqT3uro         24
# 6697  REvaHqT3uro         25
# 6698  REvaHqT3uro         26
# 6699  REvaHqT3uro         27
# 6700  REvaHqT3uro         28
#
#                                                 Segment
# 0     go plan like going get real bad got real bad t...
# 1     australia pretty expensive cheapest option pro...
# 2                                       talked filipina
# 3                                       said like asked
# 4                               said accent accent like
# ...                                                 ...
# 6696  liter per person basically put almost got two ...
# 6697                                                 oh
# 6698  look like building brand new spa right seems l...
# 6699                                      hello el nido
# 6700  guy got rainbow distance know see camera got k...
#
# [6701 rows x 3 columns]

# %%
# BERTopic on Segmented Transcripts

from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

from bertopic.representation import KeyBERTInspired

# Load multilingual embedding model
embedding_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# KeyBERT
keybert_model = KeyBERTInspired()

# Initialize BERTopic with the multilingual embedding model
topic_model = BERTopic(
    embedding_model=embedding_model, 
    language="multilingual", 
    representation_model=keybert_model,  # Improve topic descriptions
)

# Extract segments and their corresponding Video Ids
segments = []
video_ids = []

for idx, row in segmented_df.iterrows():
    segments.append(row['Segment'])
    video_ids.append(row['Video Id'])

# Fit the BERTopic model
topics, _ = topic_model.fit_transform(segments)

# %%
# INITIAL

topic_model.get_topic_info()
# Out:
#      Topic  Count                                      Name  \
# 0       -1   1526                     -1_think_kinda_go_gon
# 1        0    145             0_philippine_filipino_go_come
# 2        1    139                   1_gun_shotgun_bum_buchi
# 3        2    116                                     2____
# 4        3     99     3_philippine_filipino_manila_pakistan
# ..     ...    ...                                       ...
# 187    186     10           186_comment_think_review_please
# 188    187     10                      187_yeah_uh_oh_kinda
# 189    188     10         188_cabbage_vegetable_onion_salad
# 190    189     10      189_distance_road_kilometre_traveled
# 191    190     10  190_understand_understands_sense_concept
#
#                                         Representation  \
# 0    [think, kinda, go, gon, along, like, going, go...
# 1    [philippine, filipino, go, come, good, hello, ...
# 2    [gun, shotgun, bum, buchi, budol, busker, cami...
# 3                                 [, , , , , , , , , ]
# 4    [philippine, filipino, manila, pakistan, archi...
# ..                                                 ...
# 187  [comment, think, review, please, tell, let, , ...
# 188            [yeah, uh, oh, kinda, really, , , , , ]
# 189  [cabbage, vegetable, onion, salad, dish, cooke...
# 190  [distance, road, kilometre, traveled, kilomete...
# 191  [understand, understands, sense, concept, pret...
#
#                                    Representative_Docs
# 0    [like would tell like understands learning swa...
# 1    [hello everybody doug today coming cebu city p...
# 2    [uh travesty bum gun australia like normalized...
# 3                            [plain, sample, reminded]
# 4    [people would often guess filipino american co...
# ..                                                 ...
# 187  [leave comment, let u know comment, let u know...
# 188        [yeah yeah yeah, yeah yeah yeah, yeah yeah]
# 189  [know good vegetable dish, vegetable get green...
# 190  [ah okay depending distance, longer distance m...
# 191  [understand let people understand people want ...
#
# [192 rows x 5 columns]

# %% [markdown]
# ### Update Resulting Topics

# %%
# Reduce outliers
new_topics = topic_model.reduce_outliers(segments, topics)

topic_model.update_topics(segments, topics=new_topics)

topic_model.get_topic_info()
# Out:
# 2025-03-13 12:01:33,690 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#      Topic  Count                                   Name  \
# 0       -1     27                -1_parokya_ai_honk_buff
# 1        0    186                    0_like_got_right_go
# 2        1    142               1_gun_bum_pambyahe_sapin
# 3        2    117        2_least_mission_reminded_sample
# 4        3    109  3_philippine_american_filipino_native
# ..     ...    ...                                    ...
# 187    186     18        186_comment_section_brush_leave
# 188    187     31        187_kinda_yeah_government_clean
# 189    188     23   188_vegetable_salad_eggplant_carroty
# 190    189     19        189_far_kilometre_distance_road
# 191    190     17  190_sense_understand_either_pretender
#
#                                         Representation  \
# 0    [parokya, ai, honk, buff, blindfold, category,...
# 1    [like, got, right, go, know, uh, yeah, get, fo...
# 2    [gun, bum, pambyahe, sapin, isa, ucieczkadoraj...
# 3    [least, mission, reminded, sample, buying, jun...
# 4    [philippine, american, filipino, native, popul...
# ..                                                 ...
# 187  [comment, section, brush, leave, click, please...
# 188  [kinda, yeah, government, clean, halo, replace...
# 189  [vegetable, salad, eggplant, carroty, opening,...
# 190  [far, kilometre, distance, road, destination, ...
# 191  [sense, understand, either, pretender, incapab...
#
#                                    Representative_Docs
# 0    [like would tell like understands learning swa...
# 1    [hello everybody doug today coming cebu city p...
# 2    [uh travesty bum gun australia like normalized...
# 3                            [plain, sample, reminded]
# 4    [people would often guess filipino american co...
# ..                                                 ...
# 187  [leave comment, let u know comment, let u know...
# 188        [yeah yeah yeah, yeah yeah yeah, yeah yeah]
# 189  [know good vegetable dish, vegetable get green...
# 190  [ah okay depending distance, longer distance m...
# 191  [understand let people understand people want ...
#
# [192 rows x 5 columns]

# %%
# UPDATE

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

from bertopic.representation import PartOfSpeech

import requests

# Custom stopwords list
custom_stopwords = ['like', 'yeah', 'yes', 'let', 'okay', 'gonna', 'ok', 'bye', 'just', 'got', 'right', 'mmm', 'oh', 'ah', 'gosh', 'guys', 'nice']

# Fetch stopwords from GitHub
github_stopwords_url = "https://raw.githubusercontent.com/stopwords-iso/stopwords-en/master/stopwords-en.txt"
github_stopwords = set(requests.get(github_stopwords_url).text.splitlines())

# Append GitHub stopwords to the custom stopwords set
custom_stopwords = set(custom_stopwords)  
custom_stopwords.update(github_stopwords)  

# Combine predefined stopwords (ENGLISH_STOP_WORDS) with custom stopwords
combined_stopwords = list(ENGLISH_STOP_WORDS.union(set(custom_stopwords)))

# Create a CountVectorizer with combined stopwords as a list
vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words=combined_stopwords)

representation_model = KeyBERTInspired()

# %%
topic_model.update_topics(segments, vectorizer_model=vectorizer_model, representation_model=representation_model)

# %%
# UPDATED

topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1     27  -1_parokya parokya_whoooooooooooa wayhay_delas_ey
# 1        0    186                 0_philippine_filipino_manila_local
# 2        1    142  1_bum gun_fist bump fist_bump fist_bump fist bump
# 3        2    117                                              2____
# 4        3    109  3_philippine_philippine philippine_filipino ph...
# ..     ...    ...                                                ...
# 187    186     18  186_comment comment comment_comment comment_wr...
# 188    187     31  187_outdoor bit kinda_built kinda mesh_kinda m...
# 189    188     23  188_salad vegetable_vegetable dish_salad veget...
# 190    189     19  189_kilometre walked_destination trip alright_...
# 191    190     17  190_understands sense_understand sense_underst...
#
#                                         Representation  \
# 0    [parokya parokya, whoooooooooooa wayhay, delas...
# 1    [philippine, filipino, manila, local, hey, fun...
# 2    [bum gun, fist bump fist, bump fist, bump fist...
# 3                                 [, , , , , , , , , ]
# 4    [philippine, philippine philippine, filipino p...
# ..                                                 ...
# 187  [comment comment comment, comment comment, wri...
# 188  [outdoor bit kinda, built kinda mesh, kinda me...
# 189  [salad vegetable, vegetable dish, salad vegeta...
# 190  [kilometre walked, destination trip alright, k...
# 191  [understands sense, understand sense, understa...
#
#                                    Representative_Docs
# 0    [like would tell like understands learning swa...
# 1    [hello everybody doug today coming cebu city p...
# 2    [uh travesty bum gun australia like normalized...
# 3                            [plain, sample, reminded]
# 4    [people would often guess filipino american co...
# ..                                                 ...
# 187  [leave comment, let u know comment, let u know...
# 188        [yeah yeah yeah, yeah yeah yeah, yeah yeah]
# 189  [know good vegetable dish, vegetable get green...
# 190  [ah okay depending distance, longer distance m...
# 191  [understand let people understand people want ...
#
# [192 rows x 5 columns]

# %%
# Get topic information
topic_info_df = topic_model.get_topic_info()

# Save to CSV
topic_info_df.to_csv("NewUpdated2-ILW-BERTopic_info.csv", index=False)

print("Topic info saved as topic_info.csv")
# Out:
# Topic info saved as topic_info.csv

# %% [markdown]
# # Visualization

# %%
# Get topic representations (top words for each topic)
topic_labels = {topic: ", ".join([word for word, _ in words]) 
                for topic, words in topic_model.get_topics().items()}


# Create a DataFrame to track topics with Video Ids and Segment numbers
topic_data = {
    "Video Id": video_ids,
    "Segment": segments,
    "Topic": new_topics,
    "Topic Name": [topic_labels.get(topic, "No Topic") for topic in new_topics]
}

# %%
# Create a DataFrame to organize the results
topic_df = pd.DataFrame(topic_data)

topic_df
# Out:
#          Video Id                                            Segment  Topic  \
# 0     MBtWxCM7NYg  go plan like going get real bad got real bad t...      0
# 1     MBtWxCM7NYg  australia pretty expensive cheapest option pro...      0
# 2     O0cIJww_amw                                    talked filipina      3
# 3     O0cIJww_amw                                    said like asked     28
# 4     O0cIJww_amw                            said accent accent like      0
# ...           ...                                                ...    ...
# 6696  REvaHqT3uro  liter per person basically put almost got two ...      0
# 6697  REvaHqT3uro                                                 oh     29
# 6698  REvaHqT3uro  look like building brand new spa right seems l...      0
# 6699  REvaHqT3uro                                      hello el nido     56
# 6700  REvaHqT3uro  guy got rainbow distance know see camera got k...      0
#
#                                              Topic Name
# 0     philippine, filipino, manila, local, hey, fun,...
# 1     philippine, filipino, manila, local, hey, fun,...
# 2     philippine, philippine philippine, filipino ph...
# 3     parokya parokya, whoooooooooooa wayhay, delas,...
# 4     parokya parokya, whoooooooooooa wayhay, delas,...
# ...                                                 ...
# 6696  philippine, filipino, manila, local, hey, fun,...
# 6697  hahaha aaaaah, hahaha aaaaah aaaaah, aaaa, hah...
# 6698  philippine, filipino, manila, local, hey, fun,...
# 6699  parokya parokya, whoooooooooooa wayhay, delas,...
# 6700  philippine, filipino, manila, local, hey, fun,...
#
# [6701 rows x 4 columns]

# %% [markdown]
# ## Videos under each Topic

# %%
# Display topics along with their corresponding Video Ids and Segment Numbers
for topic in sorted(set(topics)):  # Sort to display topics in order
    topic_name = topic_labels.get(topic, "No Topic")
    print(f"\n==== Topic #{topic} - {topic_name} ====\n")  # Format the header
    
    # Filter segments that belong to the current topic
    topic_segments = topic_df[topic_df['Topic'] == topic]

    # Print Video Id and Segment text for each row
    for _, row in topic_segments.iterrows():
        print(f"Video Id: {row['Video Id']}, Segment: {row['Segment']}\n")
    
    print("=" * 50)  # Separator for readability
# Out:
# ==== Topic #-1 - parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk ====
#
# Video Id: --8n6A8Q6M0, Segment: honk honk
#
# Video Id: --8n6A8Q6M0, Segment: kawazaki
#
# Video Id: MKBogPOM3Ao, Segment: nooo
#
# Video Id: MKBogPOM3Ao, Segment: sayote
#
# Video Id: MKBogPOM3Ao, Segment: advocate
#
# Video Id: mcWEmkXF4ik, Segment: powdery
#
# Video Id: mcWEmkXF4ik, Segment: wasted
#
# Video Id: mcWEmkXF4ik, Segment: whoooooooooooa wayhay
#
# Video Id: mcWEmkXF4ik, Segment: category
#
# Video Id: mcWEmkXF4ik, Segment: tattooed
#
# Video Id: mcWEmkXF4ik, Segment: parokya parokya
#
# Video Id: mcWEmkXF4ik, Segment: barking
#
# Video Id: mcWEmkXF4ik, Segment: farmland valley
#
# Video Id: mcWEmkXF4ik, Segment: privately owned
#
# Video Id: dGM9kDXdWcQ, Segment: b
#
# Video Id: VoUdWRHkDwA, Segment: sunscreen
#
# Video Id: lLQcFpgbMOk, Segment: impromptu
#
# Video Id: fA0m-LaA_7c, Segment: blindfold ey
#
# Video Id: fA0m-LaA_7c, Segment: blindfold
#
# Video Id: fA0m-LaA_7c, Segment: glossy
#
# Video Id: fA0m-LaA_7c, Segment: identify handful
#
# Video Id: BjaKfnWjX9Y, Segment: category
#
# Video Id: BjaKfnWjX9Y, Segment: ai ai delas ala
#
# Video Id: BjaKfnWjX9Y, Segment: pokwang
#
# Video Id: BjaKfnWjX9Y, Segment: buff blonde buff blonde
#
# Video Id: wpnWOgl3MVc, Segment: rooted
#
# Video Id: nCbla8yws6k, Segment: whatttt
#
# ==================================================
#
# ==== Topic #0 - philippine, filipino, manila, local, hey, fun, street, city, spot, gon ====
#
# Video Id: MBtWxCM7NYg, Segment: go plan like going get real bad got real bad today biggest mall philippine third biggest entire world mall asia apparently mall big visitor per day yes per day mall big biggest ikea world arena hold event concept let go look name josie welcome back channel welcome new mall big already lost two minute think give little bit understanding big place actually okay last six month since thailand singapore searching dyson era okay dyson stall gon na check hope since never stock let look okay never mind moving heap different kind stall shop recognize home obviously international one american one would probably say could find anything need safe say wondering cold downstairs look ice skating rink shopping center question many thing um one ice right getting cleaned think think top level surrounded many place eat well know else could else could put shopping centre point okay joke said walked past archery range like somewhere shoot arrow else laser tag okay well stand corrected walking food hall idea drink food lost looking drink many option honestly kind want coffee see see one many people option even find anywhere want go shopping center massive quite confusing different building well going going sushi going food first think need sustenance order walk around shopping mall next hour going try sushi craving sushi long able find chicken sushi anywhere chicken sushi let see go excited sushi first time probably six month sushi ready really hot right let grab sushi know green thing top actually pretty good sushi australia sushi called katsu chicken crispy chicken inside sushi roll usually avocado best sushi ever know sushi meant fish favorite find anywhere since traveling pretty close teriyaki chicken cucumber pretty close though tell sushi order comment like sushi pretty good dish like order lot australia taste really different know differently something still like taste like le deep fried make sense two thing cost peso filipino peso
#
# Video Id: k5iXUMHPXb8, Segment: grinded pepper question nope put pepper say baam pim pim pim pim like lot pepper like lot pepper
#
# ...
#
# Video Id: CBmNk9pSsy4, Segment: fourth year come
#
# Video Id: mcWEmkXF4ik, Segment: quite year
#
# Video Id: mcWEmkXF4ik, Segment: year year yes
#
# Video Id: mcWEmkXF4ik, Segment: think happen like year year
#
# Video Id: mcWEmkXF4ik, Segment: maybe year
#
# Video Id: mcWEmkXF4ik, Segment: year think
#
# Video Id: CI8PSPP9vlE, Segment: always tell fully rest
#
# Video Id: 401ZvQ11euA, Segment: fully committed imposing year
#
# Video Id: LFkSktRSJpM, Segment: uh annually renew one see every year every year need one
#
# Video Id: VoUdWRHkDwA, Segment: sure year around
#
# Video Id: VoUdWRHkDwA, Segment: hopefully going change nearly
#
# Video Id: YLPogsvk7ew, Segment: bruce lee started freshman year u dub year space needle built
#
# Video Id: LU3dP_VdymQ, Segment: hopefully change next year
#
# Video Id: LU3dP_VdymQ, Segment: planning trip three year ago
#
# Video Id: wpnWOgl3MVc, Segment: eats oxtail kare kare even one year old
#
# Video Id: wpnWOgl3MVc, Segment: need change fit mainstream
#
# Video Id: vwIIeiOhTJ0, Segment: around million year danger extinction habitat loss difficult raise captivity
#
# Video Id: vwIIeiOhTJ0, Segment: g live year
#
# Video Id: vwIIeiOhTJ0, Segment: tamaraws live year
#
# Video Id: vwIIeiOhTJ0, Segment: designed celebrate year independence spanish rule
#
# ==================================================
#
# ==== Topic #181 - ticket spot candy, eat easy ticket, easy ticket, ticket qr, ticket, easy ticket spot, ride ticket, ticket spot, ride ticket cent, candy candy bulalo ====
#
# Video Id: mcWEmkXF4ik, Segment: okay one ticket please
#
# Video Id: mcWEmkXF4ik, Segment: okay look like got qr code something hopefully buy one ride one ticket something like
#
# Video Id: mcWEmkXF4ik, Segment: okay okay good good one
#
# Video Id: mcWEmkXF4ik, Segment: okay get try one nice
#
# Video Id: mcWEmkXF4ik, Segment: oh okay good yeah good okay like cent okay buy one piece please
#
# Video Id: mcWEmkXF4ik, Segment: like piece box
#
# Video Id: mcWEmkXF4ik, Segment: one good
#
# Video Id: mcWEmkXF4ik, Segment: okay good one
#
# Video Id: mcWEmkXF4ik, Segment: one good sir
#
# Video Id: mcWEmkXF4ik, Segment: yeah okay sure good one
#
# Video Id: mcWEmkXF4ik, Segment: okay good one
#
# Video Id: mcWEmkXF4ik, Segment: ah okay nice one
#
# Video Id: mcWEmkXF4ik, Segment: okay good nice one
#
# Video Id: mcWEmkXF4ik, Segment: okay nice one okay
#
# Video Id: F5yCChwGHzM, Segment: yeaaah eat easy buy ticket directly spot
#
# Video Id: R9ya0jtNpGs, Segment: please candy want candy
#
# Video Id: lLQcFpgbMOk, Segment: bulalo buy bigger pot try
#
# Video Id: fA0m-LaA_7c, Segment: three five piece
#
# ==================================================
#
# ==== Topic #182 - airport gon uh, cebu actual airport, lol airport, airport lol, airport amazing stay, airport, gon head airport, international airport, international airport manila, airport manila ====
#
# Video Id: --8n6A8Q6M0, Segment: yeah hour wait uh kind main lobby area like kind like edge cebu right near airport right
#
# Video Id: --8n6A8Q6M0, Segment: like five minute drive airport
#
# Video Id: --8n6A8Q6M0, Segment: back room gon na get uh everything packed gon na head airport amazing stay
#
# Video Id: mcWEmkXF4ik, Segment: flight booked cebu
#
# Video Id: mcWEmkXF4ik, Segment: actual airport like flight week cebu
#
# Video Id: Vx0TqLbcVpc, Segment: little sleep middle bench bangkok airport
#
# Video Id: Vx0TqLbcVpc, Segment: seems like airport pretty easy navigate
#
# Video Id: oul9IITqAoA, Segment: international airport manila city closed
#
# Video Id: oul9IITqAoA, Segment: external flight accepted
#
# Video Id: oul9IITqAoA, Segment: despite flight ban several passenger liner left clark international airport heading indonesia australia
#
# Video Id: VoUdWRHkDwA, Segment: background cebu left side mactan side
#
# Video Id: nCbla8yws6k, Segment: la salle every time want enter check like airport lol yes like airport
#
# ==================================================
#
# ==== Topic #183 - uh sort enter, sort enter, uh sort, sort enter write, priority write curfew, person uh sort, priority, priority write, checked lot cat, learning ====
#
# Video Id: O0cIJww_amw, Segment: since day call kenyan filipina heart strategy talking one reason learning language learning new language order talk another person
#
# Video Id: --8n6A8Q6M0, Segment: uh sort enter
#
# Video Id: y9iCFcSaD58, Segment: ordering ordering ordering
#
# Video Id: y9iCFcSaD58, Segment: well order
#
# Video Id: mcWEmkXF4ik, Segment: ordering
#
# Video Id: mcWEmkXF4ik, Segment: ah ordering
#
# Video Id: mcWEmkXF4ik, Segment: ordered
#
# Video Id: mcWEmkXF4ik, Segment: write order
#
# Video Id: mcWEmkXF4ik, Segment: additional order sir
#
# Video Id: mcWEmkXF4ik, Segment: additional order call
#
# Video Id: 2ftG8JuMzz4, Segment: conserving environment still top priority course
#
# Video Id: p1LaUfLyYpQ, Segment: write
#
# Video Id: oul9IITqAoA, Segment: curfew reinforced military patrol checkpoint implemented maintain order identify small group infected individual
#
# Video Id: CI8PSPP9vlE, Segment: priority value
#
# Video Id: LtXiRN0P2VY, Segment: order
#
# Video Id: nCbla8yws6k, Segment: every time want enter campus checked first lot cat feed cat
#
# ==================================================
#
# ==== Topic #184 - moment wowing audience, audience, wowing audience, movie series hmmm, audience worldwide appeared, audience worldwide, wowing audience worldwide, popular actress host, actress host, shot movie series ====
#
# Video Id: O0cIJww_amw, Segment: never done today channel
#
# Video Id: O0cIJww_amw, Segment: many like darna series
#
# Video Id: Vx0TqLbcVpc, Segment: one thing really like tv
#
# Video Id: YLPogsvk7ew, Segment: camera zoom cause kid growing hawaii bruce lee asian person ever saw movie tv kicked as
#
# Video Id: mBqdFmLnKCE, Segment: miao show
#
# Video Id: LU3dP_VdymQ, Segment: basically private experience moment
#
# Video Id: BD2RRl7wPMw, Segment: wowing audience worldwide appeared show little big shot
#
# Video Id: BjaKfnWjX9Y, Segment: movie yes tv
#
# Video Id: BjaKfnWjX9Y, Segment: also tv series
#
# Video Id: BjaKfnWjX9Y, Segment: tv show hmmm
#
# Video Id: BjaKfnWjX9Y, Segment: ahh wait tv series
#
# Video Id: sXsHYugynnI, Segment: alex gonzaga alex gonzaga popular actress tv host vlogger
#
# Video Id: ZFpnR0xpdRI, Segment: john moment tv
#
# Video Id: ZFpnR0xpdRI, Segment: moment tv
#
# ==================================================
#
# ==== Topic #185 - start, uh start, started start, start start, start yep start, yep start start, yep start, start yep, begun, start start start ====
#
# Video Id: --8n6A8Q6M0, Segment: gon na quick little swim uh start day right
#
# Video Id: --8n6A8Q6M0, Segment: okay start yellow
#
# Video Id: --8n6A8Q6M0, Segment: start yep
#
# Video Id: --8n6A8Q6M0, Segment: start yep
#
# Video Id: --8n6A8Q6M0, Segment: start start okay
#
# Video Id: --8n6A8Q6M0, Segment: maybe going direction
#
# Video Id: MKBogPOM3Ao, Segment: okay let start
#
# Video Id: MKBogPOM3Ao, Segment: start
#
# Video Id: MKBogPOM3Ao, Segment: go go start
#
# Video Id: MKBogPOM3Ao, Segment: start melting becomes little bit messy
#
# Video Id: CBmNk9pSsy4, Segment: anyway let start
#
# Video Id: mcWEmkXF4ik, Segment: start
#
# Video Id: Vx0TqLbcVpc, Segment: day definitely starting direction
#
# Video Id: Vx0TqLbcVpc, Segment: wall start story modern day philippine portuguese explorer direction spanish crown trying circumnavigate earth first time
#
# Video Id: YLPogsvk7ew, Segment: construction begun year
#
# Video Id: BD2RRl7wPMw, Segment: yup started
#
# Video Id: nCbla8yws6k, Segment: already start downloading drama ehhhhh
#
# ==================================================
#
# ==== Topic #186 - comment comment comment, comment comment, write comment comment, leave comment comment, comment comment video, leave comment favorite, comment comment leave, comment comment aico, comment helpful, question comment answer ====
#
# Video Id: --8n6A8Q6M0, Segment: earlier morning would shown like actually going comment crane uh established obviously part bohol
#
# Video Id: CBmNk9pSsy4, Segment: like video please click like click subscribe especially question comment answer question comment let make helpful positive community
#
# Video Id: mcWEmkXF4ik, Segment: okay think got u
#
# Video Id: mcWEmkXF4ik, Segment: brush section
#
# Video Id: mcWEmkXF4ik, Segment: whole section brush broom
#
# Video Id: 2ftG8JuMzz4, Segment: love hear thought leave comment let u know favorite part video want leave u thought
#
# Video Id: 401ZvQ11euA, Segment: leave comment
#
# Video Id: iHyEzFFHD1g, Segment: leave information good review section
#
# Video Id: y9xOKcZD0xE, Segment: else put u otherwise gathered u together
#
# Video Id: VoUdWRHkDwA, Segment: maybe tell u comment
#
# Video Id: fA0m-LaA_7c, Segment: suggestion gave u load input
#
# Video Id: fA0m-LaA_7c, Segment: think pronounced pinnekjott like phonetically correct comment please
#
# Video Id: fA0m-LaA_7c, Segment: please comment
#
# Video Id: BD2RRl7wPMw, Segment: let u know comment section
#
# Video Id: l9hIJpOP5Fo, Segment: leave comment comment section video always remember like share subscribe bobbied saying take care god bless peace
#
# Video Id: u6uj4yjTn-k, Segment: fan sb someone know well please write comment
#
# Video Id: FXnVfuiMQjg, Segment: seen different comment aico
#
# Video Id: vwIIeiOhTJ0, Segment: let u know comment
#
# ==================================================
#
# ==== Topic #187 - outdoor bit kinda, built kinda mesh, kinda mesh, uh kinda, built kinda, kinda misty, kinda clean energy, kinda clean, kinda indoor bit, kinda mesh wire ====
#
# Video Id: --8n6A8Q6M0, Segment: yeah yeah
#
# Video Id: --8n6A8Q6M0, Segment: yeah yeah uhhuh change
#
# Video Id: --8n6A8Q6M0, Segment: yeah yeah yeah
#
# Video Id: --8n6A8Q6M0, Segment: yeah yeah yeah
#
# Video Id: --8n6A8Q6M0, Segment: yeah yeah
#
# Video Id: --8n6A8Q6M0, Segment: yeah yeah
#
# Video Id: y9iCFcSaD58, Segment: yeah fine
#
# Video Id: MKBogPOM3Ao, Segment: chap chye yeah
#
# Video Id: MKBogPOM3Ao, Segment: yeah kinda like yeah
#
# Video Id: MKBogPOM3Ao, Segment: first like yeah yeah going halo halo
#
# Video Id: mcWEmkXF4ik, Segment: yeah sometimes yeah
#
# Video Id: mcWEmkXF4ik, Segment: okay really uh yeah
#
# Video Id: mcWEmkXF4ik, Segment: yeah got vip treatment
#
# Video Id: mcWEmkXF4ik, Segment: oh yeah yeah yeah
#
# Video Id: mcWEmkXF4ik, Segment: really uh yeah
#
# Video Id: mcWEmkXF4ik, Segment: air clean fresh always seems kinda misty fogginess
#
# Video Id: mcWEmkXF4ik, Segment: yeah yeah
#
# Video Id: mcWEmkXF4ik, Segment: yeah outdoor bit look like way kinda indoor bit right
#
# Video Id: mcWEmkXF4ik, Segment: yeah yeah yeah
#
# Video Id: mcWEmkXF4ik, Segment: yeah box
#
# Video Id: mcWEmkXF4ik, Segment: really uh oh yeah yeah
#
# Video Id: mcWEmkXF4ik, Segment: thought kinda like one place said three distinct place three different management
#
# Video Id: mcWEmkXF4ik, Segment: built kinda mesh wire metal kinda trail
#
# Video Id: mcWEmkXF4ik, Segment: yeah yeah got ta careful
#
# Video Id: mcWEmkXF4ik, Segment: look like kinda athletics track
#
# Video Id: mcWEmkXF4ik, Segment: saying government got plan phase replace kinda like clean energy maybe government vehicle something
#
# Video Id: mcWEmkXF4ik, Segment: busy packed people kinda like walking like
#
# Video Id: Vx0TqLbcVpc, Segment: trying learn yeah
#
# Video Id: wpnWOgl3MVc, Segment: yeah need turn around
#
# Video Id: wpnWOgl3MVc, Segment: yeah r u f
#
# Video Id: ZFpnR0xpdRI, Segment: yeah yeah give ten
#
# ==================================================
#
# ==== Topic #188 - salad vegetable, vegetable dish, salad vegetable feel, vegetable love vegetable, peranakan vegetable, onion cabbage vegetable, vegetable onion cabbage, vegetable, vegetable green onion, salad carroty ====
#
# Video Id: y9iCFcSaD58, Segment: sweat little crunchy fried
#
# Video Id: MKBogPOM3Ao, Segment: kind like tart tomato eggplant okra green bean kangkong
#
# Video Id: MKBogPOM3Ao, Segment: filling along vegetable sweet gravy sauce peanut top
#
# Video Id: MKBogPOM3Ao, Segment: familiar peranakan vegetable called chap chye
#
# Video Id: MKBogPOM3Ao, Segment: stir fried vegetable
#
# Video Id: MKBogPOM3Ao, Segment: vegetable still crunchy
#
# Video Id: MKBogPOM3Ao, Segment: convinced used like vegetable got eat vegetable got love like vegetable stay fresh
#
# Video Id: MKBogPOM3Ao, Segment: vegetable cooked type sauce remain crunchy
#
# Video Id: MKBogPOM3Ao, Segment: know good vegetable dish
#
# Video Id: iM43LN5gdgs, Segment: salad
#
# Video Id: iM43LN5gdgs, Segment: eggplant eggplant salad
#
# Video Id: iM43LN5gdgs, Segment: ah yes vegetable feel cold see shaking yeah really cold
#
# Video Id: mcWEmkXF4ik, Segment: vegetable onion cabbage
#
# Video Id: mcWEmkXF4ik, Segment: vegetable get green onion cabbage gon na go green onion spiciness go
#
# Video Id: lLQcFpgbMOk, Segment: meat side vegetable side
#
# Video Id: lLQcFpgbMOk, Segment: knife opening frozen vegetable
#
# Video Id: lLQcFpgbMOk, Segment: warm okay please add vegetable
#
# Video Id: fA0m-LaA_7c, Segment: potato salad carroty salad like mashed carroty salad gravy smell like lamb mutton something
#
# Video Id: fA0m-LaA_7c, Segment: quite literally stitch opening get even cook
#
# Video Id: BXSZVp68G_M, Segment: lumpia fresh crispy stuffed vegetable adobo tender full flavor
#
# Video Id: BjaKfnWjX9Y, Segment: yes food vegetable meat
#
# Video Id: U8XwxNBrsCA, Segment: tradition originated otomi indian guanajuato us dye flower vegetable create imprint tortilla
#
# Video Id: vwIIeiOhTJ0, Segment: eat often boiled vegetable fried oil popular great flavor
#
# ==================================================
#
# ==== Topic #189 - kilometre walked, destination trip alright, kilometre walked thankfully, traveled residency distance, destination trip, distance fare, distance, kilometre kilometre walked, distance kilometre, depending distance ====
#
# Video Id: --8n6A8Q6M0, Segment: road go
#
# Video Id: --8n6A8Q6M0, Segment: many kilometer
#
# Video Id: CBmNk9pSsy4, Segment: take long road well traveled residency
#
# Video Id: mcWEmkXF4ik, Segment: longer distance mean higher fare right
#
# Video Id: mcWEmkXF4ik, Segment: far
#
# Video Id: mcWEmkXF4ik, Segment: best thing place far swing
#
# Video Id: mcWEmkXF4ik, Segment: like destination written
#
# Video Id: mcWEmkXF4ik, Segment: need get across road first
#
# Video Id: mcWEmkXF4ik, Segment: ah okay depending distance
#
# Video Id: mcWEmkXF4ik, Segment: yes kilometre
#
# Video Id: mcWEmkXF4ik, Segment: okay must going kilometre
#
# Video Id: Vx0TqLbcVpc, Segment: think almost like walked thankfully go far noticed going
#
# Video Id: Vx0TqLbcVpc, Segment: far far away yeah yeah
#
# Video Id: lLQcFpgbMOk, Segment: little bit far still
#
# Video Id: LU3dP_VdymQ, Segment: way second destination
#
# Video Id: LU3dP_VdymQ, Segment: best trip far
#
# Video Id: BXSZVp68G_M, Segment: alright guy end trip little manila seoul
#
# Video Id: BjaKfnWjX9Y, Segment: far
#
# Video Id: nCbla8yws6k, Segment: finally arrived walking pretty far oh gate
#
# ==================================================
#
# ==== Topic #190 - understands sense, understand sense, understand people understand, brought sense, people understand, understand people, sense explain, understand concept, pretender sense, sense ====
#
# Video Id: --8n6A8Q6M0, Segment: um understands
#
# Video Id: MKBogPOM3Ao, Segment: make sense
#
# Video Id: mcWEmkXF4ik, Segment: air conditioning need either
#
# Video Id: mcWEmkXF4ik, Segment: understand let people understand people want either
#
# Video Id: mcWEmkXF4ik, Segment: understand guy understand whole concept even like coffee
#
# Video Id: mcWEmkXF4ik, Segment: understand
#
# Video Id: mcWEmkXF4ik, Segment: thing
#
# Video Id: mcWEmkXF4ik, Segment: sense adventure
#
# Video Id: mcWEmkXF4ik, Segment: many people either
#
# Video Id: CI8PSPP9vlE, Segment: sometimes really understand pinays would want fair skin
#
# Video Id: CI8PSPP9vlE, Segment: think one thing incapable anything else like
#
# Video Id: dGM9kDXdWcQ, Segment: pretender make sense
#
# Video Id: lLQcFpgbMOk, Segment: explain anything
#
# Video Id: lLQcFpgbMOk, Segment: always purpose
#
# Video Id: fA0m-LaA_7c, Segment: make sense
#
# Video Id: U8XwxNBrsCA, Segment: sara brought sense
#
# Video Id: sXsHYugynnI, Segment: social medium account exhibit artistic endeavor fashion sense travel
#
# ==================================================

# %%
# Display topics along with their corresponding Video Ids and Segment Numbers
for topic in sorted(set(topics)):  # Sort to display topics in order
    topic_name = topic_labels.get(topic, "No Topic")
    print(f"\n==== Topic #{topic} - {topic_name} ====\n")  # Format the header
    
    # Filter segments that belong to the current topic
    topic_segments = topic_df[topic_df['Topic'] == topic]
    
    # Group by Video Id and count the number of segments assigned to this topic
    video_segment_count = topic_segments.groupby('Video Id').size()
    
    # Print the details for each Video Id and the number of segments assigned to this topic
    for video_id, count in video_segment_count.items():
        print(f"Video Id: {video_id}, Total Segments: {count}")
    
    print("=" * 50)  # Separator for readability
# Out:
# ==== Topic #-1 - parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 2
# Video Id: BjaKfnWjX9Y, Total Segments: 4
# Video Id: MKBogPOM3Ao, Total Segments: 3
# Video Id: VoUdWRHkDwA, Total Segments: 1
# Video Id: dGM9kDXdWcQ, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 4
# Video Id: lLQcFpgbMOk, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 9
# Video Id: nCbla8yws6k, Total Segments: 1
# Video Id: wpnWOgl3MVc, Total Segments: 1
# ==================================================
#
# ==== Topic #0 - philippine, filipino, manila, local, hey, fun, street, city, spot, gon ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 8
# Video Id: 0IMWasj76yU, Total Segments: 1
# Video Id: 1kErCqgIVMk, Total Segments: 1
# Video Id: 2TmagN6RhkI, Total Segments: 1
# Video Id: 2ftG8JuMzz4, Total Segments: 1
# Video Id: 3n1nspLgfd4, Total Segments: 1
# Video Id: 4OiOwDh5lKE, Total Segments: 1
# Video Id: 6ftiWoCJ4dM, Total Segments: 1
# Video Id: 7jDrzdX2Ucc, Total Segments: 1
# Video Id: 7zaMbzqj8AI, Total Segments: 2
# Video Id: 8DYPxsr7kDI, Total Segments: 2
# Video Id: 8kcD3vk12AY, Total Segments: 1
# Video Id: 9Qlof7jPQpg, Total Segments: 1
# Video Id: ARMdb7fgfQU, Total Segments: 1
# Video Id: A_HLtsg4TVA, Total Segments: 2
# Video Id: BXSZVp68G_M, Total Segments: 1
# Video Id: BjaKfnWjX9Y, Total Segments: 3
# Video Id: CI8PSPP9vlE, Total Segments: 1
# Video Id: CUlbqob5Njg, Total Segments: 2
# Video Id: F5yCChwGHzM, Total Segments: 3
# Video Id: F9z7b9ei2Lg, Total Segments: 2
# Video Id: FkBRtBZhNyc, Total Segments: 3
# Video Id: Foa5W5bVUEQ, Total Segments: 2
# Video Id: GH4gd0X9K_E, Total Segments: 1
# Video Id: Gl2RpA1xS6M, Total Segments: 2
# Video Id: HcRh8IrwbCA, Total Segments: 1
# Video Id: HkRKi7_Iywc, Total Segments: 1
# Video Id: InP5_mgUUfE, Total Segments: 2
# Video Id: KSrS_KmFcmM, Total Segments: 2
# Video Id: LFkSktRSJpM, Total Segments: 15
# Video Id: LU3dP_VdymQ, Total Segments: 2
# Video Id
Total Segments: 1
# Video Id: VoUdWRHkDwA, Total Segments: 1
# Video Id: bKCr62Dk7Us, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 1
# Video Id: lLQcFpgbMOk, Total Segments: 1
# Video Id: mBqdFmLnKCE, Total Segments: 2
# Video Id: mcWEmkXF4ik, Total Segments: 10
# Video Id: nCbla8yws6k, Total Segments: 1
# Video Id: y9iCFcSaD58, Total Segments: 1
# ==================================================
#
# ==== Topic #57 - market, market market, market quiapo, divisoria market, market fresh market, street market, market heading, market public, public market, market mission hey ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 2
# Video Id: BXSZVp68G_M, Total Segments: 3
# Video Id: LFkSktRSJpM, Total Segments: 1
# Video Id: VoUdWRHkDwA, Total Segments: 3
# Video Id: Vx0TqLbcVpc, Total Segments: 5
# Video Id: bAn0qP3BHcI, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 29
# Video Id: sXsHYugynnI, Total Segments: 1
# ==================================================
#
# ==== Topic #58 - video laanya video, video video, video video video, video laanya, video, video watched, video watched video, video watching, people video, video spent ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 5
# Video Id: BD2RRl7wPMw, Total Segments: 1
# Video Id: BXSZVp68G_M, Total Segments: 1
# Video Id: BjaKfnWjX9Y, Total Segments: 3
# Video Id: CI8PSPP9vlE, Total Segments: 1
# Video Id: LU3dP_VdymQ, Total Segments: 1
# Video Id: MKBogPOM3Ao, Total Segments: 2
# Video Id: S4bNEgM483k, Total Segments: 1
# Video Id: Vx0TqLbcVpc, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 2
# Video Id: iM43LN5gdgs, Total Segments: 3
# Video Id: iWMyjfgyCYU, Total Segments: 1
# ...
#
# Video Id: --8n6A8Q6M0, Total Segments: 1
# Video Id: 2ftG8JuMzz4, Total Segments: 4
# Video Id: BXSZVp68G_M, Total Segments: 2
# Video Id: MKBogPOM3Ao, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 5
# Video Id: y9iCFcSaD58, Total Segments: 6
# ==================================================
#
# ==== Topic #164 - light damian damian, light damian, damian light, light damian light, light refreshing damian, light light damian, light bulb damian, glass damian, restore light damian, makeshift material damian ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 1
# Video Id: FXnVfuiMQjg, Total Segments: 13
# Video Id: fA0m-LaA_7c, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 2
# Video Id: vwIIeiOhTJ0, Total Segments: 1
# Video Id: y9iCFcSaD58, Total Segments: 3
# ==================================================
#
# ==== Topic #165 - wait, wait umm, umm wait, wait umm wait, wait wait, wait wait umm, wait pas, wait wait wait, wait coming, coming wait ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 3
# Video Id: 86gs985X5tU, Total Segments: 1
# Video Id: BjaKfnWjX9Y, Total Segments: 2
# Video Id: FXnVfuiMQjg, Total Segments: 1
# Video Id: O0cIJww_amw, Total Segments: 1
# Video Id: bAn0qP3BHcI, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 2
# Video Id: lLQcFpgbMOk, Total Segments: 4
# Video Id: mcWEmkXF4ik, Total Segments: 4
# Video Id: y9iCFcSaD58, Total Segments: 1
# ==================================================
#
# ==== Topic #166 - stay tuned watching, tuned watching watching, awesome watching watching, watching jurassic, awesome watching, watching watching, jurassic watching, watching, tuned watching, watching stay tuned ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 1
# Video Id: 2ftG8JuMzz4, Total Segments: 1
# Video Id: BXSZVp68G_M, Total Segments: 1
# Video Id: F5yCChwGHzM, Total Segments: 1
# Video Id: LU3dP_VdymQ, Total Segments: 1
# Video Id: O0cIJww_amw, Total Segments: 1
# Video Id: VoUdWRHkDwA, Total Segments: 1
# Video Id: dGM9kDXdWcQ, Total Segments: 1
# Video Id: iHyEzFFHD1g, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 2
# Video Id: nCbla8yws6k, Total Segments: 1
# Video Id: vwIIeiOhTJ0, Total Segments: 1
# Video Id: wpnWOgl3MVc, Total Segments: 2
# ==================================================
#
# ==== Topic #167 - weather cloud, weather cloud time, cloud, uh cloud formation, cloud cover, poked cloud, weather classic gökçe, cloud time, manila cloud, poked cloud time ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 4
# Video Id: BjaKfnWjX9Y, Total Segments: 1
# Video Id: LU3dP_VdymQ, Total Segments: 5
# Video Id: VoUdWRHkDwA, Total Segments: 4
# Video Id: mcWEmkXF4ik, Total Segments: 5
# Video Id: y9iCFcSaD58, Total Segments: 3
# ==================================================
#
# ==== Topic #168 - meat meat, meat, meat lot meat, meat craft, meat tender wan, meat fundamental, meat bc, meat fatty piece, meat super, lot meat ====
#
# Video Id: 2ftG8JuMzz4, Total Segments: 6
# Video Id: BXSZVp68G_M, Total Segments: 1
# Video Id: MKBogPOM3Ao, Total Segments: 2
# Video Id: fA0m-LaA_7c, Total Segments: 3
# Video Id: iM43LN5gdgs, Total Segments: 1
# Video Id: lLQcFpgbMOk, Total Segments: 5
# Video Id: mcWEmkXF4ik, Total Segments: 3
# Video Id: y9iCFcSaD58, Total Segments: 3
# ==================================================
#
# ==== Topic #169 - mount kalugong, kalugong mount, mount kalugong gon, mount kalugong mount, kalugong mount kalugong, mount kalugong kalugong, kalugong kalugong mount, gon mount kalugong, mount kalugong called, mount kalugong trail ====
#
# Video Id: mcWEmkXF4ik, Total Segments: 20
# Video Id: oul9IITqAoA, Total Segments: 3
# ==================================================
#
# ==== Topic #170 - burnt mang inasal, burnt mang, burn inasal, burn inasal smoke, rumored burn inasal, inasal rumored burn, burn, rumored burn, kill lit bonfire, inasal smoke glowing ====
#
# Video Id: 401ZvQ11euA, Total Segments: 2
# Video Id: 86gs985X5tU, Total Segments: 1
# Video Id: FXnVfuiMQjg, Total Segments: 1
# Video Id: dGM9kDXdWcQ, Total Segments: 1
# Video Id: lLQcFpgbMOk, Total Segments: 2
# Video Id: mBqdFmLnKCE, Total Segments: 2
# Video Id: mcWEmkXF4ik, Total Segments: 4
# Video Id: oul9IITqAoA, Total Segments: 4
# Video Id: y9iCFcSaD58, Total Segments: 1
# ==================================================
#
# ==== Topic #171 - cool, cool cool, cool cool cool, hey cool cool, hey cool, pretty cool, cool pretty cool, ciao cool, cool shot cool, cool ciao ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 4
# Video Id: BjaKfnWjX9Y, Total Segments: 2
# Video Id: MKBogPOM3Ao, Total Segments: 2
# Video Id: VoUdWRHkDwA, Total Segments: 1
# Video Id: Vx0TqLbcVpc, Total Segments: 2
# Video Id: YLPogsvk7ew, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 3
# Video Id: p1LaUfLyYpQ, Total Segments: 1
# Video Id: y9iCFcSaD58, Total Segments: 1
# ==================================================
#
# ==== Topic #172 - double uh gon, cream double, fat cream double, double fat cream, double uh, cream fat double, cream double class, double, guess country double, roll creamy ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 5
# Video Id: CI8PSPP9vlE, Total Segments: 1
# Video Id: LFkSktRSJpM, Total Segments: 1
# Video Id: VoUdWRHkDwA, Total Segments:
Total Segments: 1
# Video Id: y9iCFcSaD58, Total Segments: 2
# ==================================================
#
# ==== Topic #184 - moment wowing audience, audience, wowing audience, movie series hmmm, audience worldwide appeared, audience worldwide, wowing audience worldwide, popular actress host, actress host, shot movie series ====
#
# Video Id: BD2RRl7wPMw, Total Segments: 1
# Video Id: BjaKfnWjX9Y, Total Segments: 4
# Video Id: LU3dP_VdymQ, Total Segments: 1
# Video Id: O0cIJww_amw, Total Segments: 2
# Video Id: Vx0TqLbcVpc, Total Segments: 1
# Video Id: YLPogsvk7ew, Total Segments: 1
# Video Id: ZFpnR0xpdRI, Total Segments: 2
# Video Id: mBqdFmLnKCE, Total Segments: 1
# Video Id: sXsHYugynnI, Total Segments: 1
# ==================================================
#
# ==== Topic #185 - start, uh start, started start, start start, start yep start, yep start start, yep start, start yep, begun, start start start ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 6
# Video Id: BD2RRl7wPMw, Total Segments: 1
# Video Id: CBmNk9pSsy4, Total Segments: 1
# Video Id: MKBogPOM3Ao, Total Segments: 4
# Video Id: Vx0TqLbcVpc, Total Segments: 2
# Video Id: YLPogsvk7ew, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 1
# Video Id: nCbla8yws6k, Total Segments: 1
# ==================================================
#
# ==== Topic #186 - comment comment comment, comment comment, write comment comment, leave comment comment, comment comment video, leave comment favorite, comment comment leave, comment comment aico, comment helpful, question comment answer ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 1
# Video Id: 2ftG8JuMzz4, Total Segments: 1
# Video Id: 401ZvQ11euA, Total Segments: 1
# Video Id: BD2RRl7wPMw, Total Segments: 1
# Video Id: CBmNk9pSsy4, Total Segments: 1
# Video Id: FXnVfuiMQjg, Total Segments: 1
# Video Id: VoUdWRHkDwA, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 3
# Video Id: iHyEzFFHD1g, Total Segments: 1
# Video Id: l9hIJpOP5Fo, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 3
# Video Id: u6uj4yjTn-k, Total Segments: 1
# Video Id: vwIIeiOhTJ0, Total Segments: 1
# Video Id: y9xOKcZD0xE, Total Segments: 1
# ==================================================
#
# ==== Topic #187 - outdoor bit kinda, built kinda mesh, kinda mesh, uh kinda, built kinda, kinda misty, kinda clean energy, kinda clean, kinda indoor bit, kinda mesh wire ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 6
# Video Id: MKBogPOM3Ao, Total Segments: 3
# Video Id: Vx0TqLbcVpc, Total Segments: 1
# Video Id: ZFpnR0xpdRI, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 17
# Video Id: wpnWOgl3MVc, Total Segments: 2
# Video Id: y9iCFcSaD58, Total Segments: 1
# ==================================================
#
# ==== Topic #188 - salad vegetable, vegetable dish, salad vegetable feel, vegetable love vegetable, peranakan vegetable, onion cabbage vegetable, vegetable onion cabbage, vegetable, vegetable green onion, salad carroty ====
#
# Video Id: BXSZVp68G_M, Total Segments: 1
# Video Id: BjaKfnWjX9Y, Total Segments: 1
# Video Id: MKBogPOM3Ao, Total Segments: 8
# Video Id: U8XwxNBrsCA, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 2
# Video Id: iM43LN5gdgs, Total Segments: 3
# Video Id: lLQcFpgbMOk, Total Segments: 3
# Video Id: mcWEmkXF4ik, Total Segments: 2
# Video Id: vwIIeiOhTJ0, Total Segments: 1
# Video Id: y9iCFcSaD58, Total Segments: 1
# ==================================================
#
# ==== Topic #189 - kilometre walked, destination trip alright, kilometre walked thankfully, traveled residency distance, destination trip, distance fare, distance, kilometre kilometre walked, distance kilometre, depending distance ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 2
# Video Id: BXSZVp68G_M, Total Segments: 1
# Video Id: BjaKfnWjX9Y, Total Segments: 1
# Video Id: CBmNk9pSsy4, Total Segments: 1
# Video Id: LU3dP_VdymQ, Total Segments: 2
# Video Id: Vx0TqLbcVpc, Total Segments: 2
# Video Id: lLQcFpgbMOk, Total Segments: 1
# Video Id: mcWEmkXF4ik, Total Segments: 8
# Video Id: nCbla8yws6k, Total Segments: 1
# ==================================================
#
# ==== Topic #190 - understands sense, understand sense, understand people understand, brought sense, people understand, understand people, sense explain, understand concept, pretender sense, sense ====
#
# Video Id: --8n6A8Q6M0, Total Segments: 1
# Video Id: CI8PSPP9vlE, Total Segments: 2
# Video Id: MKBogPOM3Ao, Total Segments: 1
# Video Id: U8XwxNBrsCA, Total Segments: 1
# Video Id: dGM9kDXdWcQ, Total Segments: 1
# Video Id: fA0m-LaA_7c, Total Segments: 1
# Video Id: lLQcFpgbMOk, Total Segments: 2
# Video Id: mcWEmkXF4ik, Total Segments: 7
# Video Id: sXsHYugynnI, Total Segments: 1
# ==================================================

# %% [markdown]
# ## Topic Distribution per Transcript

# %%
# Group by Video Id and get the unique topics for each Video Id
video_topics = topic_df.groupby('Video Id')['Topic'].unique()

# Display the topics for each Video Id
for video_id, topics in video_topics.items():
    print(f"Transcript Video {video_id}:")
    print(f"Topics Present: {', '.join(map(str, topics))}\n")
# Out:
# Transcript Video --8n6A8Q6M0:
# Topics Present: 124, 125, 17, 63, 3, 140, 35, 66, 143, 121, 0, 167, 42, 4, 95, 43, 39, 52, 172, 1, 30, 41, 61, 83, 179, 78, 141, 40, 18, 185, 101, 142, 85, 33, 96, 99, 46, 13, 80, 31, 113, 134, 111, 98, 12, 10, 190, 76, 84, 110, 145, 44, 14, 157, 115, 81, 182, 114, 126, 178, 62, 86, 70, 112, 131, 158, 2, 160, 5, 94, 71, 58, 138, 103, 183, 20, 7, 180, 130, 117, 28, 189, 25, 29, 19, 73, 15, 135, 120, 139, 23, 65, 56, 87, 177, 154, 174, 16, 82, 68, -1, 171, 51, 122, 165, 147, 11, 38, 102, 93, 159, 107, 149, 74, 164, 57, 69, 67, 187, 148, 129, 136, 75, 127, 119, 88, 156, 137, 36, 79, 50, 6, 175, 166, 34, 89, 53, 123, 118, 161, 186, 162, 128, 152, 163, 132
#
# Transcript Video 0IMWasj76yU:
# Topics Present: 0
#
# Transcript Video 1kErCqgIVMk:
# Topics Present: 0
#
# Transcript Video 2TmagN6RhkI:
# Topics Present: 0
#
# Transcript Video 2ftG8JuMzz4:
# Topics Present: 21, 106, 96, 17, 1, 163, 52, 22, 92, 0, 19, 2, 15, 23, 36, 97, 168, 127, 157, 9, 173, 80, 35, 8, 111, 38, 37, 149, 183, 186, 166
#
# Transcript Video 3n1nspLgfd4:
# Topics Present: 0
#
# Transcript Video 401ZvQ11euA:
# Topics Present: 13, 170, 24, 1, 3, 63, 98, 70, 39, 2, 35, 136, 73, 37, 137, 112, 62, 66, 85, 74, 180, 105, 114, 154, 34, 186, 143, 179
#
# Transcript Video 4OiOwDh5lKE:
# Topics Present: 0
#
# Transcript Video 6ftiWoCJ4dM:
# Topics Present: 0, 137, 128
#
# Transcript Video 7jDrzdX2Ucc:
# Topics Present: 0
#
# Transcript Video 7zaMbzqj8AI:
# Topics Present: 0, 114, 23, 162
#
# Transcript Video 86gs985X5tU:
# Topics Present: 22, 14, 21, 170, 55, 97, 165, 8, 145, 146, 9, 11, 67, 48, 108, 7, 111, 117, 141, 106
#
# Transcript Video 8DYPxsr7kDI:
# Topics Present: 0
#
# Transcript Video 8kcD3vk12AY:
# Topics Present: 0
#
# Transcript Video 9Qlof7jPQpg:
# Topics Present: 88, 0
#
# Transcript Video ARMdb7fgfQU:
# Topics Present: 0
#
# Transcript Video A_HLtsg4TVA:
#
# Transcript Video nOsxxtVS7fE:
# Topics Present: 0
#
# Transcript Video oul9IITqAoA:
# Topics Present: 1, 3, 13, 182, 183, 89, 82, 4, 148, 43, 169, 124, 29, 170, 83, 2, 5, 156, 118
#
# Transcript Video p1LaUfLyYpQ:
# Topics Present: 2, 145, 1, 88, 27, 95, 89, 36, 60, 183, 39, 14, 23, 40, 0, 43, 53, 69, 5, 11, 171, 46
#
# Transcript Video puxKH-_9xGM:
# Topics Present: 0
#
# Transcript Video q5Y4j8oBtRY:
# Topics Present: 0
#
# Transcript Video qMwRJXEZJ6k:
# Topics Present: 116, 3, 11, 70, 46, 64, 42, 31, 51, 74, 53, 10, 81, 161
#
# Transcript Video roCaFODDTbM:
# Topics Present: 0
#
# Transcript Video sXsHYugynnI:
# Topics Present: 59, 129, 12, 90, 57, 103, 184, 106, 135, 6, 190
#
# Transcript Video tjDZ9-6PxiQ:
# Topics Present: 0
#
# Transcript Video u6uj4yjTn-k:
# Topics Present: 45, 82, 41, 86, 33, 39, 107, 78, 11, 186, 152, 176, 58
#
# Transcript Video vk7_uI-V_9I:
# Topics Present: 0
#
# Transcript Video vwIIeiOhTJ0:
# Topics Present: 36, 2, 3, 180, 7, 121, 137, 67, 186, 179, 38, 173, 62, 81, 18, 177, 97, 161, 88, 20, 101, 70, 106, 40, 144, 10, 159, 59, 83, 138, 0, 15, 4, 63, 164, 188, 8, 6, 55, 71, 107, 84, 90, 92, 136, 46, 166
#
# Transcript Video wpnWOgl3MVc:
# Topics Present: 50, 3, 23, 46, 180, 21, 147, 48, 85, 0, 187, 27, 59, 104, 12, 19, 16, 179, -1, 78, 166, 87, 123
#
# Transcript Video y9ApSkrvLKg:
# Topics Present: 0
#
# Transcript Video y9iCFcSaD58:
# Topics Present: 0, 183, 134, 69, 14, 21, 27, 61, 9, 50, 163, 38, 97, 104, 2, 87, 137, 110, 133, 149, 188, 67, 86, 78, 141, 173, 40, 33, 41, 12, 117, 124, 146, 52, 99, 145, 4, 112, 118, 109, 96, 159, 8, 1, 56, 139, 7, 64, 121, 85, 120, 73, 187, 44, 91, 49, 111, 72, 175, 130, 171, 82, 39, 19, 138, 147, 70, 129, 48, 76, 28, 131, 122, 77, 29, 170, 18, 160, 51, 16, 167, 143, 128, 164, 23, 168, 92, 115, 11, 83, 153, 103, 165, 15, 35, 17, 45, 3, 152, 5, 26, 119, 102
#
# Transcript Video y9xOKcZD0xE:
# Topics Present: 0, 70, 186, 61, 16, 8, 139, 18, 12, 100, 80, 132, 21, 20, 99, 2, 89, 39
#
# Transcript Video yR6a9-ufsZc:
# Topics Present: 0
#
# Transcript Video zTcCSyucYqI:
# Topics Present: 0
#
# Transcript Video zwOJjQuL4i4:
# Topics Present: 63, 6, 115, 119, 23, 0, 131, 37, 30

# %%
# Retrieve topic names from BERTopic
topic_info = topic_model.get_topic_info()
topic_mapping = {row["Topic"]: row["Name"] for _, row in topic_info.iterrows()}

# Count topic occurrences per Video Id
topic_counts = topic_df.groupby(["Video Id", "Topic"]).size().reset_index(name="Count")

# Calculate percentage per Video Id
topic_counts["Percentage"] = topic_counts.groupby("Video Id")["Count"].transform(lambda x: (x / x.sum()) * 100)

# Map topic names
topic_counts["Topic Name"] = topic_counts["Topic"].map(topic_mapping)

# Aggregate topics into a single row per Video Id with newline separation
video_topics = topic_counts.groupby("Video Id").apply(
    lambda group: "\n".join(
        [f"{row['Topic Name']} ({row['Percentage']:.2f}%)" for _, row in group.iterrows()]
    )
).reset_index(name="List of Topics with %")

# Display the final DataFrame
print(video_topics)
# Out:
#        Video Id                              List of Topics with %
# 0   --8n6A8Q6M0  -1_parokya parokya_whoooooooooooa wayhay_delas...
# 1   0IMWasj76yU       0_philippine_filipino_manila_local (100.00%)
# 2   1kErCqgIVMk       0_philippine_filipino_manila_local (100.00%)
# 3   2TmagN6RhkI       0_philippine_filipino_manila_local (100.00%)
# 4   2ftG8JuMzz4  0_philippine_filipino_manila_local (1.37%)\n1_...
# ..          ...                                                ...
# 95  y9iCFcSaD58  0_philippine_filipino_manila_local (0.71%)\n1_...
# 96  y9xOKcZD0xE  0_philippine_filipino_manila_local (28.00%)\n2...
# 97  yR6a9-ufsZc       0_philippine_filipino_manila_local (100.00%)
# 98  zTcCSyucYqI       0_philippine_filipino_manila_local (100.00%)
# 99  zwOJjQuL4i4  0_philippine_filipino_manila_local (7.14%)\n6_...
#
# [100 rows x 2 columns]
# /var/folders/0h/nny21pq933l69r8z2vx7hdj80000gn/T/ipykernel_19940/2721641517.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   video_topics = topic_counts.groupby("Video Id").apply(

# %%
video_topics.to_csv("video_topics_distribution.csv", index=False)

# %% [markdown]
# ## Given a video, what are the topics under it?

# %%
# Step 1: Take user input
video_id_input = input("Enter Video Id: ").strip()

# Step 2: Retrieve Video Title from topics_per_video_df
video_title_row = topics_per_video_df.reset_index()
video_title = video_title_row.loc[video_title_row["Link"].str.contains(video_id_input, case=False, na=False), "Video Title"].values

if len(video_title) == 0:
    print("\nVideo Id not found in dataset.")
else:
    video_title = video_title[0]  # Extract single value
    print(f"\nResults for {video_id_input}.txt\n")
    print(f"Video Title: {video_title}\n")

    # Step 3: Display full initial transcript from experiment_df
    transcript = experiment_df.loc[experiment_df["Video Id"] == video_id_input, "Transcript"].values
    if len(transcript) > 0:
        print("<Transcript File>\n")
        print(transcript[0])  # Print the full transcript
    else:
        print("Transcript not found.")

    # Step 4: Retrieve topics for this Video Id from video_topics
    topics_present = video_topics.loc[video_topics["Video Id"] == video_id_input, "List of Topics with %"].values
    if len(topics_present) > 0:
        print("\nTopics Present:\n")
        print(topics_present[0])  # Display topic names and percentages
    else:
        print("No topics found.")

    # Step 5: Retrieve and display segmented transcript with topics
    print("\nSegmented Transcript and Assigned Topics:\n")

    video_segments = topic_df.loc[topic_df["Video Id"] == video_id_input, ["Segment", "Topic", "Topic Name"]]

    if not video_segments.empty:
        for idx, row in video_segments.iterrows():
            print(f"Segment {idx + 1}:")
            print(f"{row['Segment']}\n")
            print(f"➡ Assigned Topic: {row['Topic Name']} (Topic #{row['Topic']})\n")
            print("-" * 50)  # Separator for clarity
    else:
        print("No segments found for this Video Id.")
# Out:
# Results for y9iCFcSaD58.txt
#
# Video Title: PHILIPPINES STREET FOOD Tour - INSANELY DELICIOUS  FIRST TIME Trying JOLLIBEE!
#
# <Transcript File>
#
# After wrapping up our time in El Nido, we have made it all the way over to Boracay,
# and unfortunately, the weather has not been on our side on this beautiful island,
# but good news we have our friends Greg and Jumi who have made it all the way over from Cebu with us,
# and with this bad weather we thought it would be the perfect time to bring them back into
# our lives and have another amazing opportunity
# to try some local Filipino food.
# So we're super excited about that because we're gonna see the non-touristic side of Boracay with them
# We're gonna start with a fried quail egg called Kwek Kwek,
# hope Jumi's gonna correct me if I mispronounced it
# but this is one of those things where even like the local taxi drivers are coming up grabbing one as a snack, and...
# let's go get eating!
# Who's ordering? Am I ordering or you're ordering?
# Well, you should order! Yeah
# Do you like this? Kwek Kwek! Okay, it's good? Okay!
# "Salamat!" (Thank you)
# Of course Gokce is gonna do the honors...
# We're holding like together.
# This is our first street food in Philippines. - Yes!
# All right, I'm gonna try because I don't want it to get cold. It's hot, right? - Hot!
# Is this sauce like sweet? Yeah I think it's the sauce.
# I don't want to drop the outer shell because I want to eat together.
# It tastes like eggs but the outer shell is a little bit sweet
# I think it's just kind of like - even the sweet little
# powder and then it's crunchy on the outside
# but I can't really differentiate it from my regular egg honestly... - No. - No - No
# Traditionally, it's like smaller than this.
# As a kid this is like our traditional (really) childhood street food snack.
# so you could really see it - especially in the city - you can see it everywhere!
# this is a little bigger, but still - kwek kwek!
# Kwek Kwek!
# Go ahead Steve!
# Am I getting the bigger piece?
# It's up to you!
# Thank you for holding it by the way. - No problem!
# Such a hospitable girl!
# I didn't get the yolk part either but yeah.
# No take it, take it! Definitely take it!
# I'm gonna do it with my (hands)
# That's good, that's good!
# Sweat, a little crunchy as its fried.
# I mean, I could easily see eating one of these by myself,
# but of course we're sharing, because sharing is caring!
# it's pretty good and I just love eggs, so you know I'll always go for one of these any day right on the street!
# That's pretty awesome
# This is another traditional merienda or snack during afternoon
# So this is bananacue; banana sugar coated with sugar!
# Duh!
# Caramelized banana... This is what you were
# kind of talking about right? - Yeah
# Greg already kind of told me about that, but he's excited too!
# This one's fresh. - Wow!
# Thank you!
# How much is it? - 15 pesos.
# Okay [Music]
# Oh my God! Look at this! How are we gonna eat this?
# There is two sticks in here to support both of the bananas that have been deep fried basically
# Holy cow! and it smell so good.
# I am going to small one! (- Oh my gosh)
# You can have the big one.
# Would you like to go first then? - Yeah I'll go first.
# It's a lot of calories today.
# I'm not going to be happy...
# but I'm happy now.
# We're gonna go run on the beach later.
# Well look at the steam coming out of that.
# Holy cow!
# So good. I love bananas!
# Oh God, it's hot be careful.
# All right, I'm not gonna lie, I would go for this sooner than the quail egg,
# and we would get like ridiculously chunky off of eating this - all day, every day!
# What an amazing snack, wow!
# Yeah, it's not the regular banana that you just eat.
# There are so many types of bananas. -Yes
# But the one that people actually consume on a daily basis is actually one of them. - Yeah
# It's the most frequently consumed one, because it's the one that everybody likes at most.
# but this is (a different one) another I guess banana from the banana family. - Yeah
# Holy crap Greg your stick is really crooked!
# Oh, that's what she said!
# I love how crispy it is on the outside [Music]
# It's ripe banana too!
# I am going to finish this and then give the rest to Steve.
# and we'll walk a lot maybe we will run on the beach
# [Music]
# Jumi was like "you have to try!"
# She's showing everything! That's our favorite local food!
# Very nice meeting you! Bye!
# Traffic in the island, wow!
# We're trying to move, let's go.
# I love how this walkway is covered with sand. It feels like you're completely walking on the Sandy Beach but you're actually on the walkway!
# Sideway? Whatever way it is!
# So this is sticky rice. Sticky rice! this is sticky rice flour. Ube, remember Ube?
# we had it with the Halo Halo? Oh yeah!
# and this one is Bochi with sesame seed, very different.
# Why don't they get one of each and four of us will share? - Yeah.
# One, one, one (in Tagalog). Salamat (Thank you!)
# Good job, good job, good job! -Thank you, thank you. I am learning.
# Finally we can see some sunlight today after the pouring rain earlier, and now we're gonna try
# this delicious snacks that Jumi picked for us.
# So this is the sticky rice and... What is this made of?
# Rice? Rice, of course and probably brown sugar
# and it's served on the banana leaf. - Yeah
# Really authentic.
# I don't know how to properly eat this so I'm just gonna...
# Bite it, bite it! - Oh bite? - Yeah bite. - OK!
# Of course not bite the banana leaf. I'll just take this maybe? - Yeah that's fine.
# Because I want to share it with you guys!
# Pretty good! It's not too sweet to the point that it overwhelms you, but it's sweet enough that
# it could be consumed like a dessert!
# Feeding my man with my own hands!
# If we had to rank the snacks that we've had so far today, this would right now be in last place.
# It's very plain. The banana and even the quail egg were really delicious and this is just not my gem.
# She's just going to feed me [Music]
# I see, I see what you mean in there. It's not in my expectation.
# It was supposed to be a little sweet but it was not that sweet. This one's a little bit blend.
# Buchi, buchi!
# I like the sesame seeds smell it reminds me of Simit (Turkish Bagel)
# and I love Simit, and if you don't know what Simit is, well, you should watch our Turkish street food video!
# That's interesting. What's in there?
# I have no idea! I was about to ask you.
# I don't know the Puchi that I'm so used to is straight like this filled with white thing.
# I'll feed Steve and see. I like it though [Music]
# Wow, it's a lot sweeter than I thought it was going to be.
# I don't think it's egg!
# Let's see if Greg knows the deal. Let's see what he is going to say.
# You feed Greg now too!
# It might be sweet and salted egg, I don't know! It
# has that kind of flavor. I am not sure!
# I just love the smell!
# Yeah the Sesame is really nice and chewy texture.
# I just love the smell of the sesame seed, I just love love love sesame!
# The chewy texture is really nice though.
# I know, right?
# Really interesting. By the way, this is "Travel  interesante" slash "Gökçe feeds everyone" and we're just gonna continue like this I guess for the rest of today.
# Oh man, look at this! This is like a ...
# It looks so beautiful to the point that I don't even want to eat it!
# What is this?  - Sapin sapin.
# Isa Isa Isa (One by one in Filipino). Sapin sapin. Salamat! (Thank you in Filipino)
# She is so sweet!!
# Gökçe is practicing to stay I think...
# Okay... -  It's very sticky!
# It looks like a jelly! - Like a lot less rice.
# Straight purple!
# There's literally no smell...
# Okay!
# ...which is interesting. What should be my expectations?
# It's salt is middle ground. - Middle ground, okay!
# ➡ Assigned Topic: philippine, filipino, manila, local, hey, fun, street, city, spot, gon (Topic #0)
#
# --------------------------------------------------
# Segment 887:
# ordering ordering ordering
#
# ➡ Assigned Topic: uh sort enter, sort enter, uh sort, sort enter write, priority write curfew, person uh sort, priority, priority write, checked lot cat, learning (Topic #183)
#
# --------------------------------------------------
# Segment 888:
# well order
#
# ➡ Assigned Topic: uh sort enter, sort enter, uh sort, sort enter write, priority write curfew, person uh sort, priority, priority write, checked lot cat, learning (Topic #183)
#
# --------------------------------------------------
# Segment 889:
# yeah like
#
# ➡ Assigned Topic: slipped, , , , , , , , ,  (Topic #134)
#
# --------------------------------------------------
# Segment 890:
# kwek kwek okay good
#
# ➡ Assigned Topic: salamat salamat, tagalog salamat, salamat, salamat salamat job, salamat speaking tagalog, salamat job, speaking tagalog salamat, kwek salamat salamat, salamat speaking, kwek salamat (Topic #69)
#
# --------------------------------------------------
# Segment 891:
# okay salamat
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #69)
#
# --------------------------------------------------
# Segment 892:
# course gokce gon na honor holding like together
#
# ➡ Assigned Topic: gon gon gon, gon gon, yesar gon, gon, kambayan gon, kwek steve gon, called gon, guy gon gon, gon talk, gon hard gon (Topic #14)
#
# --------------------------------------------------
# Segment 893:
# first street food philippine
#
# ➡ Assigned Topic: filipino cuisine, food philippine, filipino dish, food filipino, filipino food, indonesian food, filipino eat, food unique cuisine, exotic food, list philippine exotic (Topic #21)
#
# --------------------------------------------------
# Segment 894:
# yes
#
# ➡ Assigned Topic: blonde huh blonde, tubbataha, huh blonde, tubbataha tubbataha, lister blonde huh, nadir tubbataha tubbataha, blonde huh, tubbataha tubbataha tubbataha, lister lister blonde, lister blonde (Topic #27)
#
# --------------------------------------------------
# Segment 895:
# right gon na try want get cold hot right hot
#
# ➡ Assigned Topic: hot, hot hot, hot hot hot, hot stuff hot, hwo hot hot, damn hot, hwo hot, hot damn hot, hot stuff, hwo hwo hot (Topic #61)
#
# --------------------------------------------------
# Segment 896:
# sauce like sweet
#
# ➡ Assigned Topic: sauce bit spicy, spicy bit spicy, spicy flavor, spicy spicy, spicy, bit spicy, spicy taste, spicy bit, sauce chilles spicy, hot sauce (Topic #9)
#
# --------------------------------------------------
# Segment 897:
# yeah think sauce
#
# ➡ Assigned Topic: sauce bit spicy, spicy bit spicy, spicy flavor, spicy spicy, spicy, bit spicy, spicy taste, spicy bit, sauce chilles spicy, hot sauce (Topic #9)
#
# --------------------------------------------------
# Segment 898:
# want drop outer shell want eat together
#
# ➡ Assigned Topic: eat eat, eat, eat food, eating, ta eat, food eat, hey eat, eat properly, eat gon, gon eat (Topic #50)
#
# --------------------------------------------------
# Segment 899:
# taste like egg outer shell little bit sweet think kind like even sweet little powder crunchy outside really differentiate regular egg honestly
#
# ➡ Assigned Topic: egg uh, egg egg, egg, egg yolk, soft chuck egg, egg yolk bit, harder egg, yolk harder egg, egg white egg, solidified egg yolk (Topic #163)
#
# --------------------------------------------------
# Segment 900:
# traditionally like smaller
#
# ➡ Assigned Topic: size size, size, plastic size pretty, plastic size, traditionally bigger, wide, measure inch, scale, inch, traditionally bigger piece (Topic #38)
#
# --------------------------------------------------
# Segment 901:
# kid like traditional childhood street food snack
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #97)
#
# --------------------------------------------------
# Segment 902:
# could really see especially city see everywhere little bigger still kwek kwek
#
# ➡ Assigned Topic: kinda metropolis city, kinda metropolis, manila kinda metropolis, samal city belongs, tagalog city umm, random city manila, metropolis, manila city city, city city, samal city (Topic #104)
#
# --------------------------------------------------
# Segment 903:
# kwek kwek go ahead steve
#
# ➡ Assigned Topic: gon gon gon, gon gon, yesar gon, gon, kambayan gon, kwek steve gon, called gon, guy gon gon, gon talk, gon hard gon (Topic #14)
#
# --------------------------------------------------
# Segment 904:
# getting bigger piece
#
# ➡ Assigned Topic: size size, size, plastic size pretty, plastic size, traditionally bigger, wide, measure inch, scale, inch, traditionally bigger piece (Topic #38)
#
# --------------------------------------------------
# Segment 905:
#
#
# ➡ Assigned Topic: , , , , , , , , ,  (Topic #2)
#
# --------------------------------------------------
# Segment 906:
# thank holding way
#
# ➡ Assigned Topic: din kirby, momma mini bar, din kirby cindy, mini bar, din, salamat din kirby, momma mini, cindy, foodie momma mini,  (Topic #87)
#
# --------------------------------------------------
# Segment 907:
# problem
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #137)
#
# --------------------------------------------------
# Segment 908:
# hospitable girl
#
# ➡ Assigned Topic: girl straight girl, girlfriend girl girl, guy girl straight, girl straight, guy girl, straight girl, girlfriend girl, girl, girl girl, wee girlfriend (Topic #110)
#
# --------------------------------------------------
# Segment 909:
# get yolk part either yeah
#
# ➡ Assigned Topic: fun ramen, eat ramen, enjoy ramen, sir eat ramen, ramen enjoy, ramen eat, ramen eat ramen, ramen enjoy ramen, yolk ramen, ramen restaurant ramen (Topic #133)
#
# --------------------------------------------------
# Segment 910:
# take take definitely take gon na good good
#
# ➡ Assigned Topic: follow, follow uh follow, follow follow uh, uh follow, follow follow, follow uh, follow gon, pursue follow, pursue follow follow, uh follow called (Topic #149)
#
# --------------------------------------------------
# Segment 911:
# sweat little crunchy fried
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #188)
#
# --------------------------------------------------
# Segment 912:
# mean could easily see eating one course sharing sharing caring pretty good love egg know always go one day right street pretty awesome another traditional merienda snack afternoon bananacue banana sugar coated sugar
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #163)
#
# --------------------------------------------------
# Segment 913:
# duh caramelized banana
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 914:
# kind talking right yeah greg already kind told excited
#
# ➡ Assigned Topic: pas hey guy, hey mate message, cute guy cute, cute hey mate, hey mate, guy alright guy, alright guy bobbied, mate guy happy, pas hey, cute hey (Topic #86)
#
# --------------------------------------------------
# Segment 915:
# one fresh wow
#
# ➡ Assigned Topic: wow wow, wow, wow wow wow, wow wow hey, wow woohoo, wow god wow, amazing wow wow, whoa wow, huh amazing wow, amazing wow (Topic #78)
#
# --------------------------------------------------
# Segment 916:
# thank much
#
# ➡ Assigned Topic: pretty entire menu, entire menu, famous lechon, carved typically turkey, lechon lechon, lechon, typically turkey cuz, impressive centrepiece, entire menu oil, centrepiece (Topic #141)
#
# --------------------------------------------------
# Segment 917:
# peso
#
# ➡ Assigned Topic: kilo couple kilo, couple kilo, kilo kilo, kilo, kilo kilo kilo, weighs couple kilo, kilo weighs dunno, peso kilo kilo, kilo weighs, kilo kilo weighs (Topic #173)
#
# --------------------------------------------------
# Segment 918:
# okay oh god look
#
# ➡ Assigned Topic: map, oily write map, write map, map map, write map map, map purpose prospect, map purpose, map map purpose, guy map, searching guy map (Topic #40)
#
# --------------------------------------------------
# Segment 919:
# gon na eat
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #50)
#
# --------------------------------------------------
# Segment 920:
# two stick support banana deep fried basically holy cow
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 921:
# smell good
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #33)
#
# --------------------------------------------------
# Segment 922:
# going small one big one
#
# ➡ Assigned Topic: size size, size, plastic size pretty, plastic size, traditionally bigger, wide, measure inch, scale, inch, traditionally bigger piece (Topic #38)
#
# --------------------------------------------------
# Segment 923:
# would like go first yeah go first
#
# ➡ Assigned Topic: walking, walking time puchi, walking walking walking, walking straight, bringing moving walking, moving walking, walking walking, walking walking minute, walking straight modernise, puchi straight filled (Topic #41)
#
# --------------------------------------------------
# Segment 924:
# lot calorie today
#
# ➡ Assigned Topic: kilo couple kilo, couple kilo, kilo kilo, kilo, kilo kilo kilo, weighs couple kilo, kilo weighs dunno, peso kilo kilo, kilo weighs, kilo kilo weighs (Topic #173)
#
# --------------------------------------------------
# Segment 925:
# going happy happy
#
# ➡ Assigned Topic: fun fun, fun fun fun, fun uh, fun, hat fun, hey fun, hey fun fast, hat fun hey, enjoying, enjoy enjoy (Topic #12)
#
# --------------------------------------------------
# Segment 926:
# gon na go run beach later
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #117)
#
# --------------------------------------------------
# Segment 927:
# well look steam coming
#
# ➡ Assigned Topic: hot, hot hot, hot hot hot, hot stuff hot, hwo hot hot, damn hot, hwo hot, hot damn hot, hot stuff, hwo hwo hot (Topic #61)
#
# --------------------------------------------------
# Segment 928:
# holy cow good
#
# ➡ Assigned Topic: lot sweeter balance, uh pretty insight, pretty insight, pretty insight pretty, sweeter balance, balance expecting lot, sweeter balance experience, insight pretty, expecting lot sweeter, insight pretty dark (Topic #33)
#
# --------------------------------------------------
# Segment 929:
# love banana
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 930:
# oh god hot careful
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #124)
#
# --------------------------------------------------
# Segment 931:
# right gon na lie would go sooner quail egg would get like ridiculously chunky eating day every day
#
# ➡ Assigned Topic: egg uh, egg egg, egg, egg yolk, soft chuck egg, egg yolk bit, harder egg, yolk harder egg, egg white egg, solidified egg yolk (Topic #163)
#
# --------------------------------------------------
# Segment 932:
# amazing snack wow
#
# ➡ Assigned Topic: yummy, yummy hmm, hmm yummy, yummy yummy, yummy yummy hmm, hmm yummy yummy, yummy hmm yummy, yum yummy, yummy wee, yummy yummy yummy (Topic #146)
#
# --------------------------------------------------
# Segment 933:
# yeah regular banana eat
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 934:
# many type banana
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 935:
# yes one people actually consume daily basis actually one yeah frequently consumed one one everybody like
#
# ➡ Assigned Topic: uh day, day, day day, spent day yesterday, tomorrow day, uh day people, mind yesterday sunday, weekend day day, afternoon, guess afternoon (Topic #52)
#
# --------------------------------------------------
# Segment 936:
# another guess banana banana family
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 937:
# yeah holy crap greg stick really crooked
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #99)
#
# --------------------------------------------------
# Segment 938:
# oh said love crispy outside ripe banana
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 939:
# going finish give rest steve
#
# ➡ Assigned Topic: finish rest, finish rest steve, finish ride, close finished gon, finished gon, rest steve finished, finished gon finish, finish ride guy, finished, gon finish (Topic #145)
#
# --------------------------------------------------
# Segment 940:
# walk lot maybe run beach jumi like try
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #4)
#
# --------------------------------------------------
# Segment 941:
# showing everything
#
# ➡ Assigned Topic: variety variety, variety gon variety, variety, variety gon, variety variety variety, variety upsold, variety customised, recommends variety upsold, variety variety pack, gon variety variety (Topic #112)
#
# --------------------------------------------------
# Segment 942:
# favorite local food
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #21)
#
# --------------------------------------------------
# Segment 943:
# nice meeting bye
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #118)
#
# --------------------------------------------------
# Segment 944:
# traffic island wow
#
# ➡ Assigned Topic: ha ha ha, ha ha, dying boulevard ha, ha, wow street stuff, wow street, pavement guy loudest, dying boulevard, noise pollution traffic, causing traffic (Topic #109)
#
# --------------------------------------------------
# Segment 945:
# trying move let go
#
# ➡ Assigned Topic: break spirit break, break spirit, yam leave break, leave break stick, wait difficult ugly, ugly artistic, soul break, break, ugly eff, break heart (Topic #96)
#
# --------------------------------------------------
# Segment 946:
# love walkway covered sand
#
# ➡ Assigned Topic: secret beach, beach puka, puka beach, beach puka beach, beach, beach beach, puka beach puka, puka beach beautiful, beautiful beach, question wow beach (Topic #4)
#
# --------------------------------------------------
# Segment 947:
# feel like completely walking sandy beach actually walkway
#
# ➡ Assigned Topic: secret beach, beach puka, puka beach, beach puka beach, beach, beach beach, puka beach puka, puka beach beautiful, beautiful beach, question wow beach (Topic #4)
#
# --------------------------------------------------
# Segment 948:
# sideway whatever way
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #159)
#
# --------------------------------------------------
# Segment 949:
# sticky rice
#
# ➡ Assigned Topic: rice, lol rice, banaue rice, rice rice, rice main, plain rice, rice bit, sticky rice, rice main dish, bit rice (Topic #8)
#
# --------------------------------------------------
# Segment 950:
# sticky rice
#
# ➡ Assigned Topic: rice, lol rice, banaue rice, rice rice, rice main, plain rice, rice bit, sticky rice, rice main dish, bit rice (Topic #8)
#
# --------------------------------------------------
# Segment 951:
# sticky rice flour
#
# ➡ Assigned Topic: rice, lol rice, banaue rice, rice rice, rice main, plain rice, rice bit, sticky rice, rice main dish, bit rice (Topic #8)
#
# --------------------------------------------------
# Segment 952:
# ube remember ube
#
# ➡ Assigned Topic: bum gun, fist bump fist, bump fist, bump fist bump, fist bump, fist, bum, gun, shotgun, bump (Topic #1)
#
# --------------------------------------------------
# Segment 953:
# halo halo
#
# ➡ Assigned Topic: save halo halo, halo save, save halo, halo halo save, morning halo halo, halo save halo, eat halo halo, halo halo greeting, halo greeting, halo halo brown (Topic #56)
#
# --------------------------------------------------
# Segment 954:
# oh yeah
#
# ➡ Assigned Topic: slipped, , , , , , , , ,  (Topic #134)
#
# --------------------------------------------------
# Segment 955:
# one bochi sesame seed different
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #139)
#
# --------------------------------------------------
# Segment 956:
# get one four u share
#
# ➡ Assigned Topic: milo bit milo, bit milo, milo, milo guy, milo milo, milo milo milo, milo friend milo, milo bit, milo guy cone, milo friend (Topic #7)
#
# --------------------------------------------------
# Segment 957:
# yeah one one one
#
# ➡ Assigned Topic: milo bit milo, bit milo, milo, milo guy, milo milo, milo milo milo, milo friend milo, milo bit, milo guy cone, milo friend (Topic #7)
#
# --------------------------------------------------
# Segment 958:
# salamat good job good job good job
#
# ➡ Assigned Topic: salamat salamat, tagalog salamat, salamat, salamat salamat job, salamat speaking tagalog, salamat job, speaking tagalog salamat, kwek salamat salamat, salamat speaking, kwek salamat (Topic #69)
#
# --------------------------------------------------
# Segment 959:
# thank thank
#
# ➡ Assigned Topic: din kirby, momma mini bar, din kirby cindy, mini bar, din, salamat din kirby, momma mini, cindy, foodie momma mini,  (Topic #87)
#
# --------------------------------------------------
# Segment 960:
# learning
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #64)
#
# --------------------------------------------------
# Segment 961:
# finally see sunlight today pouring rain earlier gon na try delicious snack jumi picked u
#
# ➡ Assigned Topic: rain gon rain, rain gon, raining weather letting, gon rain, rained rain gon, rain coming rainy, rain sun raining, rain drizzle, rain, rain earlier gon (Topic #121)
#
# --------------------------------------------------
# Segment 962:
# sticky rice made
#
# ➡ Assigned Topic: rice, lol rice, banaue rice, rice rice, rice main, plain rice, rice bit, sticky rice, rice main dish, bit rice (Topic #8)
#
# --------------------------------------------------
# Segment 963:
# rice
#
# ➡ Assigned Topic: rice, lol rice, banaue rice, rice rice, rice main, plain rice, rice bit, sticky rice, rice main dish, bit rice (Topic #8)
#
# --------------------------------------------------
# Segment 964:
# rice course probably brown sugar served banana leaf
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 965:
# yeah really authentic
#
# ➡ Assigned Topic: honestly, uh honestly, honestly honestly, uh honestly honestly, honestly honestly honestly, real, real real, real life, real life malate, honestly honestly authentic (Topic #85)
#
# --------------------------------------------------
# Segment 966:
# know properly eat gon na
#
# ➡ Assigned Topic: eat eat, eat, eat food, eating, ta eat, food eat, hey eat, eat properly, eat gon, gon eat (Topic #50)
#
# --------------------------------------------------
# Segment 967:
# bite bite
#
# ➡ Assigned Topic: bite bite, wee bit chewy, bite, bite bite bite, bite haha, bite haha teeth, mouth itlike bite, itlike bite, bite bite feel, bite feel (Topic #120)
#
# --------------------------------------------------
# Segment 968:
# oh bite yeah bite ok
#
# ➡ Assigned Topic: bite bite, wee bit chewy, bite, bite bite bite, bite haha, bite haha teeth, mouth itlike bite, itlike bite, bite bite feel, bite feel (Topic #120)
#
# --------------------------------------------------
# Segment 969:
# course bite banana leaf
#
# ➡ Assigned Topic: banana ketchup, ketchup banana, ketchup banana ketchup, ketchup ketchup banana, supposed banana ketchup, banana ketchup banana, ketchup banana tree, served banana, mushy banana, banana eat (Topic #67)
#
# --------------------------------------------------
# Segment 970:
# take maybe
#
# ➡ Assigned Topic: differs chapaghetti taste, chapaghetti taste, taste completely chapaghetti, chapaghetti delicious sir, chapaghetti delicious, wheat love oatmeal, cream wheat love, love oatmeal, eeeeeehehhhhhh, delicious sir (Topic #73)
#
# --------------------------------------------------
# Segment 971:
# yeah fine
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #187)
#
# --------------------------------------------------
# Segment 972:
# want share guy
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #44)
#
# --------------------------------------------------
# Segment 973:
# pretty good
#
# ➡ Assigned Topic: wooh gulaman wow, pretty wooh sago, wooh gulaman, fantastic uh, fantastic uh sizzling, gulaman wow, gulaman wow load, pretty wooh, xl fantastic uh, jelly wooh gulaman (Topic #91)
#
# --------------------------------------------------
# Segment 974:
# ...
# Segment 1108:
# steamed duck embryo
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #15)
#
# --------------------------------------------------
# Segment 1109:
# day meaning fully grown duckling little bit probably duckling
#
# ➡ Assigned Topic: uh day, day, day day, spent day yesterday, tomorrow day, uh day people, mind yesterday sunday, weekend day day, afternoon, guess afternoon (Topic #52)
#
# --------------------------------------------------
# Segment 1110:
# classic iconic nighttime snack
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #97)
#
# --------------------------------------------------
# Segment 1111:
# really little bit worried right jumi picked though like whole supposed break open
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #121)
#
# --------------------------------------------------
# Segment 1112:
# marked open embryonic fluid
#
# ➡ Assigned Topic: water water, water, water water water, outline water, water cool, salle lot water, wow water add, lot water, blue water water, submerged (Topic #35)
#
# --------------------------------------------------
# Segment 1113:
# going stuck lack better way describe
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #39)
#
# --------------------------------------------------
# Segment 1114:
# sip sip sip
#
# ➡ Assigned Topic: uh margarita, margarita uh, margarita super uh, margarita pool cebu, margarita margarita, margarita frozen margarita, margarita, margarita classic margarita, margarita margarita margarita, margarita uh water (Topic #17)
#
# --------------------------------------------------
# Segment 1115:
# oh like warm
#
# ➡ Assigned Topic: hot, hot hot, hot hot hot, hot stuff hot, hwo hot hot, damn hot, hwo hot, hot damn hot, hot stuff, hwo hwo hot (Topic #61)
#
# --------------------------------------------------
# Segment 1116:
# little salty
#
# ➡ Assigned Topic: salty salty, salty, salty salty salty, salty salted, salty salty haha, haha salty salty, salty haha salty, salty flavor salty, salty food salty, salt salty (Topic #77)
#
# --------------------------------------------------
# Segment 1117:
# strange man
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #45)
#
# --------------------------------------------------
# Segment 1118:
# odd thing eat food u obviously like
#
# ➡ Assigned Topic: eat eat, eat, eat food, eating, ta eat, food eat, hey eat, eat properly, eat gon, gon eat (Topic #50)
#
# --------------------------------------------------
# Segment 1119:
# juice tasty oh god eat entire thing
#
# ➡ Assigned Topic: yummy, yummy hmm, hmm yummy, yummy yummy, yummy yummy hmm, hmm yummy yummy, yummy hmm yummy, yum yummy, yummy wee, yummy yummy yummy (Topic #146)
#
# --------------------------------------------------
# Segment 1120:
# like whole
#
# ➡ Assigned Topic: huh, buff huh, people huh, huh combination buff, people huh combination, huh combination, combination buff huh, buff huh gloss, stuff guy, people people huh (Topic #48)
#
# --------------------------------------------------
# Segment 1121:
# whole thing good luck
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #33)
#
# --------------------------------------------------
# Segment 1122:
# go think
#
# ➡ Assigned Topic: lot sweeter gökçe, idea taste vinegar, prefer sweeter, shinee shinee, vinegar prefer sweeter, taste vinegar prefer, idea taste, wow lot sweeter, sweeter, sweeter gökçe (Topic #39)
#
# --------------------------------------------------
# Segment 1123:
# go steve go
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #14)
#
# --------------------------------------------------
# Segment 1124:
# really good freaking weird man
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #122)
#
# --------------------------------------------------
# Segment 1125:
# really right definitely choice greg jumi choice philippine
#
# ➡ Assigned Topic: philippine, philippine philippine, filipino philippine, philippine philippine philippine, philippine filipino, philippine country, gon philippine, filipino, filipino filipino, philippine philippine filipino (Topic #3)
#
# --------------------------------------------------
# Segment 1126:
# seems like everybody right course filipino famous jollibee wait course check first time ever course local filipino food philippine try jollibee
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #152)
#
# --------------------------------------------------
# Segment 1127:
# oh wow really happening huh
#
# ➡ Assigned Topic: wow wow, wow, wow wow wow, wow wow hey, wow woohoo, wow god wow, amazing wow wow, whoa wow, huh amazing wow, amazing wow (Topic #78)
#
# --------------------------------------------------
# Segment 1128:
# okay
#
# ➡ Assigned Topic: alright, fine, quiapo alright, , , , , , ,  (Topic #5)
#
# --------------------------------------------------
# Segment 1129:
# never seen jumi excited
#
# ➡ Assigned Topic: parokya parokya, whoooooooooooa wayhay, delas, ey, ala pokwang, delas ala, whoooooooooooa, ala pokwang buff, ala, honk (Topic #139)
#
# --------------------------------------------------
# Segment 1130:
# greg gon na share bucket chicken yeah chicken must
#
# ➡ Assigned Topic: chicken chicken, chicken, juicy chicken, chicken fried chicken, chicken halang, fried chicken, gon chicken chicken, chicken halang halang, grilled chicken chicken, gon chicken (Topic #26)
#
# --------------------------------------------------
# Segment 1131:
# like must
#
# ➡ Assigned Topic: huh, buff huh, people huh, huh combination buff, people huh combination, huh combination, combination buff huh, buff huh gloss, stuff guy, people people huh (Topic #48)
#
# --------------------------------------------------
# Segment 1132:
# think got ta try spaghetti uh wish italian uh kind crazy spaghetti used got ta try
#
# ➡ Assigned Topic: noodle pancit noodle, yellow noodle noodle, pancit noodle, pancit noodle canton, noodle noodle choose, yellow noodle pancit, style yellow noodle, noodle creamy, noodle canton cantonese, noodle canton (Topic #119)
#
# --------------------------------------------------
# Segment 1133:
# okay
#
# ➡ Assigned Topic: alright, fine, quiapo alright, , , , , , ,  (Topic #5)
#
# --------------------------------------------------
# Segment 1134:
# peach mango pie must
#
# ➡ Assigned Topic: coconut coconut, coconut, milky coconut, milky coconut prefer, lemon coconut, mountain coconut, juice coconut, mango coconut hint, coconut juice, lemon coconut mango (Topic #18)
#
# --------------------------------------------------
# Segment 1135:
# jollibee taking freaking world
#
# ➡ Assigned Topic: crazy, uh crazy, crazy uh, ridiculous crazy, stupid completely crazy, completely crazy, ridiculous ridiculous crazy, literally crazy, crazy bit, insane literally crazy (Topic #122)
#
# --------------------------------------------------
# Segment 1136:
# thank jollibee
#
# ➡ Assigned Topic: pretty entire menu, entire menu, famous lechon, carved typically turkey, lechon lechon, lechon, typically turkey cuz, impressive centrepiece, entire menu oil, centrepiece (Topic #141)
#
# --------------------------------------------------
# Segment 1137:
# gigantic chicken piece oh god
#
# ➡ Assigned Topic: chicken chicken, chicken, juicy chicken, chicken fried chicken, chicken halang, fried chicken, gon chicken chicken, chicken halang halang, grilled chicken chicken, gon chicken (Topic #26)
#
# --------------------------------------------------
# Segment 1138:
# good
#
# ➡ Assigned Topic: lot sweeter balance, uh pretty insight, pretty insight, pretty insight pretty, sweeter balance, balance expecting lot, sweeter balance experience, insight pretty, expecting lot sweeter, insight pretty dark (Topic #33)
#
# --------------------------------------------------
# Segment 1139:
